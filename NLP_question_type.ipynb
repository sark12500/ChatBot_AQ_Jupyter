# %%
# -*- coding: utf-8 -*-
from datetime import datetime
import regex as re
from abc import ABCMeta, abstractmethod
from collections import OrderedDict

import jieba
import jieba.posseg as pseg
import requests
from bs4 import BeautifulSoup

# %%
# encoding=UTF-8
# !flask/bin/python

from cassandra.cluster import Cluster
from cassandra.policies import DCAwareRoundRobinPolicy
from cassandra.auth import PlainTextAuthProvider
from cassandra.query import BatchStatement
import pandas as pd


class CassandraType(object):
    PRODUCTION = 0
    TEST = 1
    TEST_DOCKER = 2


class CassandraDAO(object):

    # you have to install following items :
    # a. python-Cassandra driver
    # b. pyspark cassandra connector

    def __init__(self, type):
        #         print('runing father.__init__')
        if type == CassandraType.PRODUCTION:
            self.contact_points = ['192.168.95.127', '192.168.95.122']
            self.contact_points_str = "192.168.95.127,192.168.95.122"
        elif type == CassandraType.TEST:
            self.contact_points = ['192.168.0.41', '192.168.0.42']
            self.contact_points_str = "192.168.0.41,192.168.0.42"
        else:
            self.contact_points = ['192.168.0.121', '192.168.0.122', '192.168.0.52']
            self.contact_points_str = "192.168.0.121,192.168.0.122,192.168.0.52"

        self.formatString = "org.apache.spark.sql.cassandra"
        self.username = "username"
        self.password = "password"
        self.cluster = None
        self.session = None
        self.createSession()

    def __del__(self):
        self.cluster.shutdown()

    def pandas_factory(self, colnames, rows):
        return pd.DataFrame(rows, columns=colnames)

    def createSession(self):
        print "contact_points = " + self.contact_points_str
        self.cluster = Cluster(
            contact_points=self.contact_points,  # random select a node
            #             load_balancing_policy = DCAwareRoundRobinPolicy(local_dc='datacenter1'),
            #         auth_provider = PlainTextAuthProvider(username='cassandra', password='cassandra')
        )
        self.session = self.cluster.connect()
        self.session.row_factory = self.pandas_factory
        self.session.default_fetch_size = 10000000  # needed for large queries, otherwise driver will do pagination. Default is 50000.

    def getSession(self):
        return self.session

    def execCQL(self, keyspace, cql):
        """
        execute CQL
        """
        self.session.set_keyspace(keyspace)
        self.session.execute_async(cql)

    def execCQLSelect(self, keyspace, cql):
        """
        execute CQL, select only
        """

        self.session.set_keyspace(keyspace)

        #       cassandra ResultSet
        async_results = self.session.execute_async(cql)
        return async_results

    def execCQLCallBackAnysc(self, keyspace, cql, handle_success, handle_error):
        """
        execute CQL, if success => handle_success function, else handle_error
        """
        self.session.set_keyspace(keyspace)
        async_results = self.session.execute_async(cql)
        async_results.add_callbacks(handle_success, handle_error)

    def execCQLSelectToPandasDF(self, keyspace, cql):
        """
        execute CQL, select only, return Pandas DataFrame
        """

        self.session.set_keyspace(keyspace)

        #       cassandra ResultSet
        async_results = self.session.execute_async(cql)
        #         async_results = self.session.execute_async(cql)
        #       to Pandas DataFrame
        return async_results.result()._current_rows


    def execCQLSelectToRDD(self, sqlContext, keyspace, cql):
        """
        execute CQL, select only, return Spark RDD
        """

        return self.execCQLSelectToDF(sqlContext, keyspace, cql).rdd.map(tuple)  # dataFrame to RDD

    @property
    def contactPoints(self):
        return self.contact_points

    @contactPoints.setter
    def contactPoints(self, contact_points):
        self.contact_points = contact_points

    @contactPoints.deleter
    def contactPoints(self):
        del self.contact_points

# %%
CASSANDRA_ENV = CassandraType.PRODUCTION
dao = CassandraDAO(CASSANDRA_ENV)
# Out:
# contact_points = 192.168.95.127,192.168.95.122

# %%
import pandas as pd
import jieba
import jieba.posseg as pseg

class JiebaSegmentor:

    def __init__(self, dict_path, userdict=[], stopwords = False, stopwords_path=None):
        self.dict_path = dict_path
        self.userdict = userdict
        self.dictionary_init()
        self.stopwords_path = stopwords_path
        self.stopwords = stopwords
        self.stopwords_set = set()
        self.stopwords_init()

    def dictionary_init(self):
        jieba.set_dictionary(self.dict_path)
        for path in self.userdict:
            print path
            jieba.load_userdict(path)
    
    def stopwords_init(self):
        if self.stopwords_path:
            with open(self.stopwords_path ,'r') as stopwords:
                for stopword in stopwords:
                    self.stopwords_set.add(stopword.strip('\n').decode('utf-8'))

    def taiwan_country(self):
        return [u'臺北', u'台北', u'基隆', u'臺中', u'台中', u'臺南', u'台南', u'高雄',
                u'宜蘭', u'桃園', u'新竹', u'苗栗', u'彰化', u'南投', u'嘉義', u'雲林',
                u'屏東', u'臺東', u'台東', u'花蓮', u'澎湖']

    def wordToNumber(self, input_text):

        target = u''
        for s in input_text:

            if (s == u'零') or (s == '0'):
                to_word = u'0'
            elif (s == u'一') or (s == u'壹') or (s == '1'):
                to_word = u'1'
            elif (s == u'二') or (s == u'兩') or (s == u'貳') or (s == '2'):
                to_word = u'2'
            elif (s == u'三') or (s == u'參') or (s == '3'):
                to_word = u'3'
            elif (s == u'四') or (s == u'肆') or (s == '4'):
                to_word = u'4'
            elif (s == u'五') or (s == u'伍') or (s == '5'):
                to_word = u'5'
            elif (s == u'六') or (s == u'陸') or (s == '6'):
                to_word = u'6'
            elif (s == u'七') or (s == u'柒') or (s == '7'):
                to_word = u'7'
            elif (s == u'八') or (s == u'捌') or (s == '8'):
                to_word = u'8'
            elif (s == u'九') or (s == u'玖') or (s == '9'):
                to_word = u'9'
            else:
                to_word = s

        target = target + to_word
        return target

    def input_text_preprocessing(self, input_text):

        if type(input_text) is not unicode:
            input_text = input_text.decode('utf-8')

#         input_text = self.wordToNumber(input_text)
        return input_text

    def get_names(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        names = []
        words = pseg.cut(input_text)
        print words
        for w, f in words:
            if f.lower() == 'nr':
                names.append(w)
        for name in names:
            print name.encode('utf-8')
        return names

    def lcut(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        cut_raw = jieba.lcut(input_text)
        key = []

        for k in cut_raw:
            if self.stopwords:
                if k in self.stopwords_set:
                    continue
            
            key.append(k)
        df = pd.DataFrame({"word": key})
        return df

    def pseg_lcut(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        cut_raw = pseg.lcut(input_text)
        key = []
        value = []

        for k, v in cut_raw:
            tag = v
            if self.stopwords:
                if k in self.stopwords_set:
                    continue
            
            if k in self.taiwan_country():
                tag = u'ns'
            if len(k) > 1 and tag == u'x':
                tag = u'n'
            key.append(k)
            value.append(tag)
        df = pd.DataFrame({"word": key, "tag": value})
        return df

# %%
import jieba
import jieba.posseg as pseg
jieba_path = "/nfs/aq_test/jieba/"
jieba_dict_path1 = jieba_path + "dict_taiwan.txt"
jieba_dict_path2 = jieba_path +"userdict.txt"
jieba_dict_path3 = jieba_path +"dict.txt.big"
jieba_dict_path4 = jieba_path +"dict.txt.small"
jieba_stopwords_path = jieba_path +"stopwords.txt"
segmentor = JiebaSegmentor(jieba_dict_path1, 
                           [jieba_dict_path2,jieba_dict_path3,jieba_dict_path4], 
                           stopwords = False, 
                           stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /nfs/aq_test/jieba/dict_taiwan.txt ...
# DEBUG:jieba:Building prefix dict from /nfs/aq_test/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u34e30d1c15f49735c28e2158fa64cd7a.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.u34e30d1c15f49735c28e2158fa64cd7a.cache
# Loading model cost 0.578 seconds.
# DEBUG:jieba:Loading model cost 0.578 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# /nfs/aq_test/jieba/userdict.txt
# /nfs/aq_test/jieba/dict.txt.big
# /nfs/aq_test/jieba/dict.txt.small

# %%
# jieba & 詞性測試
test_cut =pseg.lcut('西瓜好大一顆')
text_subject_dict={}
for w,n in test_cut:
    print w + ' (' + n + ')'
    text_subject_dict.update({w:n})
print '---subject_dict---'
for k, v in text_subject_dict.items():
    print k + ' (' + v + ')'
# Out:
# 西瓜 (ns)
# 好 (a)
# 大 (a)
# 一顆 (m)
# ---subject_dict---
# 一顆 (m)
# 西瓜 (ns)
# 好 (a)
# 大 (a)

# %%
test_cut_raw_0 = pseg.lcut('陳水扁')
for w,n in test_cut_raw_0:
    print w + ' (' + n + ')'
# Out:
# 陳水扁 (nr)

# %%
unit_sentence = [u'什麼',u'哪個',u'哪些',u'那個',u'那些',u'哪兒',u'那兒']#,u'哪',u'那']
unit_sentence_rule = ''
for k,v in enumerate(unit_sentence):
    if k == len(unit_sentence) - 1:
        unit_sentence_rule = unit_sentence_rule + v
    else:
        unit_sentence_rule = unit_sentence_rule + v + '|'
print '(' + unit_sentence_rule + ')'
# Out:
# (什麼|哪個|哪些|那個|那些|哪兒|那兒)

# %%
class CheckQuestion:
    __metaclass__ = ABCMeta

    def __init__(self):
        pass

    class Label(object):
        WHY = 'why'
        WHEN = 'when'
        WHERE = 'where'
        WHO = 'who'
        WHAT = 'what'
        HOW = 'how'
        HOW_MANY = 'how_many'
        STATUS = 'status'
        FEEL = 'feel'
        OTHER = 'other'

    def get_v_subject(self):
        return ['v', 'vd', 'vg', 'vi', 'vn', 'vq', 'vt']

    def get_adj_subject(self):
        return ['a', 'ad', 'ag', 'an']

    def get_people_subject(self):
        return ['nr','nrfg','nrt']

    def get_location_subject(self):
        return ['ns']
    
    def get_n_subject(self):
        return ['n','ng','nt','nz']
 
    def get_eng_subject(self):
        return ['eng']
    
    def __get_unit_word(self):
        return [u'有沒有',u'什麼', u'哪一個', u'那一個', u'哪個', u'哪些', u'那個', u'那些', u'怎麼', u'哪兒', u'那兒', u'怎', u'哪', u'那']

    def get_adj_word_rule(self):
        return u'(鬼|怪|神祕|神奇)?(的)?'

    def get_unit_word_post_rule(self):

        unit_word = self.__get_unit_word()
        unit_word_rule = ''

        for k, v in enumerate(unit_word):
            unit_word_rule = unit_word_rule + v
            if k < len(unit_word) - 1:
                unit_word_rule = unit_word_rule + '|'

        unit_word_rule = '(' + unit_word_rule + ')' + u'(是)?'

        return unit_word_rule

    def get_unit_word_pre_rule(self):

        unit_word = self.__get_unit_word()
        unit_word_rule = ''

        for k, v in enumerate(unit_word):
            unit_word_rule = unit_word_rule + v
            if k < len(unit_word) - 1:
                unit_word_rule = unit_word_rule + '|'

        unit_word_rule = u'(是)?' + '(' + unit_word_rule + ')'

        return unit_word_rule

    def __repr__(self):
        return "{class_name}".format(class_name=self.__class__.__name__)

    @abstractmethod
    def check(self):
        pass

# %% [markdown]
# # 詢問原因

# %%
class CheckWhy(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckWhy, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問原因:
        label: why
        句型：
        1.(為什麼|爲何|爲啥)
        2.通用疑問句+通用形容句+(原因|理由)
        3.(原因|理由) + 通用疑問句+通用形容句
        """
        self.label = ''
        self.target = ''
        
        #1
        rule = u'(為什麼|爲何|爲啥)'
        pattern = re.compile(rule)
        #         print rule
        match = pattern.search(input_text)
        if match is not None:
            self.label = self.Label.WHY
            return True

        #2
        rule = self.get_unit_word_post_rule() + self.get_adj_word_rule() + u'(原因|理由)'
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        if match is not None:
            self.label = self.Label.WHY
            return True

        #3
        rule = u'(原因|理由)' + self.get_unit_word_pre_rule() + self.get_adj_word_rule()
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        if match is not None:
            self.label = self.Label.WHY
            return True

    # cc = CheckWhy(u'小狗會叫的原因是什麼')
    # if cc.check():
    #     print cc.label

# %% [markdown]
# # 詢問時間

# %%
class CheckWhen(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckWhen, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問時間:
        label: when
        """
        self.label = ''
        self.target = ''

        rule = u'(什麼時間|什麼時候|什麼年份|什麼月份|什麼年|什麼月|什麼日|什麼天|'+\
                u'哪時|那時|何時|哪一年|哪一月|哪一天|哪年|哪月|哪日|哪天|那一年|那一月|那一天|那年|那月|那日|那天)'
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        if match is not None:
            self.label = self.Label.WHEN
            return True

#         rule = self.get_unit_word_post_rule() + \
#                self.get_adj_word_rule() + \
#                u'(時間|時候|年份|月份|一年|一月|一天|年|月|日|天)'
#         #         print rule
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)
#         # print match
#         if match is not None:
#             self.label = self.Label.WHEN
#             return True

#         rule = u'(時間|時候|年份|月份|一年|一月|一天|年|月|日|天)' + \
#                self.get_unit_word_pre_rule() + \
#                self.get_adj_word_rule()
#         #         print rule
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)
#         if match is not None:
#             self.label = self.Label.WHEN
#             return True

    # # cc = CheckWhen(u'什麼年份發生法國大革命')
    # cc = CheckWhen(u'法國大革命發生年份是什麼')
    # if cc.check():
    #     print cc.label

# %% [markdown]
# # 詢問地點

# %%
class CheckWhere(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckWhere, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問地點:
        label: where
        句型：
        1.問單一地點
        2.(在何處|在何地|何地|何處|在哪裡|哪裡|在哪兒|哪兒|在哪|在那裡|那裡|在那兒|那兒|在那)
        3.通用疑問句+通用形容句+(地點|地方|國家|省分|城市|城鎮|{詞性為ns}))
        """
        self.label = ''
        self.target = ''
        
        #1
        cut_df = self.segmentor.pseg_lcut(input_text)
        if len(cut_df) == 1 and cut_df['tag'][0] in self.get_location_subject():
            self.label = self.Label.WHERE
            self.target = cut_df['word'][0]
            return True
        
        #2
        rule = u'(在何處|在何地|何地|何處|在哪裡|哪裡|在哪兒|哪兒|在哪|在那裡|那裡|在那兒|那兒|在那)'
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        if match is not None:
            for index, row in cut_df.iterrows():
                w = row['word']
                n = row['tag']
                if n.lower() in self.get_location_subject(): #or n.lower() in self.get_eng_subject():
                    self.label = self.Label.WHERE
                    self.target = w
                    return True

            self.label = self.Label.WHERE
            return True
        
        #3
        rule = self.get_unit_word_post_rule() + \
               self.get_adj_word_rule() + \
               u'(地點|地方|國家|省分|城市|城鎮)'
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        # print match
        if match is not None:
            self.label = self.Label.WHERE
            return True

#         rule = self.get_unit_word_post_rule() + u'(.*)'
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)

#         if match is not None:
# #             print match.group(1)
# #             print match.group(2)
# #             print match.group(3)

#             content = None
#             if match.group(2):
#                 content = match.group(2)

#             if match.group(3):
#                 content = match.group(3)

#             if content is not None:
#                 cut_df = self.segmentor.pseg_lcut(content)
#                 for index, row in cut_df.iterrows():
#                     w = row['word']
#                     n = row['tag']
#                     if n.lower() in self.get_location_subject():
#                         self.label = self.Label.WHERE
#                         self.target = w
#                         return True
#                     break

#         rule = u'(.*)' + self.get_unit_word_pre_rule()
#         #         print rule
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)

#         if match is not None:
#             #             print match.group(1)

#             content = None
#             if match.group(1):
#                 content = match.group(1)

#             if content is not None:
#                 cut = self.segmentor.pseg_lcut(content)
#                 for w, n in cut:
#                     #                     print w + ' (' + n + ')'

#                     if n.lower() in self.get_location_subject():
#                         self.label = self.Label.WHERE
#                         return True
#                     break
    
# cc = CheckWhere(segmentor)
# if cc.check(u'[問卦] 有沒有subway塑膠手套ㄉ8卦?'):
#     print cc.label+ ' ; ' + cc.target

# %% [markdown]
# # 詢問人

# %%
class CheckWho(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckWho, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問人:
        label: who
        句型：
        1.問單一人名
        2.(誰|哪位|那位)
        3.通用疑問句+通用形容句+(人)
        4.通用疑問句+通用形容句+{詞性為nr}
        5.{詞性為nr}+通用疑問句+通用形容句
        """
        self.label = ''
        self.target = ''
        
        #1
        cut_df = self.segmentor.pseg_lcut(input_text)
        print(cut_df)
        if len(cut_df) == 1 and cut_df['tag'][0] in self.get_people_subject():
            self.label = self.Label.WHO
            self.target = cut_df['word'][0]
            return True
        
        #2
        rule = u'(是誰|哪位|那位|什麼人|誰是)'
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        # print match
        if match is not None:
            for index, row in cut_df.iterrows():
                w = row['word']
                n = row['tag']
#                 print w
#                 print n
                if n.lower() in self.get_people_subject(): #or n.lower() in self.get_eng_subject():
                    self.label = self.Label.WHO
                    self.target = w
                    return True

            self.label = self.Label.WHO
            return True
        
#         #3
#         rule = self.get_unit_word_post_rule() + \
#                self.get_adj_word_rule() + \
#                u'(人)'
#         #         print rule
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)
#         # print match
#         if match is not None:
#             self.label = self.Label.WHO
#             return True
        
#         #4
#         rule = self.get_unit_word_post_rule() + u'(.*)'
#         print rule
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)

#         if match is not None:
#             #             print match.group(1)
#             #             print match.group(2)
#             #             print match.group(3)
#             content = None
#             if match.group(2):
#                 content = match.group(2)

#             if match.group(3):
#                 content = match.group(3)

#             if content is not None:
#                 cut_df = self.segmentor.pseg_lcut(content)
#                 for index, row in cut_df.iterrows():
#                     w = row['word']
#                     n = row['tag']
#                     print w
#                     print n
#                     if n.lower() in self.get_people_subject():
#                         self.label = self.Label.WHO
#                         self.target = w
#                         return True

#         #5
#         rule = u'(.*)' + self.get_unit_word_pre_rule()
#         #         print rule
#         pattern = re.compile(rule)
#         match = pattern.search(input_text)

#         if match is not None:
#             #             print match.group(1)

#             content = None
#             if match.group(1):
#                 content = match.group(1)

#             if content is not None:
#                 cut_df = self.segmentor.pseg_lcut(content)
#                 for index, row in cut_df.iterrows():
#                     w = row['word']
#                     n = row['tag']
#                     if n.lower() in self.get_people_subject():
#                         self.label = self.Label.WHO
#                         self.target = w
#                         return True
    
# cc = CheckWho(segmentor)
# if cc.check(u'[問卦] 科技業真的有那麼爽嗎?'):
#     print cc.label+ ' ; ' + cc.target

# %% [markdown]
# # 詢問一般事務

# %%
class CheckWhat(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckWhat, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問一般事務:
        label: what
        句型：
        1.單一個字{詞性為名詞}
        2.(什麼是|哪個是|那個是)+{詞性為名詞}
        3.{詞性為名詞}+(是什麼|是哪個|是那個)
        
        """
        self.label = ''
        self.target = ''
        
        #1
        cut_df = self.segmentor.pseg_lcut(input_text)
#         print cut_df
        if len(cut_df) == 1:
            n = cut_df['tag'][0]
#             print n
            if n.lower() in self.get_n_subject()or \
                n.lower() in self.get_eng_subject():
#                 print 'in'
                self.label = self.Label.WHAT
                self.target = cut_df['word'][0]
                return True
        
        #2
        rule = u'(什麼是|哪個是|那個是)(.*)'
        pattern = re.compile(rule)
        match = pattern.search(input_text)

        if match is not None:
#             print match.group(1)
#             print match.group(2)

            content = None
            if match.group(1):
                content = match.group(1)
            
            if match.group(2):
                content = match.group(2)

            if content is not None:
                cut_df = self.segmentor.pseg_lcut(content)
#                 print 'cut_df'
#                 print cut_df
                for index, row in cut_df.iterrows():
                    w = row['word']
                    n = row['tag']
#                     if n.lower() not in self.get_people_subject() and \
#                             n.lower() not in self.get_location_subject():
                    if n.lower() in self.get_n_subject() or \
                        n.lower() in self.get_eng_subject():
                        self.label = self.Label.WHAT
                        self.target = w
                        return True

        #3
        rule = u'(.*)(是什麼|是哪個|是那個)'
        #         print rule
        pattern = re.compile(rule)
        match = pattern.search(input_text)

        if match is not None:
            content = None
            if match.group(1):
                content = match.group(1)

            if content is not None:
                cut_df = self.segmentor.pseg_lcut(content)
                for index, row in cut_df.iterrows():
                    w = row['word']
                    n = row['tag']
#                     print w
#                     print n
#                     if n.lower() not in self.get_people_subject() and \
#                             n.lower() not in self.get_location_subject():
                    if n.lower() in self.get_n_subject() or \
                        n.lower() in self.get_eng_subject():
                        self.label = self.Label.WHAT
                        self.target = w
                        return True

# cc = CheckWhat(segmentor)
# if cc.check(u'發牢騷'):
#     print cc.label+ ' ; ' + cc.target

# %% [markdown]
# # 詢問動作

# %%
class CheckHow(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckHow, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問動作:
        label: how
        句型：
        1.(怎麼|怎樣|如何|教我|教導我|學|學會)+動詞
        """
        self.label = ''
        self.target = ''
        
        #1
        rule = u'(怎麼|怎樣|如何|教我|教導我|想學|學會)(.*)'
        pattern = re.compile(rule)
        match = pattern.search(input_text)

        if match is not None:
#             print match.group(1)
#             print match.group(2)

            content = match.group(2)
            if content is not None:
                cut_df = self.segmentor.pseg_lcut(content)
                for index, row in cut_df.iterrows():
                    w = row['word']
                    n = row['tag']
#                     print w
#                     print n
                    if n.lower() in self.get_v_subject():
                        self.label = self.Label.HOW
                        self.target = input_text
                        return True
                    break

# cc = CheckHow(segmentor)
# if cc.check(u'給大學生的建議'):
#     print cc.label+ ' ; ' + cc.target

# %% [markdown]
# # 詢問數字

# %%
class CheckHowMany(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckHowMany, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問數字:
        label: howmany
        句型：
        1.(多少|幾)
        """
        self.label = ''
        self.target = ''
        
        #1
        rule = u'(多少|幾)'
        pattern = re.compile(rule)
        match = pattern.search(input_text)
        #         print rule
        if match is not None:
            self.label = self.Label.HOW_MANY
            return True

# cc = CheckHowMany(u'老闆多少錢阿一個')
# if cc.check():
#     print cc.label

# %% [markdown]
# # 詢問狀態

# %%
class CheckStatus(CheckQuestion):

    def __init__(self, segmentor):
        super(CheckStatus, self).__init__()
        self.label = ''
        self.target = ''
        self.segmentor = segmentor

    def check(self, input_text):
        """
        詢問狀態:
        label: what status
        句型：
        1.多 + 形容詞
        """
        self.label = ''
        self.target = ''
        
        #1
        rule = u'(多)(.*)'
        pattern = re.compile(rule)
        match = pattern.search(input_text)

        if match is not None:
            #             print match.group(1)
            #             print match.group(2)
            content = match.group(2)
            if content is not None:
                cut_df = self.segmentor.pseg_lcut(content)
                for index, row in cut_df.iterrows():
                    w = row['word']
                    n = row['tag']
                    if n.lower() in self.get_adj_subject():
                        self.label = self.Label.STATUS
                        return True
                    break

# %% [markdown]
# # 詢問看法

# %%
class CheckFeel(CheckQuestion):
    def __init__(self, input_text):
        super(CheckFeel, self).__init__()
        self.label = ''
        self.target = ''
        self.input_text = input_text

    def check(self):  
        """
        詢問看法:
        label: feel
        句型：
        1.(感覺|看法|想法|意見|覺得)(呢|勒|類|嗎|如何|怎樣|怎麼樣)
        """
        
        self.label = ''
        self.target = '' 
        
        #1
        rule = u'(感覺|看法|想法|意見|覺得)(呢|勒|類|嗎|如何|怎樣|怎麼樣)'
        pattern = re.compile(rule)
        match = pattern.search(self.input_text)
#         print rule
        if match is not None:
            self.label = self.Label.FEEL
            return True
    
# cc = CheckFeel(u'各位酸民覺得呢')
# if cc.check():
#     print cc.label

# %% [markdown]
# # 其他

# %%
class CheckOther(CheckQuestion):

    def __init__(self):
        super(CheckOther, self).__init__()

    def check(self, input_text):
        self.label = 'other'
        self.target = ''
        return True

# %%
jieba_dict_path1 = "/home/charles/dataset/jieba/dict_taiwan.txt"
jieba_dict_path2 = "/home/charles/dataset/jieba/userdict.txt"
jieba_dict_path3 = "/home/charles/dataset/jieba/dict.txt.big"
jieba_dict_path4 = "/home/charles/dataset/jieba/dict.txt.small"
jieba_stopwords_path = "/home/charles/dataset/jieba/stopwords.txt"
segmentor = JiebaSegmentor(jieba_dict_path1, 
                           [jieba_dict_path2,jieba_dict_path3,jieba_dict_path4], 
                           stopwords = False, 
                           stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /home/charles/dataset/jieba/dict_taiwan.txt ...
# DEBUG:jieba:Building prefix dict from /home/charles/dataset/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u48306fa201322dcccc3d0c62898fbadc.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.u48306fa201322dcccc3d0c62898fbadc.cache
# Loading model cost 0.867 seconds.
# DEBUG:jieba:Loading model cost 0.867 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# /home/charles/dataset/jieba/userdict.txt
# /home/charles/dataset/jieba/dict.txt.big
# /home/charles/dataset/jieba/dict.txt.small

# %%
from functools import wraps
import regex as re

# %%
def cache(func):
    memo = {}

    @wraps(func)
    def _wrapper(*args):
        res = memo.get(args, None)
        if res is not None:
            print 'cache exist'
            return res
        else:
            res = func(*args)
            memo[args] = res
        return res
    return _wrapper

class WikiPedia:
    
    def __init__(self, lang='zh'):
        self.__lang = lang
   
    def set_lang(self, lang):
        self.__lang = lang

    def wiki_query_list(self, query, lang):
        """
        查詢wiki單字解釋與相關詞API
        """

        url = ("https://"+lang+".wikipedia.org/w/api.php?action=opensearch&search="+query+"&utf8")    
        response = requests.post(url)
        if response.status_code == requests.codes.ok:
            result = response.json()
        #     print result[0]
            if len(result[2]) == 0:
                return None

            content = result[2][0]
            if content == u"" or u"重定向" in content:  
                print 'redirect'
                return None

            return content
        
    def wiki_query_snippet(self, query, lang):
    
        def query_api(query_str, lang):
            
            search_list = []
            url = ("https://"+lang+".wikipedia.org/w/api.php?action=query&list=search&srsearch="+
                    query_str+"&format=json&formatversion=2")    
            response = requests.post(url)
            if response.status_code == requests.codes.ok:

                result = response.json()
                if "query" in result:
                    if "search" in result["query"]:
                        search_list = result["query"]["search"]

            return search_list

        search_list = query_api(query, lang)
        if search_list:

            if search_list[0].has_key("title"):
                title = search_list[0]["title"]
                search_list = query_api(title, lang)  
                if search_list:
                    if search_list[0].has_key("snippet") and\
                        search_list[0]["snippet"]:

                        snippet = search_list[0]["snippet"]
                        snippet = snippet.split(u'。')[0]
                        snippet = re.sub(r'</?\w+[^>]*>','',snippet)+u'。'
                        return snippet
        return None
    
    @cache
    def summery(self, query):
        """
        查詢wiki API
        1.查詢wiki單字解釋與相關詞API
        2.查詢wiki單字解釋片段API
        都以中文wiki百科查詢, 當出現重定向(縮寫或只有簡體文章時發生), 改由查詢wiki單字解釋片段API
        wiki單字解釋片段API的答案不完整, 所以不考慮一開始就呼叫
        爲了提高英文單字準確性, 會使用wiki單字解釋片段API查出的title再當單字查詢一次
        """

        def check_contain_chinese(query):

            for ch in query:
                if u'\u4e00' <= ch <= u'\u9fff':
                    return True
            return False

        if not query:
            return None

        if type(query) is not unicode:
            query = query.decode('utf-8')

    #     if check_contain_chinese(query):
    #         lang = 'zh'
    #     else:
    #         lang = 'en'

        lang = 'zh'

        print 'wiki query : ' + query
        for result in [self.wiki_query_list(query, lang), 
                       self.wiki_query_snippet(query, lang)]:
            if result:
                return result
        return None

# %%
from collections import namedtuple
class QuestionTypeCheck:

    def __init__(self, segmentor, source='user'):
        self.segmentor = segmentor
        self.source = source
        self.check_pipeline = [CheckWhy(self.segmentor),
                              CheckWhen(self.segmentor),
                              CheckWhere(self.segmentor),
                              CheckWho(self.segmentor),
                              CheckHow(self.segmentor),
                              CheckHowMany(self.segmentor),
                              CheckStatus(self.segmentor),
                              CheckWhat(self.segmentor)]
        #                       CheckFeel(self.segmentor)]

    QuestionTypeTuple = namedtuple('QuestionTypeTuple', {
                                    'label',
                                    'target',
                                })    
    
    @property
    def source(self):
        return self.source

    @source.setter
    def source(self, source):
        self.source = source
    
    def check_question_type(self, input_text):
        """
        [ Command ] design pattern
        """ 
        if type(input_text) is not unicode:
            input_text = input_text.decode('utf-8')
        
#         print input_text
        if self.source == 'ptt':
            # ptt text clean
            input_text = input_text.replace(u'Re: ', u'')
            input_text = re.sub(u"\\[.*?]", u"", input_text)
        elif self.source == 'dcard':
            input_text = re.sub(u"\\(.*?\\)|\\{.*?}|\\[.*?]|\\（.*?）|\\【.*?】|\\#.*? |\\#.*?#", "", input_text)
              
        label = ''
        target = ''

        # 有被標注到就不往下做
        for cmd in self.check_pipeline:
            if cmd.check(input_text):
                label = cmd.label
                target = cmd.target
                break

        if label == '':
            cmd = CheckOther()
            cmd.check(input_text)
            label = cmd.label
        
        qt = self.QuestionTypeTuple(label=label,
                                   target=target)
        
#         print 'label = ' + qt.label
#         print 'target = ' + qt.target
#         if qt.label in ['what', 'where', 'who']:
#             wp = WikiPedia()
#             print wp.summery(qt.target)
#         elif qt.label in ['how']:
#             # google整句丟入
#             google_search(qt.target)
        return qt

# %%
def google_search(query):
    
    if not query:
        return None
    
    if type(query) is not unicode:
        query = query.decode('utf-8')
        
    print 'google query : ' + query
        
    # Google 搜尋 URL
    google_url = 'https://www.google.com.tw/search'

    # 查詢參數
    my_params = {'q': query, 'lr':'lang_zh-TW'}

    # 下載 Google 搜尋結果
    r = requests.get(google_url, params = my_params)

    # 確認是否下載成功
    if r.status_code == requests.codes.ok:
      # 以 BeautifulSoup 解析 HTML 原始碼
      soup = BeautifulSoup(r.text, 'html.parser')

      # 觀察 HTML 原始碼
      # print(soup.prettify())

      # 以 CSS 的選擇器來抓取 Google 的搜尋結果
      items = soup.select('div.g > h3.r > a[href^="/url"]')
      for i in items[:5]:
        # 標題
        print(u"標題：" + i.text)
        # 網址
        print(u"網址：" + i.get('href').lstrip('/url?q='))

# %%
check = QuestionTypeCheck(segmentor)
check.source = 'dcard'

# %%
check.check_question_type(u'Re: [新聞]黃之瀚提美台')
# Out:
#    tag word
# 0  eng   Re
# 1    x    :
# 2    x
# 3   nr  黃之瀚
# 4    v    提
# 5    n   美台
# QuestionTypeTuple(target='', label='other')

# %%
check.check_question_type(u'老闆這袋子西瓜有幾顆')
# Out:
#   tag word
# 0   n   老闆
# 1  zg    這
# 2   n   袋子
# 3  ns   西瓜
# 4   v    有
# 5   m   幾顆
# QuestionTypeTuple(target='', label='how_many')

# %%
check.check_question_type(u'北京在哪')
# Out:
# QuestionTypeTuple(target=u'\u5317\u4eac', label='where')

# %%
check.check_question_type(u'蘇貞昌')
# Out:
#   tag word
# 0  nr  蘇貞昌
# QuestionTypeTuple(target=u'\u8607\u8c9e\u660c', label='who')

# %%
check.check_question_type(u'哪個西瓜這麼大一顆')
# error......
# Out:
#   tag word
# 0   r   哪個
# 1  ns   西瓜
# 2   r   這麼
# 3   a    大
# 4   m   一顆
# QuestionTypeTuple(target='', label='other')

# %%
check.check_question_type(u'馬英九')
# Out:
#   tag word
# 0  nr  馬英九
# QuestionTypeTuple(target=u'\u99ac\u82f1\u4e5d', label='who')

# %%
check.check_question_type(u'關於封鎖')
# Out:
#   tag word
# 0   p   關於
# 1  nr   封鎖
# QuestionTypeTuple(target='', label='other')

# %%
check.check_question_type(u'老闆這個水果多少錢呢')
# Out:
#   tag word
# 0   n   老闆
# 1   r   這個
# 2   n   水果
# 3  nr  多少錢
# 4   y    呢
# QuestionTypeTuple(target='', label='how_many')

# %%
check.check_question_type(u'老闆這個水果多高')
# Out:
#   tag word
# 0   n   老闆
# 1   r   這個
# 2   n   水果
# 3   m    多
# 4   a    高
# QuestionTypeTuple(target='', label='status')

# %%
check.check_question_type(u'姚明身高有多高呢')
# Out:
#   tag word
# 0  nr   姚明
# 1   v   身高
# 2   v    有
# 3   m    多
# 4   a    高
# 5   y    呢
# QuestionTypeTuple(target='', label='status')

# %%
check.check_question_type(u'林百里是哪位')
# Out:
#   tag word
# 0  nr  林百里
# 1   v    是
# 2   r   哪位
# QuestionTypeTuple(target=u'\u6797\u767e\u91cc', label='who')

# %%
check.check_question_type(u'請問apple是什麼')
# Out:
# QuestionTypeTuple(target=u'apple', label='what')

# %%
check.check_question_type(u'[問卦] 有沒有subway塑膠手套ㄉ8卦?')
# Out:
# QuestionTypeTuple(target='', label='other')

# %%
check.check_question_type(u'我想學游泳')
# Out:
# QuestionTypeTuple(target=u'\u6211\u60f3\u5b78\u6e38\u6cf3', label='how')

# %%
check.check_question_type(u'連勝文')
# Out:
# QuestionTypeTuple(target=u'\u9023\u52dd\u6587', label='who')

# %%
check.check_question_type('給大學生的建議')
# Out:
# QuestionTypeTuple(target='', label='other')

# %%
# ppp

# %% [markdown]
# # question type setting

# %%
dao = CassandraDAO('BACKUP')
HELPER_KEYSPACE = 'nlp_keyspace'
DCARD_ARTICLE_TABLE = 'dcard_article'
DCARD_ARTICLE_TEST_TABLE = 'dcard_article_test'
# Out:
# contact_points = 192.168.0.121,192.168.0.122,192.168.0.52

# %%
cql = 'select * from ' + DCARD_ARTICLE_TEST_TABLE + ';'
## select range
# cql = ("select * from nlp_keyspace.dcard_article_test " +
#         "where article_id > 225705809 and article_id < 225800010 allow filtering;")
pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
pd_df

# %%
def set_question_type(row):
    title = row['question']
    qt = check.check_question_type(title)
    return qt.label

pd_df['question_type'] = pd_df.apply(set_question_type, axis=1)
pd_df
# Out:
# /home/charles/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       article_id     board category  \
# 0      224297810       job     None
# 1      225961291      talk     None
# 2      225196435      food     None
# 3      224746504      talk     None
# 4      230071785  trending     None
# 5      226029225      food     None
# 6      226491861      food     None
# 7      229830476  language     None
# 8         465696      talk     None
# 9      230081344  trending     None
# 10     229701427  trending     None
# 11     226818276       job     None
# 12     229913803  trending     None
# 13     224705473      talk     None
# 14     225785190      talk     None
# 15        705433  trending     None
# 16        931773      talk     None
# 17     230108386  trending     None
# 18        615257      talk     None
# 19        828092      talk     None
# 20       1100562      talk     None
# 21         15001      talk     None
# 22        945614      talk     None
# 23     227335554       job     None
# 24     228116329  trending     None
# 25     224456408      food     None
# 26     225072351      food     None
# 27     228229118     money     None
# 28        201564  trending     None
# 29     224975193      food     None
# ...          ...       ...      ...
# 4969   225859506      food     None
# 4970   224361221       job     None
# 4971   227605710  trending     None
# 4972   225111246      talk     None
# 4973   230597841       job     None
# 4974       12994      talk     None
# 4975   224927759       job     None
# 4976   226774810       job     None
# 4977   230690056               None
# 4978   227160106      food     None
# 4979     1164550      food     None
# 4980      904590  trending     None
# 4981      531910      talk     None
# 4982   224572991  trending     None
# 4983      478123      food     None
# 4985   230509589     money     None
# 4986   226627408  trending     None
# 4987   228300438       job     None
# 4988   226716289       job     None
# 4989      188096      talk     None
# 4990   224985811       job     None
# 4991      934979      talk     None
# 4992      970946      talk     None
# 4993      237466      food     None
# 4994    10787073      talk     None
# 4995     1038314      talk     None
# 4996   230119161  trending     None
# 4997   226062599       job     None
# 4998   229656402       job     None
# 4999      122041  trending     None
#
#                                                 content  \
# 0                   想請問在健身房的工作內容有什麼呢需要做什麼 還是要會什麼技能櫃檯/教練
# 1     首次發文，手機排版，請見諒（跟朋友借的帳號）首先，刺青是一門藝術並不是每個刺青的人都是屁孩 ...
# 2
# 3     各種淡紫控啊~覺得淡紫超美的～～😘還在繼續搜集中～(燈光比較不好，淡紫色沒有很明顯…😭)－愛...
# 4     剛剛看到謝和炫出的這首歌，聽完簡直感動的說不出話來....台北年輕人這次一定要出來投票衝高投...
# 5     不知道有沒有人記得前幾天的單身狗廚房肉篇XD這次小廚跟朋友一行人去南投的某茶園露營(不透漏確...
# 6     想跟大家分享這間超好吃的日本料理店！他位於現在很多人要去的小琉球的乘船處----東港！我個人...
# 7                           請問第三句 那個「となり 」是翻成登山「時」的意思嗎？
# 8     ㄜ 因為突然想到很想知道，雖然感覺這樣問有點奇怪= =前幾個星期有看到新聞在介紹，有個女生之...
# 9     本人台中人從小有嚴重過敏體質，鼻子容易塞住，也很容易流鼻水，更容易狂打噴嚏，成年之後狀況已經...
# 10    http://www.ntdtv.com/xtr/b5/2018/09/21/a139241...
# 11    請問各位有些公司的隨身碟使用都有限定非公司的隨身碟不能用於公司電腦否則會有違反營業秘密的疑慮...
# 12    台鐵事件這幾天風向亂糟糟，終於在今天有道強風吹起了，誰沒穿褲子，我一看就知道。在今天中午12...
# 13    以前小時候就很常撕作業本一個國字寫錯重寫後覺得醜就撕數學公式（橫線）寫歪了我也撕而且都撕整頁...
# 14    昨天跟朋友在廣三逛到Owndays當場看覺得價錢透明無論度數都是不加價配到好而且最快20分鐘...
# 15    台聯與時代力量的政黨門檻５％之爭，讓台北市長柯文哲打破自己上班日不輔選的宣示！面臨立院席次保...
# 16    晚上跟男友到烏日的大X鐵板燒吃飯 門口布條上大大的週年慶85折6點快半的巔峰時刻店裡卻是半個...
# 17    韓粉最愛說的高雄負債3000億，5000天坑，韓導選上後會去查民進黨弊案請問韓導本人啥時有說...
# 18    想問大家有沒有甚麼管道可以上網投稿(雜誌/報紙)?最好有信箱&投稿條件找了一陣子沒有適合的非...
# 19    前幾天有學妹問我說如果再讓你回到大學你最想做的事情是什麼?存錢。其實我不是很喜歡買衣服，也不...
# 20    很多男生睡覺都會打呼,那如果遇上會打呼的女生,男生的看法是甚麼呢???想知道男生對會打呼的女...
# 21    都說認真的女人最美麗，認真的男人最帥氣感覺上會樂器會唱歌或是會跳舞都是很綻放光芒的才藝吧大家...
# 22    先說台鋁在高雄哦它原本是多個廢棄的貨櫃後來改造成台鋁生活圈接近夢時代，還有前鎮的好事多的附近...
# 23    爬過文章真的少之又少，想請問正職的工作內容有哪些，有個人業績壓力之類的嗎?薪水大概落在哪裡，謝謝。
# 24    https://news.tvbs.com.tw/local/851855其實我今天不是來檢...
# 25         本人是愛吃海鮮主義者，雖然吃多會過敏但海鮮魅力還是無法擋!!!!!!!!!有同好嗎哈哈哈
# 26
# 27    我最開始是在工作那邊發文，詢問趕時間開薪資戶說明一下整件事公司匯薪水是使用中信，但是我沒戶頭...
# 28    前中研院長李遠哲今（16）日表示，2015年是關鍵的一年，今年如果不努力的話，會對不起我們下...
# 29
# ...                                                 ...
# 4969  前幾天看到有人po義美的巧克力球就想到最近讓自己忍不住嘴饞的點心沒錯就是這個！！！這樣一盒2...
# 4970  餐飲服務業 照理說不能帶寵物店裡一位比我早一週進店的大姐卻整天帶著寵物上下班跟她都是站外場 ...
# 4971  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權http://www.upmed...
# 4972  不知道大家知不知道其實jolin的翻糖蛋糕並不是她做的，而是團隊製作，她只負責創意發想老實說...
# 4973  不希望被說是伸手，我真的有從網路上搜尋他的公司，真的沒什麼資訊。請問大大們有人知道嗎？最近新...
# 4974  鄭振和 Jenher Jeng 粉絲頁https://www.facebook.com/je...
# 4975  距離第一次入取，已經工作1個月多了結果第一次發薪水後，覺得頗怪怎麼沒有扣掉勞健保的部分負擔?...
# 4976  今天剛投履歷 晚上就接到面試通知請問有人做過可以分享工作經驗或是面試會有什麼考試或考核嗎需要...
# 4977  大家最關心經濟問題，我只講經濟好了首先當初拼命吹噓一帶一路的，看到中國因中美貿易被電得慘兮兮...
# 4978  每天挑戰聽歌辨名 成功可獲得百威啤酒總共可以挑戰3次 要用代碼到ibon兌換活動期間:201...
# 4979  對於馬鈴薯狂熱者來說最，基本的烹調方式非起司馬鈴薯莫屬，雖然作法簡易，調味也算不上精緻，但我...
# 4980  1：廣東深圳廢土堆崩瀉，推倒幾十座樓房，七十幾人失蹤2：土耳其庫爾德人抗議軍方持續攻擊，造成...
# 4981  因為當初近第一間學校的時候系上要求我們一次繳4000元的系會費((4年繳清))在那間學校經過...
# 4982  1.弱弱相保不是早就知道的事？現在才感覺到嗎？2.勞務折抵保費不知道哪個天才山頂洞人的學者還...
# 4983  第16篇：濃湯/雙主餐/甜點嗨，歡迎來到我的廚房！今天是豪華料理日🎉難得的海陸大餐！採取小份...
# 4985  之前刷卡時五分鐘之內消費紀錄就到App內了但我星期日刷了兩筆都還沒記到前兩天繳上個月的信用卡...
# 4986  最近這幾年「出走」這個詞時常在新聞上看到像是甚麼企業、員工不排除出走等等和朋友討論這件事時他...
# 4987  小弟我今天被通知入取電機設備工程師，待遇31500，想請問一下有沒有人待過這間公司，在裡面工...
# 4988  最近畢業到處投履歷面試，有兩個工作可以選，很難抉擇。A離家近，是計時人員，薪水要看做多久，做...
# 4989  ｡･ﾟ･(ﾉД`)･ﾟ･｡我有分類障礙(?!)-----------------------...
# 4990  文長慎入如題昨天上班的時候遇到一位客人他"自己"打翻了一杯黑咖啡幫他整理完後 他說了一句話客...
# 4991  有沒有一種情況當你坐在位子上，有個女孩子需要經過你這裡時，你把椅子往前移讓她方便過去但她卻看...
# 4992  想不到癢詢我有毅力發到第五篇wwwww一個人當清流很辛苦的，有時候也會感到無助，但是要堅持下...
# 4993         作法不難，材料有三樣。第一、吉利丁粉。第二、水和高果糖漿。第三、Amazon的模具。
# 4994  身為一個因為過敏所以常常鼻子裡充滿鼻涕的女子真的很苦惱，也想告訴大家不是每個女生都是睡美人好...
# 4995  每次去早餐店or吃宵夜…對方總是會很親切地對每個人說帥哥即便當下只有我一個男的(還是會lag...
# 4996  相信大家自己有眼睛圖片來源：https://m.facebook.com/story.php...
# 4997  首po, 手機排版，請見諒......更新:對於許多善意勸說與指責，先說聲謝謝，但在這邊我要...
# 4998  我是一個小小人資從面試邀約到新人進入公司帶新人除了決定是否錄取以外 基本都由我在處理（是否錄...
# 4999  門診護理師定義：在醫院或診所按燈叫號且擁有國家護理師執照的人http://www.ettod...
#
#                   crawl_date               create_date  \
# 0    2019-02-15 07:49:24.035  2016-07-03T16:51:05.200Z
# 1    2019-02-19 08:25:10.219  2017-03-11T09:36:15.788Z
# 2    2019-02-13 01:39:36.743  2016-11-15T03:16:45.628Z
# 3    2019-02-19 06:09:49.412  2016-09-12T14:33:05.434Z
# 4    2019-02-15 02:46:30.961  2018-11-15T19:22:07.846Z
# 5    2019-02-13 03:28:19.805  2017-03-22T04:04:36.302Z
# 6    2019-02-13 03:54:05.395  2017-05-28T16:40:26.874Z
# 7    2019-02-15 07:05:51.092  2018-10-11T12:06:50.282Z
# 8    2019-02-18 06:33:17.498  2015-08-17T13:33:21.449Z
# 9    2019-02-15 02:47:31.216  2018-11-17T11:02:23.407Z
# 10   2019-02-15 00:49:43.456  2018-09-21T17:36:30.998Z
# 11   2019-02-15 08:58:38.437  2017-07-17T01:59:42.390Z
# 12   2019-02-15 01:02:43.671  2018-10-24T08:24:42.097Z
# 13   2019-02-19 06:02:56.025  2016-09-06T13:15:01.752Z
# 14   2019-02-19 08:18:01.166  2017-02-11T13:25:45.068Z
# 15   2019-02-14 03:18:09.273  2015-10-29T13:30:27.164Z
# 16   2019-02-19 02:37:36.089  2015-12-30T11:32:01.871Z
# 17   2019-02-15 02:54:34.513  2018-11-21T08:44:59.181Z
# 18   2019-02-19 01:30:10.446  2015-10-02T15:06:59.228Z
# 19   2019-02-19 02:29:57.684  2015-12-01T07:34:51.240Z
# 20   2019-02-19 03:02:53.777  2016-02-11T10:50:30.259Z
# 21   2019-02-18 03:32:33.856  2014-01-18T17:36:34.000Z
# 22   2019-02-19 02:45:01.815  2016-01-03T09:57:33.917Z
# 23   2019-02-18 01:05:34.354  2017-09-25T19:08:21.686Z
# 24   2019-02-14 09:05:54.903  2018-01-13T05:26:25.993Z
# 25   2019-02-12 08:39:36.194  2016-07-30T13:24:36.408Z
# 26   2019-02-13 01:14:03.189  2016-10-27T15:22:25.050Z
# 27   2019-02-15 05:15:37.809  2018-02-01T09:19:16.252Z
# 28   2019-02-14 02:34:52.743  2015-05-16T15:44:00.995Z
# 29   2019-02-13 00:43:43.113  2016-10-14T09:31:33.331Z
# ...                      ...                       ...
# 4969 2019-02-13 03:18:28.551  2017-02-23T02:17:13.793Z
# 4970 2019-02-15 07:50:26.851  2016-07-15T05:52:04.891Z
# 4971 2019-02-14 08:52:45.507  2017-11-01T15:23:10.786Z
# 4972 2019-02-19 08:01:05.280  2016-11-02T11:25:02.522Z
# 4973 2019-02-18 02:46:20.694  2019-01-30T04:32:48.600Z
# 4974 2019-02-18 03:24:33.024  2013-11-02T17:27:25.000Z
# 4975 2019-02-15 08:13:22.823  2016-10-08T05:34:54.300Z
# 4976 2019-02-15 08:56:01.156  2017-07-09T12:43:11.116Z
# 4977 2019-02-15 03:50:28.140  2019-02-14T15:44:26.517Z
# 4978 2019-02-13 05:02:17.979  2017-09-03T21:46:44.431Z
# 4979 2019-02-12 07:38:41.375  2016-02-24T16:55:54.737Z
# 4980 2019-02-14 03:35:27.652  2015-12-22T15:24:59.158Z
# 4981 2019-02-19 01:22:50.246  2015-09-06T06:41:46.326Z
# 4982 2019-02-14 07:35:37.218  2016-08-19T02:47:22.806Z
# 4983 2019-02-12 06:13:48.200  2015-08-21T14:52:57.733Z
# 4985 2019-02-15 05:29:30.066  2019-01-15T15:01:01.215Z
# 4986 2019-02-14 08:26:38.253  2017-06-16T18:16:49.441Z
# 4987 2019-02-18 01:27:32.032  2018-02-14T11:04:44.372Z
# 4988 2019-02-15 08:56:35.519  2017-06-30T08:44:13.968Z
# 4989 2019-02-18 06:04:30.327  2015-05-11T08:19:02.007Z
# 4990 2019-02-15 08:14:08.061  2016-10-15T16:37:08.332Z
# 4991 2019-02-19 02:36:52.897  2015-12-31T08:03:02.092Z
# 4992 2019-02-19 02:47:51.209  2016-01-09T14:07:54.409Z
# 4993 2019-02-12 06:05:39.991  2015-05-28T07:51:10.392Z
# 4994 2019-02-19 03:30:24.093  2016-03-12T16:17:34.285Z
# 4995 2019-02-19 02:52:02.584  2016-01-27T04:41:56.070Z
# 4996 2019-02-15 02:56:00.779  2018-11-22T17:10:20.110Z
# 4997 2019-02-15 08:27:42.791  2017-03-27T08:28:44.935Z
# 4998 2019-02-18 02:04:29.894  2018-09-15T17:02:31.710Z
# 4999 2019-02-14 02:33:22.598  2015-04-01T07:55:52.844Z
#
#                                  question question_target question_type  \
# 0                                 健身房工作經驗            None         other
# 1                                   刺青的意義            None         other
# 2                                    蜂蜜真假            None         other
# 3                                  愛各種淡紫色            None         other
# 4                             台灣的未來交給柯文哲！            None         other
# 5                             單身狗廚房x野外露營篇            None         other
# 6                                龍允日式手作壽司            None         other
# 7                                  日文翻譯問題            None         other
# 8                  尋~一個卡片遊戲 給背包客專用 (電視上看到            None         other
# 9                                 我不想吸髒空氣            None         other
# 10                  金正恩「羞辱」中國人   牽出中共賣國秘密            None         other
# 11                              關於公司隨身碟使用            None         other
# 12                               揭穿台鐵避重就輕            None         other
# 13                           有一種強迫症叫做：嫌字醜            None         other
# 14                        有人在Owndays配鏡過嗎?            None         other
# 15                被台聯設計」，柯文哲與李登輝私下會面變輔選行程            None         other
# 16                                 雷雷a鐵板燒            None         other
# 17                               有關高雄負債問題            None         other
# 18                                文章投稿管道?            None         other
# 19                               給大學生的建議             None         other
# 20                              ㄍㄡˊㄍㄡˊㄍㄡˊ            None         other
# 21                            什麼樣的才華最吸引人？            None         other
# 22                                台鋁MLD影城            None         other
# 23                                 關於三友藥妝            None         other
# 24                           台南男大生9日晚間遭撞死            None         other
# 25                               有人喜歡吃海鮮嗎            None         other
# 26                                  麥當勞報報            None         other
# 27                                   中信開戶            None         other
# 28                  李遠哲鼓勵青年：勿信50年後不在地球上的人            None         other
# 29                              奶茶超好喝的OAO            None         other
# ...                                   ...             ...           ...
# 4969                               森永巧克力球            None         other
# 4970                               餐飲店養寵物            None         other
# 4971  ＃新聞  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權            None         other
# 4972                       關於 jolin 的翻糖蛋糕            None         other
# 4973                        憲哥 吸塵器面試1500人            None         other
# 4974                               科學家鄭振和            None         other
# 4975                      根本扼殺在醫院工作的年輕人！！            None         other
# 4976                         日月光  科技廠櫃檯秘書            None         other
# 4977                       台灣經濟事實上是不斷進步的!            None         other
# 4978                               免費百威啤酒            None         other
# 4979                             焗烤起司馬鈴薯泥            None         other
# 4980                                   時事            None          what
# 4981                    轉學可以要回之前繳的4年系會費嗎?            None         other
# 4982                           國民年金不到六成繳費            None         other
# 4983                               豪華海陸饗宴            None         other
# 4985                       Richart消費動態不更新            None         other
# 4986                             有本事早就出去了            None         other
# 4987                            榮成紙業 工作如何            None         other
# 4988                           工作選擇，急，在線等            None         other
# 4989                          「腦內革命，友善大腦」            None         other
# 4990                           太不要臉了吧這位客人            None         other
# 4991                            你是覺得我很胖喔？            None         other
# 4992                              統神語錄第五篇            None         other
# 4993                       可以吃的樂高玩具，影片分享。            None         other
# 4994                                  睡美人            None          what
# 4995                            只有飲食業對人最好            None         other
# 4996                         到底是誰在用政治干涉體育            None           who
# 4997                    全家系統讓我幫客人付了680元帳單            None         other
# 4998                           關於“面試”這件事情            None         other
# 4999                             過號就讓他等啊!            None         other
#
#                                     title
# 0                              健身房工作經驗（問）
# 1                                #圖 刺青的意義
# 2                                    蜂蜜真假
# 3                                  愛各種淡紫色
# 4                             台灣的未來交給柯文哲！
# 5                          #圖 單身狗廚房x野外露營篇
# 6                        #食記 #東港 龍允日式手作壽司
# 7                                  日文翻譯問題
# 8               尋~一個卡片遊戲(?) 給背包客專用 (電視上看到
# 9                                 我不想吸髒空氣
# 10                  金正恩「羞辱」中國人   牽出中共賣國秘密
# 11                              關於公司隨身碟使用
# 12                               揭穿台鐵避重就輕
# 13                           有一種強迫症叫做：嫌字醜
# 14                     #問 有人在Owndays配鏡過嗎?
# 15                被台聯設計」，柯文哲與李登輝私下會面變輔選行程
# 16                             (黑特)雷雷a鐵板燒
# 17                               有關高雄負債問題
# 18                                文章投稿管道?
# 19                           給大學生的建議 (更新)
# 20                              ㄍㄡˊㄍㄡˊㄍㄡˊ
# 21                        【閒聊】什麼樣的才華最吸引人？
# 22                                台鋁MLD影城
# 23                                 關於三友藥妝
# 24                     #社會新聞 台南男大生9日晚間遭撞死
# 25                               有人喜歡吃海鮮嗎
# 26                               #更 麥當勞報報
# 27                               #分享#中信開戶
# 28                  李遠哲鼓勵青年：勿信50年後不在地球上的人
# 29                              奶茶超好喝的OAO
# ...                                   ...
# 4969                               森永巧克力球
# 4970                               餐飲店養寵物
# 4971  ＃新聞  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權
# 4972                       關於 jolin 的翻糖蛋糕
# 4973                        憲哥 吸塵器面試1500人
# 4974                           【閒聊】科學家鄭振和
# 4975                      根本扼殺在醫院工作的年輕人！！
# 4976                      #問 日月光  科技廠櫃檯秘書
# 4977                    [轉]台灣經濟事實上是不斷進步的!
# 4978                           #情報 免費百威啤酒
# 4979                    【小食光🐽】#圖#焗烤起司馬鈴薯泥
# 4980                                   時事
# 4981                    轉學可以要回之前繳的4年系會費嗎?
# 4982                           國民年金不到六成繳費
# 4983                         [美食生活]豪華海陸饗宴
# 4985                    #問 Richart消費動態不更新
# 4986                        #討論  有本事早就出去了
# 4987                            榮成紙業 工作如何
# 4988                           工作選擇，急，在線等
# 4989                  【推廣(?)】 「腦內革命，友善大腦」
# 4990                           太不要臉了吧這位客人
# 4991                            你是覺得我很胖喔？
# 4992                【鋼筆隨寫小作業 歡迎跟抄】統神語錄第五篇
# 4993                       可以吃的樂高玩具，影片分享。
# 4994                                  睡美人
# 4995                            只有飲食業對人最好
# 4996                         到底是誰在用政治干涉體育
# 4997                 #更#全家系統讓我幫客人付了680元帳單
# 4998                           關於“面試”這件事情
# 4999                             過號就讓他等啊!
#
# [4990 rows x 10 columns]

# %%
def set_question_target(row):
    qt = check.check_question_type(row['question'])
    return qt.target

pd_df['question_target'] = pd_df.apply(set_question_target, axis=1)
pd_df
# Out:
# /home/charles/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       article_id     board category  \
# 0      224297810       job     None
# 1      225961291      talk     None
# 2      225196435      food     None
# 3      224746504      talk     None
# 4      230071785  trending     None
# 5      226029225      food     None
# 6      226491861      food     None
# 7      229830476  language     None
# 8         465696      talk     None
# 9      230081344  trending     None
# 10     229701427  trending     None
# 11     226818276       job     None
# 12     229913803  trending     None
# 13     224705473      talk     None
# 14     225785190      talk     None
# 15        705433  trending     None
# 16        931773      talk     None
# 17     230108386  trending     None
# 18        615257      talk     None
# 19        828092      talk     None
# 20       1100562      talk     None
# 21         15001      talk     None
# 22        945614      talk     None
# 23     227335554       job     None
# 24     228116329  trending     None
# 25     224456408      food     None
# 26     225072351      food     None
# 27     228229118     money     None
# 28        201564  trending     None
# 29     224975193      food     None
# ...          ...       ...      ...
# 4969   225859506      food     None
# 4970   224361221       job     None
# 4971   227605710  trending     None
# 4972   225111246      talk     None
# 4973   230597841       job     None
# 4974       12994      talk     None
# 4975   224927759       job     None
# 4976   226774810       job     None
# 4977   230690056               None
# 4978   227160106      food     None
# 4979     1164550      food     None
# 4980      904590  trending     None
# 4981      531910      talk     None
# 4982   224572991  trending     None
# 4983      478123      food     None
# 4985   230509589     money     None
# 4986   226627408  trending     None
# 4987   228300438       job     None
# 4988   226716289       job     None
# 4989      188096      talk     None
# 4990   224985811       job     None
# 4991      934979      talk     None
# 4992      970946      talk     None
# 4993      237466      food     None
# 4994    10787073      talk     None
# 4995     1038314      talk     None
# 4996   230119161  trending     None
# 4997   226062599       job     None
# 4998   229656402       job     None
# 4999      122041  trending     None
#
#                                                 content  \
# 0                   想請問在健身房的工作內容有什麼呢需要做什麼 還是要會什麼技能櫃檯/教練
# 1     首次發文，手機排版，請見諒（跟朋友借的帳號）首先，刺青是一門藝術並不是每個刺青的人都是屁孩 ...
# 2
# 3     各種淡紫控啊~覺得淡紫超美的～～😘還在繼續搜集中～(燈光比較不好，淡紫色沒有很明顯…😭)－愛...
# 4     剛剛看到謝和炫出的這首歌，聽完簡直感動的說不出話來....台北年輕人這次一定要出來投票衝高投...
# 5     不知道有沒有人記得前幾天的單身狗廚房肉篇XD這次小廚跟朋友一行人去南投的某茶園露營(不透漏確...
# 6     想跟大家分享這間超好吃的日本料理店！他位於現在很多人要去的小琉球的乘船處----東港！我個人...
# 7                           請問第三句 那個「となり 」是翻成登山「時」的意思嗎？
# 8     ㄜ 因為突然想到很想知道，雖然感覺這樣問有點奇怪= =前幾個星期有看到新聞在介紹，有個女生之...
# 9     本人台中人從小有嚴重過敏體質，鼻子容易塞住，也很容易流鼻水，更容易狂打噴嚏，成年之後狀況已經...
# 10    http://www.ntdtv.com/xtr/b5/2018/09/21/a139241...
# 11    請問各位有些公司的隨身碟使用都有限定非公司的隨身碟不能用於公司電腦否則會有違反營業秘密的疑慮...
# 12    台鐵事件這幾天風向亂糟糟，終於在今天有道強風吹起了，誰沒穿褲子，我一看就知道。在今天中午12...
# 13    以前小時候就很常撕作業本一個國字寫錯重寫後覺得醜就撕數學公式（橫線）寫歪了我也撕而且都撕整頁...
# 14    昨天跟朋友在廣三逛到Owndays當場看覺得價錢透明無論度數都是不加價配到好而且最快20分鐘...
# 15    台聯與時代力量的政黨門檻５％之爭，讓台北市長柯文哲打破自己上班日不輔選的宣示！面臨立院席次保...
# 16    晚上跟男友到烏日的大X鐵板燒吃飯 門口布條上大大的週年慶85折6點快半的巔峰時刻店裡卻是半個...
# 17    韓粉最愛說的高雄負債3000億，5000天坑，韓導選上後會去查民進黨弊案請問韓導本人啥時有說...
# 18    想問大家有沒有甚麼管道可以上網投稿(雜誌/報紙)?最好有信箱&投稿條件找了一陣子沒有適合的非...
# 19    前幾天有學妹問我說如果再讓你回到大學你最想做的事情是什麼?存錢。其實我不是很喜歡買衣服，也不...
# 20    很多男生睡覺都會打呼,那如果遇上會打呼的女生,男生的看法是甚麼呢???想知道男生對會打呼的女...
# 21    都說認真的女人最美麗，認真的男人最帥氣感覺上會樂器會唱歌或是會跳舞都是很綻放光芒的才藝吧大家...
# 22    先說台鋁在高雄哦它原本是多個廢棄的貨櫃後來改造成台鋁生活圈接近夢時代，還有前鎮的好事多的附近...
# 23    爬過文章真的少之又少，想請問正職的工作內容有哪些，有個人業績壓力之類的嗎?薪水大概落在哪裡，謝謝。
# 24    https://news.tvbs.com.tw/local/851855其實我今天不是來檢...
# 25         本人是愛吃海鮮主義者，雖然吃多會過敏但海鮮魅力還是無法擋!!!!!!!!!有同好嗎哈哈哈
# 26
# 27    我最開始是在工作那邊發文，詢問趕時間開薪資戶說明一下整件事公司匯薪水是使用中信，但是我沒戶頭...
# 28    前中研院長李遠哲今（16）日表示，2015年是關鍵的一年，今年如果不努力的話，會對不起我們下...
# 29
# ...                                                 ...
# 4969  前幾天看到有人po義美的巧克力球就想到最近讓自己忍不住嘴饞的點心沒錯就是這個！！！這樣一盒2...
# 4970  餐飲服務業 照理說不能帶寵物店裡一位比我早一週進店的大姐卻整天帶著寵物上下班跟她都是站外場 ...
# 4971  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權http://www.upmed...
# 4972  不知道大家知不知道其實jolin的翻糖蛋糕並不是她做的，而是團隊製作，她只負責創意發想老實說...
# 4973  不希望被說是伸手，我真的有從網路上搜尋他的公司，真的沒什麼資訊。請問大大們有人知道嗎？最近新...
# 4974  鄭振和 Jenher Jeng 粉絲頁https://www.facebook.com/je...
# 4975  距離第一次入取，已經工作1個月多了結果第一次發薪水後，覺得頗怪怎麼沒有扣掉勞健保的部分負擔?...
# 4976  今天剛投履歷 晚上就接到面試通知請問有人做過可以分享工作經驗或是面試會有什麼考試或考核嗎需要...
# 4977  大家最關心經濟問題，我只講經濟好了首先當初拼命吹噓一帶一路的，看到中國因中美貿易被電得慘兮兮...
# 4978  每天挑戰聽歌辨名 成功可獲得百威啤酒總共可以挑戰3次 要用代碼到ibon兌換活動期間:201...
# 4979  對於馬鈴薯狂熱者來說最，基本的烹調方式非起司馬鈴薯莫屬，雖然作法簡易，調味也算不上精緻，但我...
# 4980  1：廣東深圳廢土堆崩瀉，推倒幾十座樓房，七十幾人失蹤2：土耳其庫爾德人抗議軍方持續攻擊，造成...
# 4981  因為當初近第一間學校的時候系上要求我們一次繳4000元的系會費((4年繳清))在那間學校經過...
# 4982  1.弱弱相保不是早就知道的事？現在才感覺到嗎？2.勞務折抵保費不知道哪個天才山頂洞人的學者還...
# 4983  第16篇：濃湯/雙主餐/甜點嗨，歡迎來到我的廚房！今天是豪華料理日🎉難得的海陸大餐！採取小份...
# 4985  之前刷卡時五分鐘之內消費紀錄就到App內了但我星期日刷了兩筆都還沒記到前兩天繳上個月的信用卡...
# 4986  最近這幾年「出走」這個詞時常在新聞上看到像是甚麼企業、員工不排除出走等等和朋友討論這件事時他...
# 4987  小弟我今天被通知入取電機設備工程師，待遇31500，想請問一下有沒有人待過這間公司，在裡面工...
# 4988  最近畢業到處投履歷面試，有兩個工作可以選，很難抉擇。A離家近，是計時人員，薪水要看做多久，做...
# 4989  ｡･ﾟ･(ﾉД`)･ﾟ･｡我有分類障礙(?!)-----------------------...
# 4990  文長慎入如題昨天上班的時候遇到一位客人他"自己"打翻了一杯黑咖啡幫他整理完後 他說了一句話客...
# 4991  有沒有一種情況當你坐在位子上，有個女孩子需要經過你這裡時，你把椅子往前移讓她方便過去但她卻看...
# 4992  想不到癢詢我有毅力發到第五篇wwwww一個人當清流很辛苦的，有時候也會感到無助，但是要堅持下...
# 4993         作法不難，材料有三樣。第一、吉利丁粉。第二、水和高果糖漿。第三、Amazon的模具。
# 4994  身為一個因為過敏所以常常鼻子裡充滿鼻涕的女子真的很苦惱，也想告訴大家不是每個女生都是睡美人好...
# 4995  每次去早餐店or吃宵夜…對方總是會很親切地對每個人說帥哥即便當下只有我一個男的(還是會lag...
# 4996  相信大家自己有眼睛圖片來源：https://m.facebook.com/story.php...
# 4997  首po, 手機排版，請見諒......更新:對於許多善意勸說與指責，先說聲謝謝，但在這邊我要...
# 4998  我是一個小小人資從面試邀約到新人進入公司帶新人除了決定是否錄取以外 基本都由我在處理（是否錄...
# 4999  門診護理師定義：在醫院或診所按燈叫號且擁有國家護理師執照的人http://www.ettod...
#
#                   crawl_date               create_date  \
# 0    2019-02-15 07:49:24.035  2016-07-03T16:51:05.200Z
# 1    2019-02-19 08:25:10.219  2017-03-11T09:36:15.788Z
# 2    2019-02-13 01:39:36.743  2016-11-15T03:16:45.628Z
# 3    2019-02-19 06:09:49.412  2016-09-12T14:33:05.434Z
# 4    2019-02-15 02:46:30.961  2018-11-15T19:22:07.846Z
# 5    2019-02-13 03:28:19.805  2017-03-22T04:04:36.302Z
# 6    2019-02-13 03:54:05.395  2017-05-28T16:40:26.874Z
# 7    2019-02-15 07:05:51.092  2018-10-11T12:06:50.282Z
# 8    2019-02-18 06:33:17.498  2015-08-17T13:33:21.449Z
# 9    2019-02-15 02:47:31.216  2018-11-17T11:02:23.407Z
# 10   2019-02-15 00:49:43.456  2018-09-21T17:36:30.998Z
# 11   2019-02-15 08:58:38.437  2017-07-17T01:59:42.390Z
# 12   2019-02-15 01:02:43.671  2018-10-24T08:24:42.097Z
# 13   2019-02-19 06:02:56.025  2016-09-06T13:15:01.752Z
# 14   2019-02-19 08:18:01.166  2017-02-11T13:25:45.068Z
# 15   2019-02-14 03:18:09.273  2015-10-29T13:30:27.164Z
# 16   2019-02-19 02:37:36.089  2015-12-30T11:32:01.871Z
# 17   2019-02-15 02:54:34.513  2018-11-21T08:44:59.181Z
# 18   2019-02-19 01:30:10.446  2015-10-02T15:06:59.228Z
# 19   2019-02-19 02:29:57.684  2015-12-01T07:34:51.240Z
# 20   2019-02-19 03:02:53.777  2016-02-11T10:50:30.259Z
# 21   2019-02-18 03:32:33.856  2014-01-18T17:36:34.000Z
# 22   2019-02-19 02:45:01.815  2016-01-03T09:57:33.917Z
# 23   2019-02-18 01:05:34.354  2017-09-25T19:08:21.686Z
# 24   2019-02-14 09:05:54.903  2018-01-13T05:26:25.993Z
# 25   2019-02-12 08:39:36.194  2016-07-30T13:24:36.408Z
# 26   2019-02-13 01:14:03.189  2016-10-27T15:22:25.050Z
# 27   2019-02-15 05:15:37.809  2018-02-01T09:19:16.252Z
# 28   2019-02-14 02:34:52.743  2015-05-16T15:44:00.995Z
# 29   2019-02-13 00:43:43.113  2016-10-14T09:31:33.331Z
# ...                      ...                       ...
# 4969 2019-02-13 03:18:28.551  2017-02-23T02:17:13.793Z
# 4970 2019-02-15 07:50:26.851  2016-07-15T05:52:04.891Z
# 4971 2019-02-14 08:52:45.507  2017-11-01T15:23:10.786Z
# 4972 2019-02-19 08:01:05.280  2016-11-02T11:25:02.522Z
# 4973 2019-02-18 02:46:20.694  2019-01-30T04:32:48.600Z
# 4974 2019-02-18 03:24:33.024  2013-11-02T17:27:25.000Z
# 4975 2019-02-15 08:13:22.823  2016-10-08T05:34:54.300Z
# 4976 2019-02-15 08:56:01.156  2017-07-09T12:43:11.116Z
# 4977 2019-02-15 03:50:28.140  2019-02-14T15:44:26.517Z
# 4978 2019-02-13 05:02:17.979  2017-09-03T21:46:44.431Z
# 4979 2019-02-12 07:38:41.375  2016-02-24T16:55:54.737Z
# 4980 2019-02-14 03:35:27.652  2015-12-22T15:24:59.158Z
# 4981 2019-02-19 01:22:50.246  2015-09-06T06:41:46.326Z
# 4982 2019-02-14 07:35:37.218  2016-08-19T02:47:22.806Z
# 4983 2019-02-12 06:13:48.200  2015-08-21T14:52:57.733Z
# 4985 2019-02-15 05:29:30.066  2019-01-15T15:01:01.215Z
# 4986 2019-02-14 08:26:38.253  2017-06-16T18:16:49.441Z
# 4987 2019-02-18 01:27:32.032  2018-02-14T11:04:44.372Z
# 4988 2019-02-15 08:56:35.519  2017-06-30T08:44:13.968Z
# 4989 2019-02-18 06:04:30.327  2015-05-11T08:19:02.007Z
# 4990 2019-02-15 08:14:08.061  2016-10-15T16:37:08.332Z
# 4991 2019-02-19 02:36:52.897  2015-12-31T08:03:02.092Z
# 4992 2019-02-19 02:47:51.209  2016-01-09T14:07:54.409Z
# 4993 2019-02-12 06:05:39.991  2015-05-28T07:51:10.392Z
# 4994 2019-02-19 03:30:24.093  2016-03-12T16:17:34.285Z
# 4995 2019-02-19 02:52:02.584  2016-01-27T04:41:56.070Z
# 4996 2019-02-15 02:56:00.779  2018-11-22T17:10:20.110Z
# 4997 2019-02-15 08:27:42.791  2017-03-27T08:28:44.935Z
# 4998 2019-02-18 02:04:29.894  2018-09-15T17:02:31.710Z
# 4999 2019-02-14 02:33:22.598  2015-04-01T07:55:52.844Z
#
#                                  question question_target question_type  \
# 0                                 健身房工作經驗                         other
# 1                                   刺青的意義                         other
# 2                                    蜂蜜真假                         other
# 3                                  愛各種淡紫色                         other
# 4                             台灣的未來交給柯文哲！                         other
# 5                             單身狗廚房x野外露營篇                         other
# 6                                龍允日式手作壽司                         other
# 7                                  日文翻譯問題                         other
# 8                  尋~一個卡片遊戲 給背包客專用 (電視上看到                         other
# 9                                 我不想吸髒空氣                         other
# 10                  金正恩「羞辱」中國人   牽出中共賣國秘密                         other
# 11                              關於公司隨身碟使用                         other
# 12                               揭穿台鐵避重就輕                         other
# 13                           有一種強迫症叫做：嫌字醜                         other
# 14                        有人在Owndays配鏡過嗎?                         other
# 15                被台聯設計」，柯文哲與李登輝私下會面變輔選行程                         other
# 16                                 雷雷a鐵板燒                         other
# 17                               有關高雄負債問題                         other
# 18                                文章投稿管道?                         other
# 19                               給大學生的建議                          other
# 20                              ㄍㄡˊㄍㄡˊㄍㄡˊ                         other
# 21                            什麼樣的才華最吸引人？                         other
# 22                                台鋁MLD影城                         other
# 23                                 關於三友藥妝                         other
# 24                           台南男大生9日晚間遭撞死                         other
# 25                               有人喜歡吃海鮮嗎                         other
# 26                                  麥當勞報報                         other
# 27                                   中信開戶                         other
# 28                  李遠哲鼓勵青年：勿信50年後不在地球上的人                         other
# 29                              奶茶超好喝的OAO                         other
# ...                                   ...             ...           ...
# 4969                               森永巧克力球                         other
# 4970                               餐飲店養寵物                         other
# 4971  ＃新聞  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權                         other
# 4972                       關於 jolin 的翻糖蛋糕                         other
# 4973                        憲哥 吸塵器面試1500人                         other
# 4974                               科學家鄭振和                         other
# 4975                      根本扼殺在醫院工作的年輕人！！                         other
# 4976                         日月光  科技廠櫃檯秘書                         other
# 4977                       台灣經濟事實上是不斷進步的!                         other
# 4978                               免費百威啤酒                         other
# 4979                             焗烤起司馬鈴薯泥                         other
# 4980                                   時事              時事          what
# 4981                    轉學可以要回之前繳的4年系會費嗎?                         other
# 4982                           國民年金不到六成繳費                         other
# 4983                               豪華海陸饗宴                         other
# 4985                       Richart消費動態不更新                         other
# 4986                             有本事早就出去了                         other
# 4987                            榮成紙業 工作如何                         other
# 4988                           工作選擇，急，在線等                         other
# 4989                          「腦內革命，友善大腦」                         other
# 4990                           太不要臉了吧這位客人                         other
# 4991                            你是覺得我很胖喔？                         other
# 4992                              統神語錄第五篇                         other
# 4993                       可以吃的樂高玩具，影片分享。                         other
# 4994                                  睡美人             睡美人          what
# 4995                            只有飲食業對人最好                         other
# 4996                         到底是誰在用政治干涉體育                           who
# 4997                    全家系統讓我幫客人付了680元帳單                         other
# 4998                           關於“面試”這件事情                         other
# 4999                             過號就讓他等啊!                         other
#
#                                     title
# 0                              健身房工作經驗（問）
# 1                                #圖 刺青的意義
# 2                                    蜂蜜真假
# 3                                  愛各種淡紫色
# 4                             台灣的未來交給柯文哲！
# 5                          #圖 單身狗廚房x野外露營篇
# 6                        #食記 #東港 龍允日式手作壽司
# 7                                  日文翻譯問題
# 8               尋~一個卡片遊戲(?) 給背包客專用 (電視上看到
# 9                                 我不想吸髒空氣
# 10                  金正恩「羞辱」中國人   牽出中共賣國秘密
# 11                              關於公司隨身碟使用
# 12                               揭穿台鐵避重就輕
# 13                           有一種強迫症叫做：嫌字醜
# 14                     #問 有人在Owndays配鏡過嗎?
# 15                被台聯設計」，柯文哲與李登輝私下會面變輔選行程
# 16                             (黑特)雷雷a鐵板燒
# 17                               有關高雄負債問題
# 18                                文章投稿管道?
# 19                           給大學生的建議 (更新)
# 20                              ㄍㄡˊㄍㄡˊㄍㄡˊ
# 21                        【閒聊】什麼樣的才華最吸引人？
# 22                                台鋁MLD影城
# 23                                 關於三友藥妝
# 24                     #社會新聞 台南男大生9日晚間遭撞死
# 25                               有人喜歡吃海鮮嗎
# 26                               #更 麥當勞報報
# 27                               #分享#中信開戶
# 28                  李遠哲鼓勵青年：勿信50年後不在地球上的人
# 29                              奶茶超好喝的OAO
# ...                                   ...
# 4969                               森永巧克力球
# 4970                               餐飲店養寵物
# 4971  ＃新聞  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權
# 4972                       關於 jolin 的翻糖蛋糕
# 4973                        憲哥 吸塵器面試1500人
# 4974                           【閒聊】科學家鄭振和
# 4975                      根本扼殺在醫院工作的年輕人！！
# 4976                      #問 日月光  科技廠櫃檯秘書
# 4977                    [轉]台灣經濟事實上是不斷進步的!
# 4978                           #情報 免費百威啤酒
# 4979                    【小食光🐽】#圖#焗烤起司馬鈴薯泥
# 4980                                   時事
# 4981                    轉學可以要回之前繳的4年系會費嗎?
# 4982                           國民年金不到六成繳費
# 4983                         [美食生活]豪華海陸饗宴
# 4985                    #問 Richart消費動態不更新
# 4986                        #討論  有本事早就出去了
# 4987                            榮成紙業 工作如何
# 4988                           工作選擇，急，在線等
# 4989                  【推廣(?)】 「腦內革命，友善大腦」
# 4990                           太不要臉了吧這位客人
# 4991                            你是覺得我很胖喔？
# 4992                【鋼筆隨寫小作業 歡迎跟抄】統神語錄第五篇
# 4993                       可以吃的樂高玩具，影片分享。
# 4994                                  睡美人
# 4995                            只有飲食業對人最好
# 4996                         到底是誰在用政治干涉體育
# 4997                 #更#全家系統讓我幫客人付了680元帳單
# 4998                           關於“面試”這件事情
# 4999                             過號就讓他等啊!
#
# [4990 rows x 10 columns]

# %%
filter_pd = pd_df[pd_df['question_type'] != 'other']
print len(filter_pd)
# filter_pd[['article_id','board','title','question','question_type','question_target']]
for i,r in filter_pd.iterrows():
    print r['title'] + ' | ' + r['question'] + ' | ' + r['question_type'] + ' | ' + r['question_target']
# Out:
# 309
# ＃打工  寒假如何找超過基本工資的打工？ | ＃打工  寒假如何找超過基本工資的打工？ | how | ＃打工  寒假如何找超過基本工資的打工？
# 未來的出路在哪裏 | 未來的出路在哪裏 | where |
# #評論 國民黨產帳怎麼算？退將：民進黨也曾被餵黨產奶水 | 國民黨產帳怎麼算？退將：民進黨也曾被餵黨產奶水 | how | 國民黨產帳怎麼算？退將：民進黨也曾被餵黨產奶水
# 發發牢騷 | 發發牢騷 | what | 發發牢騷
# 公投怎麼投？ | 公投怎麼投？ | how | 公投怎麼投？
# 畢業旅行～有哪些地方可以選擇呢 | 畢業旅行～有哪些地方可以選擇呢 | where |
# 錢該怎麼算 | 錢該怎麼算 | how | 錢該怎麼算
# 智力測驗 | 智力測驗 | what | 智力測驗
# 拉K的味道怎麼辨別 | 拉K的味道怎麼辨別 | how | 拉K的味道怎麼辨別
# （問）整棟只有一個電表 那電費大家會如何算呢 | 整棟只有一個電表 那電費大家會如何算呢 | how | 整棟只有一個電表 那電費大家會如何算呢
# 怎麼判別甲甲 | 怎麼判別甲甲 | how | 怎麼判別甲甲
# 台北下著雨，餓著肚子的人何處去? | 台北下著雨，餓著肚子的人何處去? | where | 台北
# 智利櫻桃現在市價大約多少呢？ | 智利櫻桃現在市價大約多少呢？ | how_many |
# 為什麼未滿18歲不能看限制級電影 | 為什麼未滿18歲不能看限制級電影 | why |
# 大家畢業多久才找到工作? | 大家畢業多久才找到工作? | status |
# 劍靈 | 劍靈 | where | 劍靈
# 【提問】最近CPBL熱身賽的主播跟球評到底是誰....? | 最近CPBL熱身賽的主播跟球評到底是誰....? | who |
# 這個甜點哪裡買的到呢 | 這個甜點哪裡買的到呢 | where |
# 驅逐出場 | 驅逐出場 | what | 驅逐出場
# 真的窮到不知如何是好，求分享 | 真的窮到不知如何是好，求分享 | how | 真的窮到不知如何是好，求分享
# 大學生必看！「甜課」的日文怎麼說呢？ | 大學生必看！「甜課」的日文怎麼說呢？ | how | 大學生必看！「甜課」的日文怎麼說呢？
# 要怎麼加入民進黨黨工啊 | 要怎麼加入民進黨黨工啊 | how | 要怎麼加入民進黨黨工啊
# #問#西班牙文 | 西班牙文 | what | 西班牙文
# M80 | M80 | what | M80
# 想問大家知道哪裡還喝得到舞茶道嗎 | 想問大家知道哪裡還喝得到舞茶道嗎 | where |
# #工作經驗分享#文長 | 文長 | what | 文長
# 怎麼辦好像遇到輔大有名的房東 | 怎麼辦好像遇到輔大有名的房東 | how | 怎麼辦好像遇到輔大有名的房東
# 奧俐奧 | 奧俐奧 | who | 奧俐奧
# 參軍 | 參軍 | what | 參軍
# 一天是能停幾次電 | 一天是能停幾次電 | how_many |
# 愛哭是怎麼回事?! | 愛哭是怎麼回事?! | how | 愛哭是怎麼回事?!
# 牙套 | 牙套 | what | 牙套
# 西門町 | 西門町 | where | 西門町
# #問 冥想 | 冥想 | what | 冥想
# 所以我說劉喬安到底是誰? | 所以我說劉喬安到底是誰? | who |
# 大家最喜歡Radwimps的那首歌以及認識Rad幾年 | 大家最喜歡Radwimps的那首歌以及認識Rad幾年 | how_many |
# 君臨 | 君臨 | where | 君臨
# 如果IS轟炸臺灣會轟那裡? | 如果IS轟炸臺灣會轟那裡? | where | 臺灣
# 為什麼台灣學生這麼閒，可以到處潑漆? | 為什麼台灣學生這麼閒，可以到處潑漆? | why |
# 為什麼女卡友都不加我 | 為什麼女卡友都不加我 | why |
# 大家都去哪裡找最新音樂呢? | 大家都去哪裡找最新音樂呢? | where |
# 行事曆 | 行事曆 | what | 行事曆
# 外媒如何看這次的選舉 | 外媒如何看這次的選舉 | how | 外媒如何看這次的選舉
# 【求助】Dcard的廣告怎麼進化到連AdBlock都檔不掉了.. | Dcard的廣告怎麼進化到連AdBlock都檔不掉了.. | how | Dcard的廣告怎麼進化到連AdBlock都檔不掉了..
# (幫PO) 不知道該怎麼幫僑生朋友? 關於如果選系可以在重來一次，會選擇聽家人? 還是選擇自己有興趣的? |  不知道該怎麼幫僑生朋友? 關於如果選系可以在重來一次，會選擇聽家人? 還是選擇自己有興趣的? | how |  不知道該怎麼幫僑生朋友? 關於如果選系可以在重來一次，會選擇聽家人? 還是選擇自己有興趣的?
# 創作文是什麼? | 創作文是什麼? | what | 文
# 全聯盤點 加班費怎麼算 | 全聯盤點 加班費怎麼算 | how | 全聯盤點 加班費怎麼算
# 有人知道這個零食的名字是什麼麽 | 有人知道這個零食的名字是什麼麽 | what | 零食
# 基督教怎麼面對同性戀？ | 基督教怎麼面對同性戀？ | how | 基督教怎麼面對同性戀？
# 團體 | 團體 | what | 團體
# 春x堂 為什麼可以叫人幫忙提早打卡下班呢？ | 春x堂 為什麼可以叫人幫忙提早打卡下班呢？ | why |
# 有幾個黑點？ | 有幾個黑點？ | how_many |
# 後背包減壓背帶哪裡買 | 後背包減壓背帶哪裡買 | where |
# 關於履歷填寫期望薪資多少 | 關於履歷填寫期望薪資多少 | how_many |
# 加班費 | 加班費 | what | 加班費
# 到底為什麼要一直拿勞工和軍公教比啊？ | 到底為什麼要一直拿勞工和軍公教比啊？ | why |
# 你跟你同學（朋友）最高同班過幾年？ | 你跟你同學最高同班過幾年？ | how_many |
# #多益 問題 | 問題 | what | 問題
# 擲筊 | 擲筊 | what | 擲筊
# #全聯 問該如何辭職 | 問該如何辭職 | how | 問該如何辭職
# 現在的男生為什麼不能認命去當兵 | 現在的男生為什麼不能認命去當兵 | why |
# 怎麼稱呼同學 | 怎麼稱呼同學 | how | 怎麼稱呼同學
# 約克夏 | 約克夏 | who | 約克夏
# 台港大咖在那裡？ | 台港大咖在那裡？ | where | 台港
# #問 語言學 | 語言學 | what | 語言學
# 不知道這支影片大家看完的感想是什麼 | 不知道這支影片大家看完的感想是什麼 | what | 影片
# 如何幫助排便 | 如何幫助排便 | how | 如何幫助排便
# 跑步跑多久 | 跑步跑多久 | status |
# 關於拿多少回家裡 | 關於拿多少回家裡 | how_many |
# 她到底是誰！？ | 她到底是誰！？ | who |
# 什麼是霸凌？你們都是霸凌者 | 什麼是霸凌？你們都是霸凌者 | what | 霸凌
# 大家過年都包多少？ | 大家過年都包多少？ | how_many |
# 大家什麼時候開始覺得有代溝 | 大家什麼時候開始覺得有代溝 | when |
# 直銷，大餐知多少 | 直銷，大餐知多少 | how_many |
# 面試怎麼像整人節目Σ(;ﾟдﾟ) | 面試怎麼像整人節目Σ | how | 面試怎麼像整人節目Σ
# 請教這句英文怎麼翻~~ | 請教這句英文怎麼翻~~ | how | 請教這句英文怎麼翻~~
# 【討拍】台灣的女生各個都難追的跟女神一樣是怎麼回事? | 台灣的女生各個都難追的跟女神一樣是怎麼回事? | how | 台灣的女生各個都難追的跟女神一樣是怎麼回事?
# 為什麼我一定要有腰啊(ﾟ∀ﾟ)？ | 為什麼我一定要有腰啊？ | why |
# 為什麼要自稱魯蛇又急著想脫魯？ | 為什麼要自稱魯蛇又急著想脫魯？ | why |
# 該怎麼改善我的家教技巧 | 該怎麼改善我的家教技巧 | how | 該怎麼改善我的家教技巧
# 為什麼台灣曼德拉，被緣緣討厭？ | 為什麼台灣曼德拉，被緣緣討厭？ | why |
# 跨年去哪裡好玩? | 跨年去哪裡好玩? | where |
# 中原大學 | 中原大學 | what | 中原大學
# 【服貿】這幾天的觀感 | 這幾天的觀感 | how_many |
# 如何不讓心輕易被聊走 | 如何不讓心輕易被聊走 | how | 如何不讓心輕易被聊走
# #問 打一整頁英文 這樣應該多少錢？ | 打一整頁英文 這樣應該多少錢？ | how_many |
# #請益 payeer | payeer | what | payeer
# 台灣文化是什麼 | 台灣文化是什麼 | what | 台灣
# 一天最多面試過幾家公司？ | 一天最多面試過幾家公司？ | how_many |
# 為什麼有些人覺得買保險算是投資= =? | 為什麼有些人覺得買保險算是投資= =? | why |
# 為什麼有些人不喜歡看書 | 為什麼有些人不喜歡看書 | why |
# 一天最多上幾次大號? | 一天最多上幾次大號? | how_many |
# 到底要提智商測驗多久!? | 到底要提智商測驗多久!? | status |
# 動漫界的男主角誰是最渣的呢? | 動漫界的男主角誰是最渣的呢? | who |
# 去了幾趟中國 沒錯台灣真的不一樣 | 去了幾趟中國 沒錯台灣真的不一樣 | how_many |
# 為什麼紅綠燈🚥倒數的秒數是綠燈？ | 為什麼紅綠燈🚥倒數的秒數是綠燈？ | why |
# 萬安演習地震怎麼辦的八卦 | 萬安演習地震怎麼辦的八卦 | how | 萬安演習地震怎麼辦的八卦
# 狄卡大大你排哀鳳排多久啊哈哈哈 | 狄卡大大你排哀鳳排多久啊哈哈哈 | status |
# #討論 這是第幾次媒體說蔡英文抱怨/動怒了 | 這是第幾次媒體說蔡英文抱怨/動怒了 | how_many |
# #社論  人死了，怎麼沒有狗抗議？ |  人死了，怎麼沒有狗抗議？ | how |  人死了，怎麼沒有狗抗議？
# 性工作專區」何處尋？ | 性工作專區」何處尋？ | where |
# 為什麼一堆草包政客都要看稿辯論? | 為什麼一堆草包政客都要看稿辯論? | why |
# 年終獎金 | 年終獎金 | what | 年終獎金
# #問 刺青師 | 刺青師 | what | 刺青師
# 認識同志友人的這幾年 | 認識同志友人的這幾年 | how_many |
# 蹺班 | 蹺班 | what | 蹺班
# 【分享】當台東的學生在自製核反應爐時，台北的家長正因為孩子考不上建中而摔玩具….「資優生」們，你們的競爭力在哪裡？ | 當台東的學生在自製核反應爐時，台北的家長正因為孩子考不上建中而摔玩具….「資優生」們，你們的競爭力在哪裡？ | where | 台東
# Re: 30秒完成高質感書籤 之 幾何剪裁篇 | Re: 30秒完成高質感書籤 之 幾何剪裁篇 | how_many |
# share | share | what | share
# 韓文全部連音只剩下ㄴㅁㄹㅇ>ㅂㅈㄷㅅㄱ=ㄸㅉㄲㅃㅆ不知何時變音 | 韓文全部連音只剩下ㄴㅁㄹㅇ>ㅂㅈㄷㅅㄱ=ㄸㅉㄲㅃㅆ不知何時變音 | when |
# 威力彩 | 威力彩 | what | 威力彩
# 怎麼選擇工作 | 怎麼選擇工作 | how | 怎麼選擇工作
# 偏韓系流行的new blance是哪個系列的呢? | 偏韓系流行的new blance是哪個系列的呢? | what | 韓系
# 乳瑪琳 | 乳瑪琳 | what | 乳瑪琳
# 地震 | 地震 | what | 地震
# 原來十幾年前的大學生這樣生活 | 原來十幾年前的大學生這樣生活 | how_many |
# (附圖)有沒有哪個國家地鐵站設計最好看的卦？ | 有沒有哪個國家地鐵站設計最好看的卦？ | where |
# 有人說宋爺爺70幾還出來選好感人啊  而我想說的是... | 有人說宋爺爺70幾還出來選好感人啊  而我想說的是... | how_many |
# 立秋 | 立秋 | who | 立秋
# #求助 服貿和監督條例到底什麼時候過的？ | 服貿和監督條例到底什麼時候過的？ | when |
# #問  如何取得特教老師資格，(非特教學系大學畢業生) |  如何取得特教老師資格， | how |  如何取得特教老師資格，
# 這個he是什麼意思#西文 | 這個he是什麼意思#西文 | what | he
# 鄉土劇 | 鄉土劇 | what | 鄉土劇
# 求推薦哪裡有適合工作的場所 | 求推薦哪裡有適合工作的場所 | where |
# iphone6 | iphone6 | what | iphone6
# 當你看看到這句話的時候，你會怎麼想 | 當你看看到這句話的時候，你會怎麼想 | how | 當你看看到這句話的時候，你會怎麼想
# 南非幣 | 南非幣 | what | 南非幣
# RE：大學畢業男生要多少存款女生覺得合理 | RE：大學畢業男生要多少存款女生覺得合理 | how_many |
# 【創作】貴人(文中長) | 貴人 | what | 貴人
# 到底是誰... | 到底是誰... | who |
# 公主病特徵到底是什麼？？ | 公主病特徵到底是什麼？？ | what | 公主病
# 數碼寶貝 | 數碼寶貝 | what | 數碼寶貝
# 乳清哪裡買才安全 | 乳清哪裡買才安全 | where |
# TutorABC | TutorABC | what | TutorABC
# 第一份工作 多久找到 | 第一份工作 多久找到 | status |
# #不解 何時才能改掉手扶梯靠右站的習慣 | 何時才能改掉手扶梯靠右站的習慣 | when |
# 聊多久你(妳)們才願意要(給)對方line | 聊多久你們才願意要對方line | status |
# 為什麼一大早就給我這樣的驚訝 | 為什麼一大早就給我這樣的驚訝 | why |
# 想請問大家營隊怎麼招生比較有效率 | 想請問大家營隊怎麼招生比較有效率 | how | 想請問大家營隊怎麼招生比較有效率
# 該怎麼讓家裡的毛小孩不要這麼貪吃？！ | 該怎麼讓家裡的毛小孩不要這麼貪吃？！ | how | 該怎麼讓家裡的毛小孩不要這麼貪吃？！
# 出社會了，該給家裡多少錢 | 出社會了，該給家裡多少錢 | how_many |
# #文章 新政府的第一本禁書?----電從那裡來 | 新政府的第一本禁書?----電從那裡來 | where |
# #問 單字書 | 單字書 | what | 單字書
# 為什麼甲甲→男孩版、Les→女孩版呢？ | 為什麼甲甲→男孩版、Les→女孩版呢？ | why |
# 夜店 | 夜店 | what | 夜店
# #新聞#味全龍復活 有影 | 有影 | what | 有影
# 要多久才會 | 要多久才會 | status |
# 你們怎麼去追男朋友或女朋友啊？ | 你們怎麼去追男朋友或女朋友啊？ | how | 你們怎麼去追男朋友或女朋友啊？
# 為什麼清大可以這麼無聊...求解QQ | 為什麼清大可以這麼無聊...求解QQ | why |
# 日檢成績什麼時候開放查詢? | 日檢成績什麼時候開放查詢? | when |
# [發問]通知面試後可以隔多久 | 通知面試後可以隔多久 | status |
# 為什麼那麼多大學生喜歡柯文哲 | 為什麼那麼多大學生喜歡柯文哲 | why |
# 【發問】智慧型手機怎麼改成按鈕旋轉螢幕？ | 智慧型手機怎麼改成按鈕旋轉螢幕？ | how | 智慧型手機怎麼改成按鈕旋轉螢幕？
# 精益求精 | 精益求精 | what | 精益求精
# #新聞 評國運 蔡正元:蔡英文會讓台灣末日提前幾年 | 評國運 蔡正元:蔡英文會讓台灣末日提前幾年 | how_many |
# LM TV 跟WIN TV哪裡不同？ | LM TV 跟WIN TV哪裡不同？ | where |
# 考警專要怎麼準備？ | 考警專要怎麼準備？ | how | 考警專要怎麼準備？
# 大家有沒有發現搜尋引擎搜到的前幾名來源幾乎都是簡字網站? | 大家有沒有發現搜尋引擎搜到的前幾名來源幾乎都是簡字網站? | how_many |
# 達美樂 | 達美樂 | what | 達美樂
# 中共到底有多少稱台名稱 | 中共到底有多少稱台名稱 | how_many |
# 大學要存多少 文長 | 大學要存多少 文長 | how_many |
# 京東 | 京東 | where | 京東
# #問 台南哪裡還有起司馬鈴薯 | 台南哪裡還有起司馬鈴薯 | where | 台南
# 卡稱 | 卡稱 | who | 卡稱
# 【閒聊】喜歡的人幾乎不會主動密我 | 喜歡的人幾乎不會主動密我 | how_many |
# 恐男症怎麼克服… | 恐男症怎麼克服… | how | 恐男症怎麼克服…
# 一般大學女生平常都怎麼生活呢?? | 一般大學女生平常都怎麼生活呢?? | how | 一般大學女生平常都怎麼生活呢??
# 怎麼說人家長的不好看 | 怎麼說人家長的不好看 | how | 怎麼說人家長的不好看
# 當初選柯p的人現在怎麼想 | 當初選柯p的人現在怎麼想 | how | 當初選柯p的人現在怎麼想
# 台南哪裡找得到寒假打工 | 台南哪裡找得到寒假打工 | where | 台南
# 家庭煮夫 | 家庭煮夫 | what | 家庭煮夫
# 生日蛋糕 | 生日蛋糕 | what | 生日蛋糕
# 工讀一個月可以賺多少 | 工讀一個月可以賺多少 | how_many |
# 中國網友到處洗版留言 大家怎麼看？ | 中國網友到處洗版留言 大家怎麼看？ | how | 中國網友到處洗版留言 大家怎麼看？
# 蘇打綠 | 蘇打綠 | what | 蘇打綠
# 求解！一包泡麵比一碗現煮牛肉麵還貴是什麼狀況？很好吃嗎？ | 求解！一包泡麵比一碗現煮牛肉麵還貴是什麼狀況？很好吃嗎？ | what | 泡麵
# #新聞 臺灣司法到底有多少弊端 | 臺灣司法到底有多少弊端 | how_many |
# 如何改善身體 | 如何改善身體 | how | 如何改善身體
# Snapchat | Snapchat | what | Snapchat
# 蔡英文臉書：有人問我，要把國家帶去哪裡 | 蔡英文臉書：有人問我，要把國家帶去哪裡 | where |
# 請問有沒有也是剛錄取108-1梯次ROTC一年級女生後備或是政戰軍種同學智力測驗分數幾分呢？求解....感謝 | 請問有沒有也是剛錄取108-1梯次ROTC一年級女生後備或是政戰軍種同學智力測驗分數幾分呢？求解....感謝 | how_many |
# 為什麼這次台北市這麼久 | 為什麼這次台北市這麼久 | why |
# 台灣一年有多少法律系學生畢業? | 台灣一年有多少法律系學生畢業? | how_many |
# 粽子怎麼吃？ | 粽子怎麼吃？ | how | 粽子怎麼吃？
# 要如何認識在學學生？ | 要如何認識在學學生？ | how | 要如何認識在學學生？
# 朋友的喜酒該怎麼拒絕？ | 朋友的喜酒該怎麼拒絕？ | how | 朋友的喜酒該怎麼拒絕？
# 《疫苗之殤》的續集還要上演幾部？這次25萬支假疫苗已註射孩子體中，告訴我怎麽忍？ | 《疫苗之殤》的續集還要上演幾部？這次25萬支假疫苗已註射孩子體中，告訴我怎麽忍？ | how_many |
# 勢利眼 | 勢利眼 | what | 勢利眼
# 先知! 「戴小姐是誰？　蔡正元：柯文哲心裡有數」 | 先知! 「戴小姐是誰？　蔡正元：柯文哲心裡有數」 | who | 小姐
# 生日要怎麼慶祝才好？ | 生日要怎麼慶祝才好？ | how | 生日要怎麼慶祝才好？
# 朋友是什麼? 我需要定義 | 朋友是什麼? 我需要定義 | what | 朋友
# 土撥鼠為什麼叫土撥鼠 | 土撥鼠為什麼叫土撥鼠 | why |
# 哪裡可以買到運動褲呢 | 哪裡可以買到運動褲呢 | where |
# #請益 多益考試離畢業門檻差一點點如何克服？ | 多益考試離畢業門檻差一點點如何克服？ | how | 多益考試離畢業門檻差一點點如何克服？
# 要怎樣才能在liveany上好好聊天 | 要怎樣才能在liveany上好好聊天 | how | 要怎樣才能在liveany上好好聊天
# 鄰居洗澡不關門是什麼意思 | 鄰居洗澡不關門是什麼意思 | what | 關門
# 愛奇藝 | 愛奇藝 | what | 愛奇藝
# 算命先生 | 算命先生 | what | 算命先生
# #圖 賣二手內褲 我該怎麼整回去 | 賣二手內褲 我該怎麼整回去 | how | 賣二手內褲 我該怎麼整回去
# 電子發票 | 電子發票 | what | 電子發票
# 台經院 | 台經院 | what | 台經院
# #問 志願役 | 志願役 | what | 志願役
# Instagram | Instagram | what | Instagram
# 😭為什麼在車上陽光總曬在我身上 | 😭為什麼在車上陽光總曬在我身上 | why |
# 一片裙/防曬裙哪兒買? | 一片裙/防曬裙哪兒買? | where |
# 超能力 | 超能力 | what | 超能力
# #討論 為什麼你不是網紅？ | 為什麼你不是網紅？ | why |
# Caesar | Caesar | what | Caesar
# 買帽子哪裡買 | 買帽子哪裡買 | where |
# #新聞 舉質能不滅定律 徐國勇：一例一休怎麼會三輸 | 舉質能不滅定律 徐國勇：一例一休怎麼會三輸 | how | 舉質能不滅定律 徐國勇：一例一休怎麼會三輸
# 腿毛 | 腿毛 | what | 腿毛
# 呵  你自己智力測驗又幾分 #新聞 #討論 | 呵  你自己智力測驗又幾分 #討論 | how_many |
# 克丹 | 克丹 | who | 克丹
# 為什麼BWS這麼受歡迎呢？ | 為什麼BWS這麼受歡迎呢？ | why |
# 孝順 | 孝順 | what | 孝順
# 到底那裡不一樣？ | 到底那裡不一樣？ | where |
# 蔡籲別再講九二共識 柯文哲反問︰不然應怎麼處理 | 蔡籲別再講九二共識 柯文哲反問︰不然應怎麼處理 | how | 蔡籲別再講九二共識 柯文哲反問︰不然應怎麼處理
# 誰來告訴我鬼氏企業是什麼 | 誰來告訴我鬼氏企業是什麼 | what | 誰來
# 一天會跟多少人聊天呢? | 一天會跟多少人聊天呢? | how_many |
# #問 交情是什麼 如何取得 | 交情是什麼 如何取得 | how | 交情是什麼 如何取得
# 大家都怎麼找實習啊 | 大家都怎麼找實習啊 | how | 大家都怎麼找實習啊
# #圖問 我想問兩個名稱中間有個 x 是什麼意思？ | 我想問兩個名稱中間有個 x 是什麼意思？ | what | 名稱
# #問  哪裡可以買到耐烘培巧克力豆 |  哪裡可以買到耐烘培巧克力豆 | where |
# #聊 #美編 大家都怎麼離開待很久的公司的 | 大家都怎麼離開待很久的公司的 | how | 大家都怎麼離開待很久的公司的
# #問#水煮蛋 | 水煮蛋 | who | 水煮蛋
# #韓語 我看了什麼...... 五分鐘內學會讀韓文...... | 我看了什麼...... 五分鐘內學會讀韓文...... | how | 我看了什麼...... 五分鐘內學會讀韓文......
# 你們會把難過的選修放在幾年級? | 你們會把難過的選修放在幾年級? | how_many |
# 晚安 | 晚安 | what | 晚安
# 抽卡抽到的妹子為什麼那麼難加😦😦 | 抽卡抽到的妹子為什麼那麼難加😦😦 | why |
# 床墊要怎麼清洗 | 床墊要怎麼清洗 | how | 床墊要怎麼清洗
# #歌手 張韶涵（更） | 張韶涵 | who | 張韶涵
# #討論 如果你有權，你會怎麼做 | 如果你有權，你會怎麼做 | how | 如果你有權，你會怎麼做
# 月亮 | 月亮 | what | 月亮
# #徵才 工讀生 | 工讀生 | what | 工讀生
# 簽名檔 | 簽名檔 | what | 簽名檔
# 統神到底是誰? | 統神到底是誰? | who |
# 車禍問題 該怎麼處理 | 車禍問題 該怎麼處理 | how | 車禍問題 該怎麼處理
# 多少人把這邊當相親網站 ? | 多少人把這邊當相親網站 ? | how_many |
# #更 到底值多少錢？ | 到底值多少錢？ | how_many |
# #問 股票 | 股票 | what | 股票
# 大家房租都多少錢啊？? | 大家房租都多少錢啊？? | how_many |
# 雲林虎尾有哪裡剪髮不錯的嗎? | 雲林虎尾有哪裡剪髮不錯的嗎? | where | 雲林
# 災後 | 災後 | what | 災後
# 遠傳入主中嘉為什麼不好? | 遠傳入主中嘉為什麼不好? | why |
# #圖#花蓮#台東 美食 | 美食 | what | 美食
# 選情 | 選情 | what | 選情
# #問 如何阻止別人辦信用卡 | 如何阻止別人辦信用卡 | how | 如何阻止別人辦信用卡
# 【轉貼】低薪?沒人才? 台灣哪裡沒人才了 人材多的是 | 低薪?沒人才? 台灣哪裡沒人才了 人材多的是 | where |
# 誰是統獨教父？請理性看待統獨 | 誰是統獨教父？請理性看待統獨 | who |
# 為什麼大家跑操場都跑逆時鐘 | 為什麼大家跑操場都跑逆時鐘 | why |
# 趕潮流之如何分辨台科生 | 趕潮流之如何分辨台科生 | how | 趕潮流之如何分辨台科生
# 學了第二外語，才知道什麼是真正的學語言 | 學了第二外語，才知道什麼是真正的學語言 | what | 學
# 沖繩 | 沖繩 | what | 沖繩
# 洗手檯 | 洗手檯 | what | 洗手檯
# 請問國外adidas nmd R1 哪裡買？ | 請問國外adidas nmd R1 哪裡買？ | where |
# 請問新手怎麼挑選股票 | 請問新手怎麼挑選股票 | how | 請問新手怎麼挑選股票
# 為什麼做甜點? | 為什麼做甜點? | why |
# Snapchat | Snapchat | what | Snapchat
# 香腸為什麼叫煙強？ | 香腸為什麼叫煙強？ | why |
# 出國考察 | 出國考察 | what | 出國考察
# Follow | Follow | what | Follow
# #問  工讀生勞健保扣多少 |  工讀生勞健保扣多少 | how_many |
# 哪裡能買到整條的生魚片？ | 哪裡能買到整條的生魚片？ | where |
# 生命中出現過幾個左撇子? | 生命中出現過幾個左撇子? | how_many |
# Gooooooal | Gooooooal | what | Gooooooal
# 請問如何抉擇 | 請問如何抉擇 | how | 請問如何抉擇
# #FB #路權 為什麼不能反對重機上國道(文長 | 為什麼不能反對重機上國道(文長 | why |
# #MLB Lin | Lin | what | Lin
# 求推薦流行適合幾個男生跳的舞步 | 求推薦流行適合幾個男生跳的舞步 | how_many |
# #問 想問怎麼改善英文口說🙏🏻 | 想問怎麼改善英文口說🙏🏻 | how | 想問怎麼改善英文口說🙏🏻
# 台中 哪裡有好吃 cp高 的宵夜? | 台中 哪裡有好吃 cp高 的宵夜? | where |
# 寒假如何打發? | 寒假如何打發? | how | 寒假如何打發?
# 為什麼不讓皮卡丘進化？小智的話讓人流淚了>////< | 為什麼不讓皮卡丘進化？小智的話讓人流淚了>////< | why |
# 為什麼要砲轟柯P | 為什麼要砲轟柯P | why |
# 【新手】D卡到底是什麼呀??? | D卡到底是什麼呀??? | what | D
# 為什麼要辦家聚? | 為什麼要辦家聚? | why |
# 誰是可馨? | 誰是可馨? | who |
# #問 有哪位卡友去過台北國際會議中心嗎？ | 有哪位卡友去過台北國際會議中心嗎？ | who |
# 一個w+一個倒v 是什麼牌的logo? | 一個w+一個倒v 是什麼牌的logo? | what | w
# #圖 早午餐 | 早午餐 | what | 早午餐
# #新聞 發文議「中華台北」遭酸 林義傑反擊：我拿國旗你們在哪？ | 發文議「中華台北」遭酸 林義傑反擊：我拿國旗你們在哪？ | where | 台北
# 貧富差距 | 貧富差距 | what | 貧富差距
# 痞客邦 | 痞客邦 | what | 痞客邦
# 中壢哪兒有賣甜湯 | 中壢哪兒有賣甜湯 | where | 中壢
# #第一次找工作 注意事項 | 注意事項 | what | 注意事項
# 戴牙套後多久會改變 | 戴牙套後多久會改變 | status |
# #問 高雄哪裡有好吃的包子 | 高雄哪裡有好吃的包子 | where | 高雄
# 轉 丹佐華盛頓對新聞的看法與如何看新聞 | 轉 丹佐華盛頓對新聞的看法與如何看新聞 | how | 轉 丹佐華盛頓對新聞的看法與如何看新聞
# 為什麼我都抽不到女生？ | 為什麼我都抽不到女生？ | why |
# 怎麼寫阿阿阿 | 怎麼寫阿阿阿 | how | 怎麼寫阿阿阿
# 請問你每個月開銷多少？ | 請問你每個月開銷多少？ | how_many |
# 買了口紅發現不喜歡，該怎麼處理? | 買了口紅發現不喜歡，該怎麼處理? | how | 買了口紅發現不喜歡，該怎麼處理?
# #問  高雄/台南哪裡找得到吹糖 |  高雄/台南哪裡找得到吹糖 | where | 高雄
# 請問如何找打工？ | 請問如何找打工？ | how | 請問如何找打工？
# 關於Spotify 有幾個小問題 | 關於Spotify 有幾個小問題 | how_many |
# 孩子怎麼想 | 孩子怎麼想 | how | 孩子怎麼想
# #新聞 拿國旗扯納粹挨轟　謝志偉臉書狂開砲：你們是什麼身份 | 拿國旗扯納粹挨轟　謝志偉臉書狂開砲：你們是什麼身份 | what | 國旗
# 學運(亞投行、服貿、核四廠等...)你們怎麼看?(有政黨色彩或某黨青年軍別來亂) | 學運你們怎麼看? | how | 學運你們怎麼看?
# 大成就明師是誰？ 是吃得嗎？ | 大成就明師是誰？ 是吃得嗎？ | who |
# 『多圖文長』喔～是誰住在深海的大鳳梨裡 | 『多圖文長』喔～是誰住在深海的大鳳梨裡 | who | 鳳梨
# #問 Line代幣如何使用 | Line代幣如何使用 | how | Line代幣如何使用
# 台大宿舍候補大概什麼時候會補到 | 台大宿舍候補大概什麼時候會補到 | when |
# 請問找工作該怎麼避免踩雷呢 | 請問找工作該怎麼避免踩雷呢 | how | 請問找工作該怎麼避免踩雷呢
# 為什麼很多媽媽會覺得女生就該依附著男生 | 為什麼很多媽媽會覺得女生就該依附著男生 | why |
# #甜點 #甜點的成本哪裡來？ | #甜點的成本哪裡來？ | where |
# 公投通知單不知道寄到哪裡去了😭😭 | 公投通知單不知道寄到哪裡去了😭😭 | where |
# 時事 | 時事 | what | 時事
# 睡美人 | 睡美人 | what | 睡美人
# 到底是誰在用政治干涉體育 | 到底是誰在用政治干涉體育 | who |

# %%
ppp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-278-a2d17bb96faf> in <module>()
# ----> 1 ppp
#
# NameError: name 'ppp' is not defined

# %%
#insert 
DCARD_ARTICLE_TABLE = 'dcard_article_test'
# cql = cql + 'BEGIN BATCH '
for index, row in pd_df.iterrows():

    cql = ("insert into " + DCARD_ARTICLE_TABLE + "(article_id, question, question_type) " + 
          "values(" + str(row['article_id']) + ",'" + 
          row['question'] + "','" + row['question_type'] + "');")
#     print cql
#     dao.execCQL(HELPER_KEYSPACE, cql)
    
# cql = cql + ' APPLY BATCH '
# print cql
# Out:
# insert into dcard_article_test(article_id, question, question_type) values(224297810,'健身房工作經驗','other');
# insert into dcard_article_test(article_id, question, question_type) values(225961291,'刺青的意義','other');
# insert into dcard_article_test(article_id, question, question_type) values(225196435,'蜂蜜真假','other');
# insert into dcard_article_test(article_id, question, question_type) values(224746504,'愛各種淡紫色','other');
# insert into dcard_article_test(article_id, question, question_type) values(230071785,'台灣的未來交給柯文哲！','other');
# insert into dcard_article_test(article_id, question, question_type) values(226029225,'單身狗廚房x野外露營篇','other');
# insert into dcard_article_test(article_id, question, question_type) values(226491861,'龍允日式手作壽司','other');
# insert into dcard_article_test(article_id, question, question_type) values(229830476,'日文翻譯問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(465696,'尋~一個卡片遊戲 給背包客專用 (電視上看到','other');
# insert into dcard_article_test(article_id, question, question_type) values(230081344,'我不想吸髒空氣','other');
# insert into dcard_article_test(article_id, question, question_type) values(229701427,'金正恩「羞辱」中國人   牽出中共賣國秘密','other');
# insert into dcard_article_test(article_id, question, question_type) values(226818276,'關於公司隨身碟使用','other');
# insert into dcard_article_test(article_id, question, question_type) values(229913803,'揭穿台鐵避重就輕','other');
# insert into dcard_article_test(article_id, question, question_type) values(224705473,'有一種強迫症叫做：嫌字醜','other');
# insert into dcard_article_test(article_id, question, question_type) values(225785190,'有人在Owndays配鏡過嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(705433,'被台聯設計」，柯文哲與李登輝私下會面變輔選行程','other');
# insert into dcard_article_test(article_id, question, question_type) values(931773,'雷雷a鐵板燒','other');
# insert into dcard_article_test(article_id, question, question_type) values(230108386,'有關高雄負債問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(615257,'文章投稿管道?','other');
# insert into dcard_article_test(article_id, question, question_type) values(828092,'給大學生的建議 ','other');
# insert into dcard_article_test(article_id, question, question_type) values(1100562,'ㄍㄡˊㄍㄡˊㄍㄡˊ','other');
# insert into dcard_article_test(article_id, question, question_type) values(15001,'什麼樣的才華最吸引人？','other');
# insert into dcard_article_test(article_id, question, question_type) values(945614,'台鋁MLD影城','other');
# insert into dcard_article_test(article_id, question, question_type) values(227335554,'關於三友藥妝','other');
# insert into dcard_article_test(article_id, question, question_type) values(228116329,'台南男大生9日晚間遭撞死','other');
# insert into dcard_article_test(article_id, question, question_type) values(224456408,'有人喜歡吃海鮮嗎','other');
# insert into dcard_article_test(article_id, question, question_type) values(225072351,'麥當勞報報','other');
# insert into dcard_article_test(article_id, question, question_type) values(228229118,'中信開戶','other');
# insert into dcard_article_test(article_id, question, question_type) values(201564,'李遠哲鼓勵青年：勿信50年後不在地球上的人','other');
# insert into dcard_article_test(article_id, question, question_type) values(224975193,'奶茶超好喝的OAO','other');
# insert into dcard_article_test(article_id, question, question_type) values(226541806,'DIGI+ talent 資策會台北','other');
# insert into dcard_article_test(article_id, question, question_type) values(224801095,'送喜歡做蛋糕的人禮物選擇','other');
# insert into dcard_article_test(article_id, question, question_type) values(1030105,'想問一下會計事務所vs 業界 vs 公職','other');
# insert into dcard_article_test(article_id, question, question_type) values(229339823,'詢問詩特莉打工','other');
# insert into dcard_article_test(article_id, question, question_type) values(1100373,'中正大學 死會的比例','other');
# insert into dcard_article_test(article_id, question, question_type) values(227570291,'想詢問巨匠美語','other');
# insert into dcard_article_test(article_id, question, question_type) values(224835679,'腦殘粉絲','other');
# insert into dcard_article_test(article_id, question, question_type) values(53167,'帽T的穿搭','other');
# insert into dcard_article_test(article_id, question, question_type) values(228053266,'＃打工  寒假如何找超過基本工資的打工？','how');
# insert into dcard_article_test(article_id, question, question_type) values(224879845,'剛花100塊趕走壁虎!值得啦','other');
# insert into dcard_article_test(article_id, question, question_type) values(548931,'USB. WIFI','other');
# insert into dcard_article_test(article_id, question, question_type) values(225789236,'花蓮早餐推薦#圖','other');
# insert into dcard_article_test(article_id, question, question_type) values(224482170,'我們該約了的另ㄧ種可能','other');
# insert into dcard_article_test(article_id, question, question_type) values(821633,'公車上偷吃阿姨水果的人出面回應了','other');
# insert into dcard_article_test(article_id, question, question_type) values(225224023,'不要只想貪','other');
# insert into dcard_article_test(article_id, question, question_type) values(892752,'蘋果廚房之超簡單泡菜炒烏龍','other');
# insert into dcard_article_test(article_id, question, question_type) values(226588638,'關於中醫診所助理','other');
# insert into dcard_article_test(article_id, question, question_type) values(58130,'各大學代表美食!!!','other');
# insert into dcard_article_test(article_id, question, question_type) values(224698147,'Iphone原廠手機殼','other');
# insert into dcard_article_test(article_id, question, question_type) values(98707,'幫媽咪找工讀生減輕壓力><','other');
# insert into dcard_article_test(article_id, question, question_type) values(229515976,'未來的出路在哪裏','where');
# insert into dcard_article_test(article_id, question, question_type) values(227531167,'7-11上課','other');
# insert into dcard_article_test(article_id, question, question_type) values(330350,'別只是盲從-彩虹頭貼','other');
# insert into dcard_article_test(article_id, question, question_type) values(225442610,'愛麗絲風奇幻午茶甜點！ #失眠動物園','other');
# insert into dcard_article_test(article_id, question, question_type) values(224512553,'國民黨產帳怎麼算？退將：民進黨也曾被餵黨產奶水','how');
# insert into dcard_article_test(article_id, question, question_type) values(230135857,'反對不乾淨選舉？','other');
# insert into dcard_article_test(article_id, question, question_type) values(11236,'喜歡打桌球的人','other');
# insert into dcard_article_test(article_id, question, question_type) values(663481,'明年我不會投國民黨了','other');
# insert into dcard_article_test(article_id, question, question_type) values(224158338,'請問','other');
# insert into dcard_article_test(article_id, question, question_type) values(51072,'我也想要啊～','other');
# insert into dcard_article_test(article_id, question, question_type) values(302901,'苗栗縣65年來首家影城開幕　民眾搶99元票清晨4點排隊','other');
# insert into dcard_article_test(article_id, question, question_type) values(225283744,'凡士林 限時兩件298','other');
# insert into dcard_article_test(article_id, question, question_type) values(229369789,'自製馬鈴薯蛋沙拉','other');
# insert into dcard_article_test(article_id, question, question_type) values(411019,'這樣戴口罩錯了嗎QQ','other');
# insert into dcard_article_test(article_id, question, question_type) values(629161,'沒有，因為你只想到自己','other');
# insert into dcard_article_test(article_id, question, question_type) values(230555776,'東吳的你繼續扣帽子沒關係','other');
# insert into dcard_article_test(article_id, question, question_type) values(230379624,'哪間大學的證券研究社很不錯？#社團','other');
# insert into dcard_article_test(article_id, question, question_type) values(228451875,'詢問護理產學合作','other');
# insert into dcard_article_test(article_id, question, question_type) values(224630396,'關於小團體言語霸凌#文有點長','other');
# insert into dcard_article_test(article_id, question, question_type) values(230327669,'機械系學士找得到只做一兩年的工作或實習嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224958520,'現在dcard和場外的差別','other');
# insert into dcard_article_test(article_id, question, question_type) values(226036569,'廈門航空空服員','other');
# insert into dcard_article_test(article_id, question, question_type) values(123579,'每日一善','other');
# insert into dcard_article_test(article_id, question, question_type) values(228450414,'診所薪水問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(226883090,'上班是件開心的事嗎','other');
# insert into dcard_article_test(article_id, question, question_type) values(199961133,'發發牢騷','what');
# insert into dcard_article_test(article_id, question, question_type) values(224177212,'公車憑空消失 非靈異','other');
# insert into dcard_article_test(article_id, question, question_type) values(225268765,'泡麵+……？！！','other');
# insert into dcard_article_test(article_id, question, question_type) values(997603,'辛苦了子瑜 對不起。','other');
# insert into dcard_article_test(article_id, question, question_type) values(230112038,'公投怎麼投？','how');
# insert into dcard_article_test(article_id, question, question_type) values(224383579,'有關打手槍的問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(225636613,'酸民交戰守則','other');
# insert into dcard_article_test(article_id, question, question_type) values(229070707,'西屯區 徵 長期工讀生','other');
# insert into dcard_article_test(article_id, question, question_type) values(872632,'查理布朗尼😒','other');
# insert into dcard_article_test(article_id, question, question_type) values(917731,' 甜鹹一次滿足 -  甜塔Ｘ鹹派','other');
# insert into dcard_article_test(article_id, question, question_type) values(228286856,'#工作の熱忱','other');
# insert into dcard_article_test(article_id, question, question_type) values(224596667,'關於屏東的各種大眾運輸','other');
# insert into dcard_article_test(article_id, question, question_type) values(226000079,' 甜甜粉紅少女樂X洋芋片','other');
# insert into dcard_article_test(article_id, question, question_type) values(658066,'畢業旅行～有哪些地方可以選擇呢','where');
# insert into dcard_article_test(article_id, question, question_type) values(225084801,'關於公關這個工作 2','other');
# insert into dcard_article_test(article_id, question, question_type) values(224721291,'日式彩虹胡麻烏龍麵','other');
# insert into dcard_article_test(article_id, question, question_type) values(224911186,'涉性侵少女 林依晨前男友遭訴','other');
# insert into dcard_article_test(article_id, question, question_type) values(1173439,'嘉義微食記分享 part2','other');
# insert into dcard_article_test(article_id, question, question_type) values(228808840,'請問例句翻譯','other');
# insert into dcard_article_test(article_id, question, question_type) values(224076541,'誠徵 工讀生','other');
# insert into dcard_article_test(article_id, question, question_type) values(207263,'有推薦的畢業禮物嘛','other');
# insert into dcard_article_test(article_id, question, question_type) values(227789040,'兩日遊吃了什麼😋','other');
# insert into dcard_article_test(article_id, question, question_type) values(225346291,'愛心餐點','other');
# insert into dcard_article_test(article_id, question, question_type) values(323534,'好囂張的醫生','other');
# insert into dcard_article_test(article_id, question, question_type) values(230346789,'台中市長盧秀燕就職典禮紀念品','other');
# insert into dcard_article_test(article_id, question, question_type) values(228544048,' 54新台灣 現在討論ptt柯p網軍','other');
# insert into dcard_article_test(article_id, question, question_type) values(225011266,'Mister Donut🍩 麗莎限量杯💕','other');
# insert into dcard_article_test(article_id, question, question_type) values(469405,'關於智齒','other');
# insert into dcard_article_test(article_id, question, question_type) values(224063044,'星座中毒','other');
# insert into dcard_article_test(article_id, question, question_type) values(226869874,'上班第二天就被資遣','other');
# insert into dcard_article_test(article_id, question, question_type) values(225188378,'錢該怎麼算','how');
# insert into dcard_article_test(article_id, question, question_type) values(10724,'如果成大研究所上了.......','other');
# insert into dcard_article_test(article_id, question, question_type) values(226501388,'豐原神岡地區推薦的日文補習班','other');
# insert into dcard_article_test(article_id, question, question_type) values(880306,'帶過牙套的前輩們請進','other');
# insert into dcard_article_test(article_id, question, question_type) values(229314482,'下定決心要跟慣老闆爭回權益 開調解會的注意事項','other');
# insert into dcard_article_test(article_id, question, question_type) values(99718,'關於痞子蔡........','other');
# insert into dcard_article_test(article_id, question, question_type) values(224073235,'支持國民黨不就是支持實質統一嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224677302,'真正的邊邊邊緣人','other');
# insert into dcard_article_test(article_id, question, question_type) values(229270235,'#第一次開戶','other');
# insert into dcard_article_test(article_id, question, question_type) values(27251,'夢研究專家詢問','other');
# insert into dcard_article_test(article_id, question, question_type) values(229542883,'花旗饗樂卡','other');
# insert into dcard_article_test(article_id, question, question_type) values(227202729,'從新聞觀察到的台日差異＃文化','other');
# insert into dcard_article_test(article_id, question, question_type) values(1048981,'女人的警世劇場','other');
# insert into dcard_article_test(article_id, question, question_type) values(663806,'智力測驗','what');
# insert into dcard_article_test(article_id, question, question_type) values(225377603,'俄便宜瑪德蓮蛋糕','other');
# insert into dcard_article_test(article_id, question, question_type) values(228565014,'回應陳芳明 呂秀蓮：沒說柯文哲通匪','other');
# insert into dcard_article_test(article_id, question, question_type) values(227472523,'#泡麵','other');
# insert into dcard_article_test(article_id, question, question_type) values(493570,'臺北7-11的儲幹待遇','other');
# insert into dcard_article_test(article_id, question, question_type) values(225436493,'站著吃拉麵in台灣','other');
# insert into dcard_article_test(article_id, question, question_type) values(33906,'團康活動~~~','other');
# insert into dcard_article_test(article_id, question, question_type) values(225123437,'跪求推薦好牙醫','other');
# insert into dcard_article_test(article_id, question, question_type) values(224173068,'中信兄弟封王！','other');
# insert into dcard_article_test(article_id, question, question_type) values(225440594,'送愛心鞋盒到偏鄉','other');
# insert into dcard_article_test(article_id, question, question_type) values(562626,'台灣學術界被政治荼毒？與清大某領袖','other');
# insert into dcard_article_test(article_id, question, question_type) values(12439,'年紀越大，相聚越少','other');
# insert into dcard_article_test(article_id, question, question_type) values(224391331,'拉K的味道怎麼辨別','how');
# insert into dcard_article_test(article_id, question, question_type) values(226943278,'素食「點頭蔬食」','other');
# insert into dcard_article_test(article_id, question, question_type) values(224893298,'求10/3號嶺東路上海賊拉麵附近的行車紀錄器','other');
# insert into dcard_article_test(article_id, question, question_type) values(229965637,'不後悔提攜侯友宜當警政署長 蘇貞昌：他確有執行力','other');
# insert into dcard_article_test(article_id, question, question_type) values(230027242,'丁守中民調差距不到3%　柯文哲坦言：藍的拉5%、綠的拉5%，我就倒了','other');
# insert into dcard_article_test(article_id, question, question_type) values(226304695,'致和我一樣正在經歷這些的人','other');
# insert into dcard_article_test(article_id, question, question_type) values(228176592,'2018立榮台南運務助理','other');
# insert into dcard_article_test(article_id, question, question_type) values(254681,'租屋困擾','other');
# insert into dcard_article_test(article_id, question, question_type) values(153357,'室友帶妹子回來住','other');
# insert into dcard_article_test(article_id, question, question_type) values(225502735,'高雄正顎手術推薦','other');
# insert into dcard_article_test(article_id, question, question_type) values(230181864,'問一下網軍','other');
# insert into dcard_article_test(article_id, question, question_type) values(228486994,'國泰被盜刷追溯期','other');
# insert into dcard_article_test(article_id, question, question_type) values(228186956,'✨✨"瑞士基金相關公司正在推出加密貨幣相關產品"✨✨
#  #虛擬貨幣','other');
# insert into dcard_article_test(article_id, question, question_type) values(230136489,'柯批沒讓我失望','other');
# insert into dcard_article_test(article_id, question, question_type) values(227855153,'好想罷工喔!為甚麼都沒人發起?','other');
# insert into dcard_article_test(article_id, question, question_type) values(230113418,'高雄清晨傳氣爆「柏油路炸開」波及車輛','other');
# insert into dcard_article_test(article_id, question, question_type) values(228445714,'大一年紀 開加盟店','other');
# insert into dcard_article_test(article_id, question, question_type) values(224540761,'生巧塔,抹茶塔&檸檬糖霜蛋糕','other');
# insert into dcard_article_test(article_id, question, question_type) values(92426671,'整棟只有一個電表 那電費大家會如何算呢','how');
# insert into dcard_article_test(article_id, question, question_type) values(46079,'怎麼判別甲甲','how');
# insert into dcard_article_test(article_id, question, question_type) values(228733210,'蒸肉圓','other');
# insert into dcard_article_test(article_id, question, question_type) values(224758219,'#雲','other');
# insert into dcard_article_test(article_id, question, question_type) values(224922132,'面試被公司放鳥','other');
# insert into dcard_article_test(article_id, question, question_type) values(77770,'公館附近推薦餐廳','other');
# insert into dcard_article_test(article_id, question, question_type) values(224339416,'桃園廚具','other');
# insert into dcard_article_test(article_id, question, question_type) values(230101094,'韓總沒建設性嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(78883,'"涼"咖啡~','other');
# insert into dcard_article_test(article_id, question, question_type) values(16632,'被同班同學告白會有什麼反應?','other');
# insert into dcard_article_test(article_id, question, question_type) values(1020712,'手作雞排文是中國網友的創意？','other');
# insert into dcard_article_test(article_id, question, question_type) values(205665734,'台灣為何都不栽培籃球選手?','other');
# insert into dcard_article_test(article_id, question, question_type) values(849014,'投小黨的意義？','other');
# insert into dcard_article_test(article_id, question, question_type) values(225398708,'民宿相關調查','other');
# insert into dcard_article_test(article_id, question, question_type) values(224522989,'哈根達斯應徵','other');
# insert into dcard_article_test(article_id, question, question_type) values(228417366,'看看台灣人的處理方式#國道攔車','other');
# insert into dcard_article_test(article_id, question, question_type) values(226722023,'澎湖美食實吃食記','other');
# insert into dcard_article_test(article_id, question, question_type) values(230684476,'Line Pay、黑狗卡核卡','other');
# insert into dcard_article_test(article_id, question, question_type) values(1052147,'將心比心的概念','other');
# insert into dcard_article_test(article_id, question, question_type) values(229577155,'Uber內部人員福利制度','other');
# insert into dcard_article_test(article_id, question, question_type) values(61390446,'對隨機攻擊事件的看法','other');
# insert into dcard_article_test(article_id, question, question_type) values(224658723,'有沒有躺著玩手機結果掉下來打到自己臉的掛','other');
# insert into dcard_article_test(article_id, question, question_type) values(228253086,'別相信任何人','other');
# insert into dcard_article_test(article_id, question, question_type) values(216768478,'#圖🍲🍲鮮蔬雞肉燴飯🍲🍲','other');
# insert into dcard_article_test(article_id, question, question_type) values(229913174,'幫民進黨思考兩岸新套路','other');
# insert into dcard_article_test(article_id, question, question_type) values(216760,'Re: 「請孫文、黨旗、黨歌退出校園」公民行動連署','other');
# insert into dcard_article_test(article_id, question, question_type) values(1000643,'努力減肥想考空服','other');
# insert into dcard_article_test(article_id, question, question_type) values(227498538,'謊言軍隊（文長','other');
# insert into dcard_article_test(article_id, question, question_type) values(230194224,'華航飛機餐','other');
# insert into dcard_article_test(article_id, question, question_type) values(225210291,'求指點迷津文長','other');
# insert into dcard_article_test(article_id, question, question_type) values(854579,'罷免禁止宣傳規定 中選會認定「不違憲」','other');
# insert into dcard_article_test(article_id, question, question_type) values(224869452,'你他媽再亂炸我啊','other');
# insert into dcard_article_test(article_id, question, question_type) values(12739,'倒閣不成 藍：恢復理性國會 綠：關閉朝野','other');
# insert into dcard_article_test(article_id, question, question_type) values(42988,'時事廢文-兒選情告急 父口出惡言 連戰 罵柯文哲混蛋','other');
# insert into dcard_article_test(article_id, question, question_type) values(224062835,'有人知道野貓都吃什麼嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224851956,'驚喜蛋','other');
# insert into dcard_article_test(article_id, question, question_type) values(229571856,'神出一位美麗的店經理','other');
# insert into dcard_article_test(article_id, question, question_type) values(229859064,'比特幣風險研究','other');
# insert into dcard_article_test(article_id, question, question_type) values(32365,'挑戰咖哩鍋貼','other');
# insert into dcard_article_test(article_id, question, question_type) values(532770,'教學)紙膠繪','other');
# insert into dcard_article_test(article_id, question, question_type) values(803629,'吃吃雯-肯德基經典雞腿堡','other');
# insert into dcard_article_test(article_id, question, question_type) values(227420770,'台南 碳佐麻里分享２','other');
# insert into dcard_article_test(article_id, question, question_type) values(224525760,'/ 2016夏','other');
# insert into dcard_article_test(article_id, question, question_type) values(229605639,'菁英會話老師推薦','other');
# insert into dcard_article_test(article_id, question, question_type) values(1004846,'關於還有四個月任期','other');
# insert into dcard_article_test(article_id, question, question_type) values(198787006,'#圖便宜又大碗的','other');
# insert into dcard_article_test(article_id, question, question_type) values(879034,'我支持秒買秒退 純屬個人看法','other');
# insert into dcard_article_test(article_id, question, question_type) values(42390,'台北下著雨，餓著肚子的人何處去?','where');
# insert into dcard_article_test(article_id, question, question_type) values(20802,'冰與火之歌','other');
# insert into dcard_article_test(article_id, question, question_type) values(15622770,'被撕碎也要拼回！德國這樣對待機密檔案','other');
# insert into dcard_article_test(article_id, question, question_type) values(11831,'有關學校的期末評鑑制度','other');
# insert into dcard_article_test(article_id, question, question_type) values(1221012,'蘑菇飯 :D','other');
# insert into dcard_article_test(article_id, question, question_type) values(1051401,'大家有沒有看過這個 #梅長蘇的朋友圈','other');
# insert into dcard_article_test(article_id, question, question_type) values(812558,'張忠謀：缺電、環保抗爭 台灣2大隱憂2017限電危機衝擊大','other');
# insert into dcard_article_test(article_id, question, question_type) values(224040519,'狄卡自介','other');
# insert into dcard_article_test(article_id, question, question_type) values(226739760,'2017長榮地勤考試分享','other');
# insert into dcard_article_test(article_id, question, question_type) values(102347,'imgur的使用方法','other');
# insert into dcard_article_test(article_id, question, question_type) values(382297,'《Samtripay-馬卡龍夾巧克力甘納許》','other');
# insert into dcard_article_test(article_id, question, question_type) values(230231797,'菜瓜布蛋糕? 能吃嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224902305,' 設計科的潛規則','other');
# insert into dcard_article_test(article_id, question, question_type) values(228159671,'智利櫻桃現在市價大約多少呢？','how_many');
# insert into dcard_article_test(article_id, question, question_type) values(224469474,'智慧手機問世前的你我','other');
# insert into dcard_article_test(article_id, question, question_type) values(225922230,'日本秋葉原 哈蜜瓜麵包','other');
# insert into dcard_article_test(article_id, question, question_type) values(917419,'鋼筆新入坑大家好','other');
# insert into dcard_article_test(article_id, question, question_type) values(702202,'台中 爵士音樂節','other');
# insert into dcard_article_test(article_id, question, question_type) values(224582450,'為什麼未滿18歲不能看限制級電影','why');
# insert into dcard_article_test(article_id, question, question_type) values(224188964,'嚇到了','other');
# insert into dcard_article_test(article_id, question, question_type) values(24992,'用雙手傳遞溫暖—愛上手作的開端','other');
# insert into dcard_article_test(article_id, question, question_type) values(226768531,'原來討厭你的很多人','other');
# insert into dcard_article_test(article_id, question, question_type) values(1196083,'「產品4.0」時代：日本再興起的機會','other');
# insert into dcard_article_test(article_id, question, question_type) values(11593,' 林葦茹情牽448億金童 矽谷男友列全球12大富豪','other');
# insert into dcard_article_test(article_id, question, question_type) values(142193601,'自製１００元丼飯','other');
# insert into dcard_article_test(article_id, question, question_type) values(227655702,'食品科技系（詢','other');
# insert into dcard_article_test(article_id, question, question_type) values(230289005,'關於昇恆昌刷中信LINEPAY','other');
# insert into dcard_article_test(article_id, question, question_type) values(225472347,'立院翻牆後專訪張茂松》早知道尤美女要強行闖關，但教會還是要去，因為這是做該做的事！','other');
# insert into dcard_article_test(article_id, question, question_type) values(226721209,'星巴克應徵','other');
# insert into dcard_article_test(article_id, question, question_type) values(230140744,'侯友宜這個得票率到底是？','other');
# insert into dcard_article_test(article_id, question, question_type) values(71487006,'如果明天完成不了報告會不會畢不了業','other');
# insert into dcard_article_test(article_id, question, question_type) values(224973324,'大家畢業多久才找到工作?','status');
# insert into dcard_article_test(article_id, question, question_type) values(1015326,'服飾業的悲歌','other');
# insert into dcard_article_test(article_id, question, question_type) values(224665548,'聊聊最近的煩惱吧。','other');
# insert into dcard_article_test(article_id, question, question_type) values(201422,'台北大屯山．月出','other');
# insert into dcard_article_test(article_id, question, question_type) values(227281215,'法文課','other');
# insert into dcard_article_test(article_id, question, question_type) values(560916,'關於系會費','other');
# insert into dcard_article_test(article_id, question, question_type) values(39845,'關於ACM','other');
# insert into dcard_article_test(article_id, question, question_type) values(230115021,'永吉路烤肉飯/烤香菇甜不辣超讚！','other');
# insert into dcard_article_test(article_id, question, question_type) values(228293011,'科技公司工程師','other');
# insert into dcard_article_test(article_id, question, question_type) values(225128301,'有沒有人牽FT6的人哇？','other');
# insert into dcard_article_test(article_id, question, question_type) values(227799326,'  大家有在玩股票嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(225700105,'給有玩Tinder的一些建議','other');
# insert into dcard_article_test(article_id, question, question_type) values(224591062,'美食求救😭','other');
# insert into dcard_article_test(article_id, question, question_type) values(226938768,'台灣太自由？警察沒尊嚴？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224690623,'更簡單雕花教學♥','other');
# insert into dcard_article_test(article_id, question, question_type) values(225321039,'保麗龍飲料杯','other');
# insert into dcard_article_test(article_id, question, question_type) values(229343402,'從金厦通水典禮事件回看金門的「前世今生」','other');
# insert into dcard_article_test(article_id, question, question_type) values(557396,'沒機車宜蘭兩天一夜','other');
# insert into dcard_article_test(article_id, question, question_type) values(230270919,'詢問 外師助理工作心得','other');
# insert into dcard_article_test(article_id, question, question_type) values(229217314,'高雄 宵夜推薦分享！超好吃😍','other');
# insert into dcard_article_test(article_id, question, question_type) values(962663,'聯考數學的手下敗將','other');
# insert into dcard_article_test(article_id, question, question_type) values(100344,'想問:自動傘壞了,會拿去修嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224453749,'北部飲水問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(988319,'可以不要挺大麻嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224631271,'速可達１２５比較','other');
# insert into dcard_article_test(article_id, question, question_type) values(1114017,'聯合國將禁止日本性暴力ACG','other');
# insert into dcard_article_test(article_id, question, question_type) values(224787551,'同理心？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224464674,'蝦仁炒飯！！！GAN','other');
# insert into dcard_article_test(article_id, question, question_type) values(228346629,'  金門古法道地蚵仔煎','other');
# insert into dcard_article_test(article_id, question, question_type) values(40475,'深夜串詞－曖昧','other');
# insert into dcard_article_test(article_id, question, question_type) values(226826924,'7/18 乳摸','other');
# insert into dcard_article_test(article_id, question, question_type) values(225777148,'半年特休','other');
# insert into dcard_article_test(article_id, question, question_type) values(1088612,'IG按愛心分析','other');
# insert into dcard_article_test(article_id, question, question_type) values(225616085,'抹茶控快看😽😽','other');
# insert into dcard_article_test(article_id, question, question_type) values(225152108,'洗車完就下雨','other');
# insert into dcard_article_test(article_id, question, question_type) values(230520240,'不要空汙才選韓國瑜，結果現在石化業要回來？','other');
# insert into dcard_article_test(article_id, question, question_type) values(518096,'騎車習慣大不同？　北愛衝、中緩慢、南隨性','other');
# insert into dcard_article_test(article_id, question, question_type) values(224736192,'有人在全聯或其他大賣場上過班嗎','other');
# insert into dcard_article_test(article_id, question, question_type) values(1140879,'怎麼辦','other');
# insert into dcard_article_test(article_id, question, question_type) values(230444706,'跟日本統一的優點（亂','other');
# insert into dcard_article_test(article_id, question, question_type) values(194028176,'從小就沒什麼大志','other');
# insert into dcard_article_test(article_id, question, question_type) values(230070742,'高雄人的痛？','other');
# insert into dcard_article_test(article_id, question, question_type) values(230381239,'一個車輪餅的故事','other');
# insert into dcard_article_test(article_id, question, question_type) values(229961431,'在麥當勞app留負評','other');
# insert into dcard_article_test(article_id, question, question_type) values(227026962,'鮨樂海鮮市場收銀人員','other');
# insert into dcard_article_test(article_id, question, question_type) values(226690238,'考了一隻雞','other');
# insert into dcard_article_test(article_id, question, question_type) values(241333,'龔重安保全轉宅急便　前同事：他人很好','other');
# insert into dcard_article_test(article_id, question, question_type) values(224065277,'手機板卡友的背景顏色','other');
# insert into dcard_article_test(article_id, question, question_type) values(1111819,'海龜湯','other');
# insert into dcard_article_test(article_id, question, question_type) values(269275,'服務業之被害妄想症-錄音筆篇','other');
# insert into dcard_article_test(article_id, question, question_type) values(43546,'很難再看到她的動態了，因為...','other');
# insert into dcard_article_test(article_id, question, question_type) values(224053241,'祝Dcard工程師早日康復','other');
# insert into dcard_article_test(article_id, question, question_type) values(230051496,'漫威之父史丹李逝世','other');
# insert into dcard_article_test(article_id, question, question_type) values(225981064,'有人上過 engoo 或是 AmazingTalker 嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(230508627,'檢視第三勢力民粹化','other');
# insert into dcard_article_test(article_id, question, question_type) values(617437,'討厭哥哥的小孩','other');
# insert into dcard_article_test(article_id, question, question_type) values(225372410,'茉香奶綠餅乾🍪','other');
# insert into dcard_article_test(article_id, question, question_type) values(10249,'真的有這麼好的事嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(736050,'他馬的空氣汙染','other');
# insert into dcard_article_test(article_id, question, question_type) values(226500102,' 不適合初學的蛋糕','other');
# insert into dcard_article_test(article_id, question, question_type) values(230102778,'關於公投第16案','other');
# insert into dcard_article_test(article_id, question, question_type) values(225917484,'日本麥當勞限定 櫻花冰炫風','other');
# insert into dcard_article_test(article_id, question, question_type) values(1106145,'AFC 中華 對 越南','other');
# insert into dcard_article_test(article_id, question, question_type) values(226887279,'校園實習生','other');
# insert into dcard_article_test(article_id, question, question_type) values(1136032,'了解各位對於直銷的看法','other');
# insert into dcard_article_test(article_id, question, question_type) values(740462,'免烤Oreo乳酪蛋糕  少圖+文長，很多碎碎念','other');
# insert into dcard_article_test(article_id, question, question_type) values(191473243,' 回家前當然要在臺南吃一份好吃的早餐啊!','other');
# insert into dcard_article_test(article_id, question, question_type) values(607920,'服飾店員的工作沒有很夢幻⋯獻給想嘗試的人 ','other');
# insert into dcard_article_test(article_id, question, question_type) values(229319560,'家樂福浮誇環保袋','other');
# insert into dcard_article_test(article_id, question, question_type) values(227161435,'螺螄粉大評比','other');
# insert into dcard_article_test(article_id, question, question_type) values(16264,'營隊營歌早操歌推薦','other');
# insert into dcard_article_test(article_id, question, question_type) values(59877952,'護童反廢死　白玫瑰協會號召萬人上街','other');
# insert into dcard_article_test(article_id, question, question_type) values(30497,'媽，他不是你媳婦喇....','other');
# insert into dcard_article_test(article_id, question, question_type) values(752598,'《荷蘭精釀啤酒介紹》De Molen Mooi & Meedogenloos','other');
# insert into dcard_article_test(article_id, question, question_type) values(224094332,'Ig停用帳號後重啟？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224527476,'有人也想考郵局嗎','other');
# insert into dcard_article_test(article_id, question, question_type) values(225348388,'國定7天假','other');
# insert into dcard_article_test(article_id, question, question_type) values(226752341,'美艦停台，中籲小心','other');
# insert into dcard_article_test(article_id, question, question_type) values(230105831,'關於高雄市長的話題','other');
# insert into dcard_article_test(article_id, question, question_type) values(224069845,'巨無霸蚊子','other');
# insert into dcard_article_test(article_id, question, question_type) values(10097,'每次開Dcard','other');
# insert into dcard_article_test(article_id, question, question_type) values(227436047,'中共不武統不是因為武統不了','other');
# insert into dcard_article_test(article_id, question, question_type) values(47511,'Re: 要抓住女人的心就要先抓住她的胃~','other');
# insert into dcard_article_test(article_id, question, question_type) values(12212,'推薦靠反應和動態視力的小遊戲','other');
# insert into dcard_article_test(article_id, question, question_type) values(180156259,'別再怪社會上一堆要包包的女人了, 根本是我們男生害的','other');
# insert into dcard_article_test(article_id, question, question_type) values(229196131,'公司薪資開戶','other');
# insert into dcard_article_test(article_id, question, question_type) values(229770650,'支付寶 定 支那寶','other');
# insert into dcard_article_test(article_id, question, question_type) values(228076861,'花枝意麵和鱔魚意麵那個麵','other');
# insert into dcard_article_test(article_id, question, question_type) values(894175,'發問！附圖 越獄風雲裡面的花','other');
# insert into dcard_article_test(article_id, question, question_type) values(230053358,'大家來試試11/24的結果如何~','other');
# insert into dcard_article_test(article_id, question, question_type) values(230031927,'職缺薪無4萬須揭示 工商界：恐損議薪空間','other');
# insert into dcard_article_test(article_id, question, question_type) values(44736,'劍靈','where');
# insert into dcard_article_test(article_id, question, question_type) values(226568920,'＃新聞 被控權勢性侵3女 儀隊教練2審判刑1年半','other');
# insert into dcard_article_test(article_id, question, question_type) values(225417755,'我家也有漸層飲料🌸','other');
# insert into dcard_article_test(article_id, question, question_type) values(225802093,'請問這是哪家的甜點？','other');
# insert into dcard_article_test(article_id, question, question_type) values(229390019,'怎樣才算是好的批評?','other');
# insert into dcard_article_test(article_id, question, question_type) values(225412322,'虎姑婆是吃手指還是吃腳趾(?','other');
# insert into dcard_article_test(article_id, question, question_type) values(227790042,'巧克力版本味覺糖🍇🍫','other');
# insert into dcard_article_test(article_id, question, question_type) values(229286094,'帝菲爾國際有限公司','other');
# insert into dcard_article_test(article_id, question, question_type) values(226803384,'旅店遇到的各種客人','other');
# insert into dcard_article_test(article_id, question, question_type) values(148387,'地震了，要逃嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(229888671,'有沒有人覺得韓粉多出很多','other');
# insert into dcard_article_test(article_id, question, question_type) values(225056188,'更)))你沒看過的螃蟹炒飯','other');
# insert into dcard_article_test(article_id, question, question_type) values(216334,'貓咪明信片>w<','other');
# insert into dcard_article_test(article_id, question, question_type) values(81192,'受刑人的聲明有啥好笑','other');
# insert into dcard_article_test(article_id, question, question_type) values(261220,'死刑，突然其來的震撼','other');
# insert into dcard_article_test(article_id, question, question_type) values(224374928,'妳最受不了妳男朋友做什麼？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224524957,'人手拿哀鳳不過就是小確辛','other');
# insert into dcard_article_test(article_id, question, question_type) values(1056577,'討厭師大檢察官的到底是抱持著什麼樣的想法??','other');
# insert into dcard_article_test(article_id, question, question_type) values(227556810,'廣告配唱、DEMO歌手接案','other');
# insert into dcard_article_test(article_id, question, question_type) values(948706,'關於阿嬤的藥','other');
# insert into dcard_article_test(article_id, question, question_type) values(225696831,'擦肩而過','other');
# insert into dcard_article_test(article_id, question, question_type) values(47727586,'Re 不是歧視肥宅，只是純粹不喜歡動漫','other');
# insert into dcard_article_test(article_id, question, question_type) values(181809,'自己做超豐盛晚餐','other');
# insert into dcard_article_test(article_id, question, question_type) values(124018699,'轉  爽翻了！台灣詐欺犯抵中國　全自由了','other');
# insert into dcard_article_test(article_id, question, question_type) values(224640892,'夜市無理取鬧的阿姨','other');
# insert into dcard_article_test(article_id, question, question_type) values(1208024,'可以不迷信但千萬不要不信邪','other');
# insert into dcard_article_test(article_id, question, question_type) values(230139129,'公投違法，工作人員引導民眾投票','other');
# insert into dcard_article_test(article_id, question, question_type) values(229497286,'港式飲茶吃到飽','other');
# insert into dcard_article_test(article_id, question, question_type) values(229108338,'時事，世界難民日','other');
# insert into dcard_article_test(article_id, question, question_type) values(224881058,'水煮蛋新吃法','other');
# insert into dcard_article_test(article_id, question, question_type) values(117980,' 信尾的問候','other');
# insert into dcard_article_test(article_id, question, question_type) values(1171617,'新手作品','other');
# insert into dcard_article_test(article_id, question, question_type) values(225990196,'滴卡要不要乾脆開個解籤版','other');
# insert into dcard_article_test(article_id, question, question_type) values(70076,'練習電子琴的教材推薦','other');
# insert into dcard_article_test(article_id, question, question_type) values(224130764,'學霸不容易加到卡友?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224455264,'暮光女出櫃認愛 和女人交往更愉快','other');
# insert into dcard_article_test(article_id, question, question_type) values(230459623,'誠徵臉書小幫手','other');
# insert into dcard_article_test(article_id, question, question_type) values(225780118,'的時候','other');
# insert into dcard_article_test(article_id, question, question_type) values(227306866,'聯邦銀行 925報到','other');
# insert into dcard_article_test(article_id, question, question_type) values(229821746,'韓國巧克力派','other');
# insert into dcard_article_test(article_id, question, question_type) values(230290533,'日式豬排丼','other');
# insert into dcard_article_test(article_id, question, question_type) values(225063565,'我覺得某個T講的很有道理','other');
# insert into dcard_article_test(article_id, question, question_type) values(227779487,'簡易食譜','other');
# insert into dcard_article_test(article_id, question, question_type) values(1169782,'每天早上的鬧鐘⋯','other');
# insert into dcard_article_test(article_id, question, question_type) values(224864846,'蟑螂其實很可愛','other');
# insert into dcard_article_test(article_id, question, question_type) values(114856,'〖舞會】White & Black 懷特 · 柏萊克','other');
# insert into dcard_article_test(article_id, question, question_type) values(225392340,'天冷就是要吃草莓之草莓麻糬🍓','other');
# insert into dcard_article_test(article_id, question, question_type) values(225094451,'詢問經驗','other');
# insert into dcard_article_test(article_id, question, question_type) values(107166,'Line的通知跳針','other');
# insert into dcard_article_test(article_id, question, question_type) values(227969176,'黑巧克力','other');
# insert into dcard_article_test(article_id, question, question_type) values(229277212,'你對「廣告置入新聞」有什麼看法呢？','other');
# insert into dcard_article_test(article_id, question, question_type) values(31589,'體重困擾','other');
# insert into dcard_article_test(article_id, question, question_type) values(168575995,'保護自己家的弟妹','other');
# insert into dcard_article_test(article_id, question, question_type) values(224159178,'＃圖   鹹豆漿在國外自己做！','other');
# insert into dcard_article_test(article_id, question, question_type) values(228260796,'強震釀災　藍美女議員發文：執政黨會不會倒不知道…','other');
# insert into dcard_article_test(article_id, question, question_type) values(134266895,'去冰奶跟涼奶？','other');
# insert into dcard_article_test(article_id, question, question_type) values(226216975,'有在花月嵐打工過的同學嗎','other');
# insert into dcard_article_test(article_id, question, question_type) values(228311653,'地球上最強媽媽 - 專業級年菜','other');
# insert into dcard_article_test(article_id, question, question_type) values(228562514,'柯p訪毛故居 呂秀蓮說柯p有紅光..？','other');
# insert into dcard_article_test(article_id, question, question_type) values(229326152,'黑咖啡','other');
# insert into dcard_article_test(article_id, question, question_type) values(228203380,'黑特 竹北騰x公司反推','other');
# insert into dcard_article_test(article_id, question, question_type) values(336093,'能陪女神考機車 非常開心','other');
# insert into dcard_article_test(article_id, question, question_type) values(230040938,'習近平：要像繡花一樣治理城市','other');
# insert into dcard_article_test(article_id, question, question_type) values(205384,'求大家把我罵醒','other');
# insert into dcard_article_test(article_id, question, question_type) values(228821522,'受訓期間','other');
# insert into dcard_article_test(article_id, question, question_type) values(224263805,'專訪苑舉正教授導讀《民主在退潮》','other');
# insert into dcard_article_test(article_id, question, question_type) values(225257127,'日常菜色','other');
# insert into dcard_article_test(article_id, question, question_type) values(224383788,'台灣怎麼了?','other');
# insert into dcard_article_test(article_id, question, question_type) values(846416,'北科與北商','other');
# insert into dcard_article_test(article_id, question, question_type) values(229733337,'找工作','other');
# insert into dcard_article_test(article_id, question, question_type) values(225661711,'一例一修 寶寶的錢也收','other');
# insert into dcard_article_test(article_id, question, question_type) values(839410,'問》總是烤出很硬的塔皮','other');
# insert into dcard_article_test(article_id, question, question_type) values(45353659,'論愛','other');
# insert into dcard_article_test(article_id, question, question_type) values(1090871,'少了一位親人的年夜飯...','other');
# insert into dcard_article_test(article_id, question, question_type) values(225984776,'公務員真的好嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224878041,' 牙縫痠痠癢癢','other');
# insert into dcard_article_test(article_id, question, question_type) values(230538749,'彰化女嬰猝死 托嬰中心遭1600顆蛋夜襲','other');
# insert into dcard_article_test(article_id, question, question_type) values(224831612,'微醉 梨子雞尾酒','other');
# insert into dcard_article_test(article_id, question, question_type) values(15401,'自製手機/平板小遊戲','other');
# insert into dcard_article_test(article_id, question, question_type) values(224372007,'刺激排便的食物','other');
# insert into dcard_article_test(article_id, question, question_type) values(16583,'值得思考一下的名冊','other');
# insert into dcard_article_test(article_id, question, question_type) values(230125649,'吉麥有小孩嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(229205782,'誰要吃早餐','other');
# insert into dcard_article_test(article_id, question, question_type) values(228535846,'好想吃吃看壽司郎','other');
# insert into dcard_article_test(article_id, question, question_type) values(1034398,'總統FB','other');
# insert into dcard_article_test(article_id, question, question_type) values(16206,'最近CPBL熱身賽的主播跟球評到底是誰....?','who');
# insert into dcard_article_test(article_id, question, question_type) values(226899933,'少少的面試心得','other');
# insert into dcard_article_test(article_id, question, question_type) values(228399610,'聚餐在貳樓的二樓','other');
# insert into dcard_article_test(article_id, question, question_type) values(224407608,'某個樂團MV的神運鏡','other');
# insert into dcard_article_test(article_id, question, question_type) values(226019395,'捷運公館站part1','other');
# insert into dcard_article_test(article_id, question, question_type) values(228348079,'標的 敬鵬2355','other');
# insert into dcard_article_test(article_id, question, question_type) values(1182172,'醬燒秋刀魚','other');
# insert into dcard_article_test(article_id, question, question_type) values(224300164,'留長髮','other');
# insert into dcard_article_test(article_id, question, question_type) values(204334751,'男愛妹子 女愛帥哥 👄','other');
# insert into dcard_article_test(article_id, question, question_type) values(229707325,'資方嘴臉','other');
# insert into dcard_article_test(article_id, question, question_type) values(228979492,'請教英文文法問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(54992,'一陣子沒看到寵物文了  大家來分享一下自己家的寵物吧','other');
# insert into dcard_article_test(article_id, question, question_type) values(229195325,'雙牛沙拉佐香芒莎莎醬','other');
# insert into dcard_article_test(article_id, question, question_type) values(228508228,'711消失的食物😫😫😫','other');
# insert into dcard_article_test(article_id, question, question_type) values(226644646,'這個甜點哪裡買的到呢','where');
# insert into dcard_article_test(article_id, question, question_type) values(225000397,'保險小故事','other');
# insert into dcard_article_test(article_id, question, question_type) values(229423221,'驅逐出場','what');
# insert into dcard_article_test(article_id, question, question_type) values(225122718,'築地鮮魚之鮭魚肚丼飯','other');
# insert into dcard_article_test(article_id, question, question_type) values(224756562,'林全施政報告 參與太陽花團體批「偷渡服貿」','other');
# insert into dcard_article_test(article_id, question, question_type) values(229332504,'聽袂落企！台灣不缺水電？　賴清德：缺的是信心','other');
# insert into dcard_article_test(article_id, question, question_type) values(1034058,'求摩斯打工分享','other');
# insert into dcard_article_test(article_id, question, question_type) values(227121718,'全聯打工不幫忙衝業績就欺負你','other');
# insert into dcard_article_test(article_id, question, question_type) values(191017,'有誰去過大安元氣堂中醫診所??','other');
# insert into dcard_article_test(article_id, question, question_type) values(230130747,'林佳龍市長你後悔嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(1132472,'申請護照要半年內照片，可以拿以前的嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(228457021,'#翻譯疑問','other');
# insert into dcard_article_test(article_id, question, question_type) values(228955741,'台新Richart 金融visa卡','other');
# insert into dcard_article_test(article_id, question, question_type) values(713875,'開大牛瞬間帥10倍？','other');
# insert into dcard_article_test(article_id, question, question_type) values(70496336,'大學想賺大錢！從這裡陌生開發很難！','other');
# insert into dcard_article_test(article_id, question, question_type) values(230151366,'傻眼被劃假','other');
# insert into dcard_article_test(article_id, question, question_type) values(1015224,'實習醫師日記','other');
# insert into dcard_article_test(article_id, question, question_type) values(757389,'切割「公道伯」太粗暴？王金平臉書變這樣','other');
# insert into dcard_article_test(article_id, question, question_type) values(229604449,'首爾三清洞、仁寺洞Rain#韓國','other');
# insert into dcard_article_test(article_id, question, question_type) values(215635,'大家喜歡男生怎樣的髮型呢?','other');
# insert into dcard_article_test(article_id, question, question_type) values(230154551,'臺獨的人真的很奇怪','other');
# insert into dcard_article_test(article_id, question, question_type) values(224051384,'時間去哪了？','other');
# insert into dcard_article_test(article_id, question, question_type) values(224982156,'猶豫要不要辭職','other');
# insert into dcard_article_test(article_id, question, question_type) values(224977166,'為民服務!?你們一直都找錯對象了','other');
# insert into dcard_article_test(article_id, question, question_type) values(228829000,'大谷翔平那件灰色T-shirt一般外面有賣嗎','other');
# insert into dcard_article_test(article_id, question, question_type) values(118283,'什麼？再說一次！！翟神來了？！','other');
# insert into dcard_article_test(article_id, question, question_type) values(1076383,'皮包被搶時請看','other');
# insert into dcard_article_test(article_id, question, question_type) values(12733265,'真的窮到不知如何是好，求分享','how');
# insert into dcard_article_test(article_id, question, question_type) values(139992012,'抽卡友!','other');
# ...
# insert into dcard_article_test(article_id, question, question_type) values(347756,'李顯龍栽在16歲公民手上','other');
# insert into dcard_article_test(article_id, question, question_type) values(230120177,'公投通知單不知道寄到哪裡去了😭😭','where');
# insert into dcard_article_test(article_id, question, question_type) values(229029167,'覺得打工時數太少','other');
# insert into dcard_article_test(article_id, question, question_type) values(230500492,'藏壽司','other');
# insert into dcard_article_test(article_id, question, question_type) values(226547192,'請教英文翻譯問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(228952699,'蜜橙磅蛋糕','other');
# insert into dcard_article_test(article_id, question, question_type) values(228673187,'剛到職，卻想離職！','other');
# insert into dcard_article_test(article_id, question, question_type) values(229950650,'其邁哥的政見 一通電話醫生護士到家服務','other');
# insert into dcard_article_test(article_id, question, question_type) values(226695405,'問 工時問題','other');
# insert into dcard_article_test(article_id, question, question_type) values(761886,'只關心巴黎錯了嗎？　－　請別苛責只關心巴黎的你我','other');
# insert into dcard_article_test(article_id, question, question_type) values(228814961,'BAKE CODE 烘焙密碼西湖店','other');
# insert into dcard_article_test(article_id, question, question_type) values(706757,'Re 陸生健保','other');
# insert into dcard_article_test(article_id, question, question_type) values(896728,'這我也不知道該說啥  就讓大家來說說','other');
# insert into dcard_article_test(article_id, question, question_type) values(226937327,'中國騰訊QQ聊天機械人「造反」 官方關閉服務','other');
# insert into dcard_article_test(article_id, question, question_type) values(3367509,'魯魯的 豆腐雞肉蓋飯 阿--------嘶-----------','other');
# insert into dcard_article_test(article_id, question, question_type) values(229919113,'台中直播公司','other');
# insert into dcard_article_test(article_id, question, question_type) values(228391202,'星巴克報到','other');
# insert into dcard_article_test(article_id, question, question_type) values(1098002,'酸不溜丟的初作檸檬塔','other');
# insert into dcard_article_test(article_id, question, question_type) values(226315687,'找工作好難','other');
# insert into dcard_article_test(article_id, question, question_type) values(226778612,'外交部：要求大馬鐵路網更正','other');
# insert into dcard_article_test(article_id, question, question_type) values(225258135,'那些說愛滋病就像感冒的人腦袋裝屎嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224596980,'160的女生適合騎哪台有電子儀表板的機車？？？','other');
# insert into dcard_article_test(article_id, question, question_type) values(225118418,'從併校事件中成長','other');
# insert into dcard_article_test(article_id, question, question_type) values(881007,'我爸換了智慧型手機後','other');
# insert into dcard_article_test(article_id, question, question_type) values(226376060,'誘姦變成婚外情?晨星只是渣男!?','other');
# insert into dcard_article_test(article_id, question, question_type) values(1149522,'line也有綠點點？！','other');
# insert into dcard_article_test(article_id, question, question_type) values(229906220,'工作選擇困難………求幫助','other');
# insert into dcard_article_test(article_id, question, question_type) values(230160782,'What country are you from?','other');
# insert into dcard_article_test(article_id, question, question_type) values(156787404,'有沒有花蓮又地震的八卦','other');
# insert into dcard_article_test(article_id, question, question_type) values(128040,'千層卡士達蛋塔 BY HANS','other');
# insert into dcard_article_test(article_id, question, question_type) values(225300886,'日夜之爭','other');
# insert into dcard_article_test(article_id, question, question_type) values(11619,'我又要來問微積分了','other');
# insert into dcard_article_test(article_id, question, question_type) values(1038666,'起司蛋糕 覆盆子果醬亂入 🍰','other');
# insert into dcard_article_test(article_id, question, question_type) values(227131809,'大拇哥證券','other');
# insert into dcard_article_test(article_id, question, question_type) values(227448096,'#文法','other');
# insert into dcard_article_test(article_id, question, question_type) values(228052017,'待業心情','other');
# insert into dcard_article_test(article_id, question, question_type) values(226155504,'寶雅發薪','other');
# insert into dcard_article_test(article_id, question, question_type) values(230190574,'108課綱程式設計','other');
# insert into dcard_article_test(article_id, question, question_type) values(227449615,'馬9.2跟空心蔡哪個比較好 #討論','other');
# insert into dcard_article_test(article_id, question, question_type) values(226949362,'老奶奶檸檬蛋糕的由來','other');
# insert into dcard_article_test(article_id, question, question_type) values(224471543,'有誰跟我一樣~~~','other');
# insert into dcard_article_test(article_id, question, question_type) values(230647360,'請問刮刮樂是只有過年期間中獎機率才比較高嗎？','other');
# insert into dcard_article_test(article_id, question, question_type) values(226294699,'摩斯漢堡新品((更','other');
# insert into dcard_article_test(article_id, question, question_type) values(225592021,'大社CP值超高黑輪店','other');
# insert into dcard_article_test(article_id, question, question_type) values(229804716,'外商公司業務/PM條件','other');
# insert into dcard_article_test(article_id, question, question_type) values(107708,'我的人生充滿黃啊~~~','other');
# insert into dcard_article_test(article_id, question, question_type) values(226002638,' 熱舞社悲慘現象','other');
# insert into dcard_article_test(article_id, question, question_type) values(197345270,'怎樣都不覺得生養小孩會幸福','other');
# insert into dcard_article_test(article_id, question, question_type) values(224877056,'少了肉的美味一風堂🍜','other');
# insert into dcard_article_test(article_id, question, question_type) values(224740105,'屈臣氏超長','other');
# insert into dcard_article_test(article_id, question, question_type) values(224091639,'深夜食堂-我要宰了這隻雞🐔','other');
# insert into dcard_article_test(article_id, question, question_type) values(229503085,' 轉型正義！西班牙通過法令　擬將獨裁者靈柩遷出烈士谷','other');
# insert into dcard_article_test(article_id, question, question_type) values(224202956,'電鍋 馬鈴薯濃湯','other');
# insert into dcard_article_test(article_id, question, question_type) values(229498841,'托福改台灣名字讓我想到一件事情','other');
# insert into dcard_article_test(article_id, question, question_type) values(224153012,'我的卡友呢😭😭😭','other');
# insert into dcard_article_test(article_id, question, question_type) values(246516,'廢死之後的替代方案','other');
# insert into dcard_article_test(article_id, question, question_type) values(228670808,'找一張圖：零風險高報酬','other');
# insert into dcard_article_test(article_id, question, question_type) values(225859506,'森永巧克力球','other');
# insert into dcard_article_test(article_id, question, question_type) values(224361221,'餐飲店養寵物','other');
# insert into dcard_article_test(article_id, question, question_type) values(227605710,'＃新聞  蟾蜍山百人烤肉引居民困擾　台科大學生會：請尊重校地合理使用權','other');
# insert into dcard_article_test(article_id, question, question_type) values(225111246,'關於 jolin 的翻糖蛋糕','other');
# insert into dcard_article_test(article_id, question, question_type) values(230597841,'憲哥 吸塵器面試1500人','other');
# insert into dcard_article_test(article_id, question, question_type) values(12994,'科學家鄭振和','other');
# insert into dcard_article_test(article_id, question, question_type) values(224927759,'根本扼殺在醫院工作的年輕人！！','other');
# insert into dcard_article_test(article_id, question, question_type) values(226774810,'日月光  科技廠櫃檯秘書','other');
# insert into dcard_article_test(article_id, question, question_type) values(230690056,'台灣經濟事實上是不斷進步的!','other');
# insert into dcard_article_test(article_id, question, question_type) values(227160106,'免費百威啤酒','other');
# insert into dcard_article_test(article_id, question, question_type) values(1164550,'焗烤起司馬鈴薯泥','other');
# insert into dcard_article_test(article_id, question, question_type) values(904590,'時事','what');
# insert into dcard_article_test(article_id, question, question_type) values(531910,'轉學可以要回之前繳的4年系會費嗎?','other');
# insert into dcard_article_test(article_id, question, question_type) values(224572991,'國民年金不到六成繳費','other');
# insert into dcard_article_test(article_id, question, question_type) values(478123,'豪華海陸饗宴','other');
# insert into dcard_article_test(article_id, question, question_type) values(230509589,'Richart消費動態不更新','other');
# insert into dcard_article_test(article_id, question, question_type) values(226627408,' 有本事早就出去了','other');
# insert into dcard_article_test(article_id, question, question_type) values(228300438,'榮成紙業 工作如何','other');
# insert into dcard_article_test(article_id, question, question_type) values(226716289,'工作選擇，急，在線等','other');
# insert into dcard_article_test(article_id, question, question_type) values(188096,' 「腦內革命，友善大腦」','other');
# insert into dcard_article_test(article_id, question, question_type) values(224985811,'太不要臉了吧這位客人','other');
# insert into dcard_article_test(article_id, question, question_type) values(934979,'你是覺得我很胖喔？','other');
# insert into dcard_article_test(article_id, question, question_type) values(970946,'統神語錄第五篇','other');
# insert into dcard_article_test(article_id, question, question_type) values(237466,'可以吃的樂高玩具，影片分享。','other');
# insert into dcard_article_test(article_id, question, question_type) values(10787073,'睡美人','what');
# insert into dcard_article_test(article_id, question, question_type) values(1038314,'只有飲食業對人最好','other');
# insert into dcard_article_test(article_id, question, question_type) values(230119161,'到底是誰在用政治干涉體育','who');
# insert into dcard_article_test(article_id, question, question_type) values(226062599,'全家系統讓我幫客人付了680元帳單','other');
# insert into dcard_article_test(article_id, question, question_type) values(229656402,'關於“面試”這件事情','other');
# insert into dcard_article_test(article_id, question, question_type) values(122041,'過號就讓他等啊!','other');
# WARNING:cassandra.connection:Heartbeat failed for connection (139972663327888) to 192.168.95.123
# WARNING:cassandra.connection:Heartbeat failed for connection (139972661702096) to 192.168.95.123
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('5a23d73f-8114-3bf3-81e2-d21bde8b763b'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('5a23d73f-8114-3bf3-81e2-d21bde8b763b'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('5a23d73f-8114-3bf3-81e2-d21bde8b763b'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('5a23d73f-8114-3bf3-81e2-d21bde8b763b'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('5a23d73f-8114-3bf3-81e2-d21bde8b763b'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('5a23d73f-8114-3bf3-81e2-d21bde8b763b'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('1b047db8-f5d3-3f0a-9785-39e7476e8e6e'): ['192.168.0.122', '192.168.0.52'], UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('1b047db8-f5d3-3f0a-9785-39e7476e8e6e'): ['192.168.0.122', '192.168.0.52'], UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('1b047db8-f5d3-3f0a-9785-39e7476e8e6e'): ['192.168.0.122', '192.168.0.52'], UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('1b047db8-f5d3-3f0a-9785-39e7476e8e6e'): ['192.168.0.122', '192.168.0.52'], UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('1b047db8-f5d3-3f0a-9785-39e7476e8e6e'): ['192.168.0.122', '192.168.0.52'], UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('1b047db8-f5d3-3f0a-9785-39e7476e8e6e'): ['192.168.0.122', '192.168.0.52'], UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('4b501a0b-54dd-3a82-8a2e-918a1fe7f244'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('4b501a0b-54dd-3a82-8a2e-918a1fe7f244'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('4b501a0b-54dd-3a82-8a2e-918a1fe7f244'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('4b501a0b-54dd-3a82-8a2e-918a1fe7f244'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('4b501a0b-54dd-3a82-8a2e-918a1fe7f244'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('4b501a0b-54dd-3a82-8a2e-918a1fe7f244'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('30bef868-c7e6-3c85-84fe-52cf4a63c688'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('30bef868-c7e6-3c85-84fe-52cf4a63c688'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('30bef868-c7e6-3c85-84fe-52cf4a63c688'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.122 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('30bef868-c7e6-3c85-84fe-52cf4a63c688'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('30bef868-c7e6-3c85-84fe-52cf4a63c688'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.cluster:Node 192.168.0.52 is reporting a schema disagreement: {UUID('be57b7d9-fcf7-397d-981d-0fab8a9ad6fb'): ['192.168.0.121'], UUID('30bef868-c7e6-3c85-84fe-52cf4a63c688'): ['192.168.0.122', '192.168.0.52']}
# WARNING:cassandra.connection:Heartbeat failed for connection (139971473588944) to 192.168.95.123
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.connection:Heartbeat failed for connection (139972183090384) to 192.168.95.123
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.connection:Heartbeat failed for connection (139973223581968) to 192.168.95.123
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.
# WARNING:cassandra.pool:Failed reconnecting 192.168.95.123. Retrying.

# %%
cql = 'select * from dcard_article_test;'
pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
pd_df
