# %%
# %matplotlib inline

# %%
# encoding=UTF-8
# !flask/bin/python

from cassandra.cluster import Cluster
from cassandra.policies import DCAwareRoundRobinPolicy
from cassandra.auth import PlainTextAuthProvider
from cassandra.query import BatchStatement
import pandas as pd
# from pyspark.sql.types import StringType, StructType, StructField


class CassandraType(object):
    PRODUCTION = 0
    TEST = 1
    TEST_DOCKER = 2


class CassandraDAO(object):

    # you have to install following items :
    # a. python-Cassandra driver
    # b. pyspark cassandra connector

    def __init__(self, type):
        #         print('runing father.__init__')
        if type == CassandraType.PRODUCTION:
            self.contact_points = ['192.168.95.127', '192.168.95.122']
            self.contact_points_str = "192.168.95.127,192.168.95.122"
        elif type == CassandraType.TEST:
            self.contact_points = ['192.168.0.90', '192.168.0.91', '192.168.0.92']
            self.contact_points_str = "192.168.0.90,192.168.0.91,192.168.0.92"
        else:
            self.contact_points = ['192.168.0.121', '192.168.0.122', '192.168.0.52']
            self.contact_points_str = "192.168.0.121,192.168.0.122,192.168.0.52"

        self.formatString = "org.apache.spark.sql.cassandra"
        self.username = "username"
        self.password = "password"
        self.cluster = None
        self.session = None
        self.createSession()

    def __del__(self):
        self.cluster.shutdown()

    def pandas_factory(self, colnames, rows):
        return pd.DataFrame(rows, columns=colnames)

    def createSession(self):
        print "contact_points = " + self.contact_points_str
        self.cluster = Cluster(
            contact_points=self.contact_points,  # random select a node
            #             load_balancing_policy = DCAwareRoundRobinPolicy(local_dc='datacenter1'),
            #         auth_provider = PlainTextAuthProvider(username='cassandra', password='cassandra')
        )
        self.session = self.cluster.connect()
        self.session.row_factory = self.pandas_factory
        self.session.default_fetch_size = None
        # needed for large queries, otherwise driver will do pagination. Default is 50000.

    def getSession(self):
        return self.session

    def execCQL(self, keyspace, cql):
        """
        execute CQL
        """
        self.session.set_keyspace(keyspace)
        self.session.execute_async(cql)

    def execCQLSelect(self, keyspace, cql):
        """
        execute CQL, select only
        """

        self.session.set_keyspace(keyspace)

        #       cassandra ResultSet
        async_results = self.session.execute_async(cql)
        return async_results

    def execCQLCallBackAnysc(self, keyspace, cql, handle_success, handle_error):
        """
        execute CQL, if success => handle_success function, else handle_error
        """
        self.session.set_keyspace(keyspace)
        async_results = self.session.execute_async(cql)
        async_results.add_callbacks(handle_success, handle_error)

    def execCQLSelectToPandasDF(self, keyspace, cql):
        """
        execute CQL, select only, return Pandas DataFrame
        """

        self.session.set_keyspace(keyspace)

        #       cassandra ResultSet
#         async_results = self.session.execute_async(cql, timeout=None)
        results = self.session.execute(cql, timeout=None)
        #         async_results = self.session.execute_async(cql)
        #       to Pandas DataFrame
#         return async_results.result()._current_rows
        return results._current_rows

    def execCQLSelectToDF(self, sqlContext, keyspace, cql):
        """
        execute CQL, select only, return Spark DataFrame
        """

        #       pandas dataframe to spark dataframe
        pandas_dataframe = self.execCQLSelectToPandasDF(keyspace, cql)
        if pandas_dataframe.empty:
            schema = StructType([])
            return sqlContext.createDataFrame([], schema)
        else:
            return sqlContext.createDataFrame(pandas_dataframe)

    def execCQLSelectToRDD(self, sqlContext, keyspace, cql):
        """
        execute CQL, select only, return Spark RDD
        """

        return self.execCQLSelectToDF(sqlContext, keyspace, cql).rdd.map(tuple)  # dataFrame to RDD

    @property
    def contactPoints(self):
        return self.contact_points

    @contactPoints.setter
    def contactPoints(self, contact_points):
        self.contact_points = contact_points

    @contactPoints.deleter
    def contactPoints(self):
        del self.contact_points

#     # pyspark cassandra connector
#     def readFromCassandraDF(self, sqlContext, keyspace, table):
#         """
#         read data from Cassandra, return Dataframe
#         """

#         return sqlContext.read \
#             .format(self.formatString) \
#             .options(table=table, keyspace=keyspace) \
#             .option("spark.cassandra.connection.host", self.contact_points_str) \
#             .load()

#     def readFromCassandraRDD(self, sqlContext, keyspace, table):
#         """
#         read data from Cassandra, return RDD
#         """

#         df = sqlContext.read \
#             .format(self.formatString) \
#             .options(table=table, keyspace=keyspace) \
#             .option("spark.cassandra.connection.host", self.contact_points_str) \
#             .load()
#         return df.rdd.map(tuple)  # dataFrame to RDD

#     def saveToCassandraDF(self, dataFrame, keyspace, table, mode="error"):
#         """
#         Save data to Cassandra using DataFrame, select one mode to save
        
#         SaveMode.ErrorIfExists (default) | "error"      When saving a DataFrame to a data source,
#                                                         if data already exists, an exception is expected to be thrown.
#         SaveMode.Append                  | "append"     When saving a DataFrame to a data source,
#                                                         if data/table already exists, contents of the DataFrame are
#                                                         expected to be appended to existing data.
#         SaveMode.Overwrite               | "overwrite"  Overwrite mode means that when saving a DataFrame to a data source,
#                                                         if data/table already exists, existing data is expected to be
#                                                         overwritten by the contents of the DataFrame.
#         SaveMode.Ignore                  | "ignore"     Ignore mode means that when saving a DataFrame to a data source,
#                                                         if data already exists, the save operation is expected to not
#                                                         save the contents of the DataFrame and to not change the
#                                                         existing data. This is similar to a CREATE TABLE IF NOT EXISTS

#                                                         in SQL.
#         """

#         dataFrame.write \
#             .format(self.formatString) \
#             .mode(mode) \
#             .options(table=table, keyspace=keyspace) \
#             .option("spark.cassandra.connection.host", self.contact_points_str) \
#             .save()

# %%
c_dao = CassandraDAO(CassandraType.PRODUCTION)
t_dao = CassandraDAO(CassandraType.TEST)
# Out:
# contact_points = 192.168.95.127,192.168.95.122
# contact_points = 192.168.0.90,192.168.0.91,192.168.0.92

# %%
import pandas as pd
import jieba
import jieba.posseg as pseg

class JiebaSegmentor:

    def __init__(self, dict_path, userdict=[], stopwords = False, stopwords_path=None):
        self.dict_path = dict_path
        self.userdict = userdict
        self.dictionary_init()
        self.stopwords_path = stopwords_path
        self.stopwords = stopwords
        self.stopwords_set = set()
        self.stopwords_init()

    def dictionary_init(self):
        jieba.set_dictionary(self.dict_path)
        for path in self.userdict:
            print path
            jieba.load_userdict(path)
    
    def stopwords_init(self):
        if self.stopwords_path:
            with open(self.stopwords_path ,'r') as stopwords:
                for stopword in stopwords:
                    self.stopwords_set.add(stopword.strip('\n').decode('utf-8'))

    def taiwan_country(self):
        return [u'臺北', u'台北', u'基隆', u'臺中', u'台中', u'臺南', u'台南', u'高雄',
                u'宜蘭', u'桃園', u'新竹', u'苗栗', u'彰化', u'南投', u'嘉義', u'雲林',
                u'屏東', u'臺東', u'台東', u'花蓮', u'澎湖']

    def wordToNumber(self, input_text):

        target = u''
        for s in input_text:

            if (s == u'零') or (s == '0'):
                to_word = u'0'
            elif (s == u'一') or (s == u'壹') or (s == '1'):
                to_word = u'1'
            elif (s == u'二') or (s == u'兩') or (s == u'貳') or (s == '2'):
                to_word = u'2'
            elif (s == u'三') or (s == u'參') or (s == '3'):
                to_word = u'3'
            elif (s == u'四') or (s == u'肆') or (s == '4'):
                to_word = u'4'
            elif (s == u'五') or (s == u'伍') or (s == '5'):
                to_word = u'5'
            elif (s == u'六') or (s == u'陸') or (s == '6'):
                to_word = u'6'
            elif (s == u'七') or (s == u'柒') or (s == '7'):
                to_word = u'7'
            elif (s == u'八') or (s == u'捌') or (s == '8'):
                to_word = u'8'
            elif (s == u'九') or (s == u'玖') or (s == '9'):
                to_word = u'9'
            else:
                to_word = s

        target = target + to_word
        return target

    def input_text_preprocessing(self, input_text):

        if type(input_text) is not unicode:
            input_text = input_text.decode('utf-8')

#         input_text = self.wordToNumber(input_text)
        return input_text

    def get_names(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        names = []
        words = pseg.cut(input_text)
        print words
        for w, f in words:
            if f.lower() == 'nr':
                names.append(w)
        for name in names:
            print name.encode('utf-8')
        return names

    def lcut(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        cut_raw = jieba.lcut(input_text)
        key = []

        for k in cut_raw:
            if self.stopwords:
                if k in self.stopwords_set:
                    continue
            
            key.append(k)
        df = pd.DataFrame({"word": key})
        return df

    def pseg_lcut(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        cut_raw = pseg.lcut(input_text)
        key = []
        value = []

        for k, v in cut_raw:
            tag = v
            if self.stopwords:
                if k in self.stopwords_set:
                    continue
            
            if k in self.taiwan_country():
                tag = u'ns'
            if len(k) > 1 and tag == u'x':
                tag = u'n'
            key.append(k)
            value.append(tag)
        df = pd.DataFrame({"word": key, "tag": value})
        return df

# %%
jieba_path = "/nfs/aq_test/jieba/"
jieba_dict_path1 = jieba_path + "dict_taiwan.txt"
jieba_dict_path2 = jieba_path +"userdict.txt"
jieba_dict_path3 = jieba_path +"dict.txt.big"
jieba_dict_path4 = jieba_path +"dict.txt.small"
jieba_stopwords_path = jieba_path +"stopwords.txt"
segmentor = JiebaSegmentor(jieba_dict_path1, 
                           [jieba_dict_path2,jieba_dict_path3,jieba_dict_path4], 
                           stopwords = True, 
                           stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /nfs/aq_test/jieba/dict_taiwan.txt ...
# DEBUG:jieba:Building prefix dict from /nfs/aq_test/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u34e30d1c15f49735c28e2158fa64cd7a.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.u34e30d1c15f49735c28e2158fa64cd7a.cache
# Loading model cost 0.396 seconds.
# DEBUG:jieba:Loading model cost 0.396 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# /nfs/aq_test/jieba/userdict.txt
# /nfs/aq_test/jieba/dict.txt.big
# /nfs/aq_test/jieba/dict.txt.small

# %%
segmentor.stopwords=True
segmentor.pseg_lcut('或許今天阿伯的媽媽給我好大一包的紅包喔')
# Out:
#   tag word
# 0   t   今天
# 1  ns   阿伯
# 2   n   媽媽
# 3   a    好
# 4   m   一包
# 5   n   紅包
# 6   e    喔

# %%
DB_KEYSPACE = "nlp_keyspace"
dcard_article = "dcard_article"
dcard_response = "dcard_response"
dcard_article_relationship = "dcard_article_relationship"
dcard_response_relationship = "dcard_response_relationship"
word_article_mapping_relationship = "word_article_mapping_relationship"
dcard_article_food = "dcard_article_food"
dcard_response_food = "dcard_response_food"
dcard_article_response_food = "dcard_article_response_food"
word_article_mapping_food = "word_article_mapping_food"
board_keyword = "board_keyword"

# %%
ppp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a2d17bb96faf> in <module>()
# ----> 1 ppp
#
# NameError: name 'ppp' is not defined

# %%
# target = 100000000
# step = 100000
# start = 0
# HELPER_KEYSPACE = 'nlp_keyspace'

# %%
cql = ("select distinct board, article_id, title, title_clean from " + dcard_article_response_food +";")
food_df = t_dao.execCQLSelectToPandasDF(DB_KEYSPACE, cql)
food_df.count()
# Out:
# board          9230
# article_id     9230
# title          9230
# title_clean    9230
# dtype: int64

# %%
test = food_df[["article_id", "title_clean"]].head(20)
test
# Out:
#    article_id          title_clean
# 0   232350138            你們都喝哪牌的汽水
# 1   231036157            台南東區平價甜點店
# 2   231547034  海產有毒，去廈門跟金門玩的人看一下!!
# 3   231805424         超不負責鮮蝦義大利麵食譜
# 4   231755783               抹醬吐司冷凍
# 5   233243669         最近去過12間台中咖啡廳
# 6   231708382          台中西區 | 牛逼館子
# 7   230985201    表單已關閉）大學生咖啡市場需求調查
# 8   231609439         就是有業味 真的太推：）
# 9   233232635                 茶六套餐
# 10  233087104               我也要吃布丁
# 11  231728775          食記part2 #台中
# 12  232581594    鹽埕食圈#佬掉牙-這才是酒吧的進度
# 13  233190318                椪糖知多少
# 14  232963178               這是什麼福袋
# 15  232051733        宿舍簡單料理|蛤蜊蝦仁麵食
# 16  232529509          大家有推薦的乾拌麵嗎？
# 17  231688231               想找這個餅乾
# 18  231432196              幫阿嬤煮的午餐
# 19  231012485        求衛理女中旁邊的大腸包小腸

# %%
list(test['article_id'])
# Out:
# [u'232350138',
#  u'231036157',
#  u'231547034',
#  u'231805424',
#  u'231755783',
#  u'233243669',
#  u'231708382',
#  u'230985201',
#  u'231609439',
#  u'233232635',
#  u'233087104',
#  u'231728775',
#  u'232581594',
#  u'233190318',
#  u'232963178',
#  u'232051733',
#  u'232529509',
#  u'231688231',
#  u'231432196',
#  u'231012485']

# %%
test[test['title_clean'].str.len() > 5]
# Out:
#    article_id          title_clean
# 0   232350138            你們都喝哪牌的汽水
# 1   231036157            台南東區平價甜點店
# 2   231547034  海產有毒，去廈門跟金門玩的人看一下!!
# 3   231805424         超不負責鮮蝦義大利麵食譜
# 4   231755783               抹醬吐司冷凍
# 5   233243669         最近去過12間台中咖啡廳
# 6   231708382          台中西區 | 牛逼館子
# 7   230985201    表單已關閉）大學生咖啡市場需求調查
# 8   231609439         就是有業味 真的太推：）
# 10  233087104               我也要吃布丁
# 11  231728775          食記part2 #台中
# 12  232581594    鹽埕食圈#佬掉牙-這才是酒吧的進度
# 14  232963178               這是什麼福袋
# 15  232051733        宿舍簡單料理|蛤蜊蝦仁麵食
# 16  232529509          大家有推薦的乾拌麵嗎？
# 17  231688231               想找這個餅乾
# 18  231432196              幫阿嬤煮的午餐
# 19  231012485        求衛理女中旁邊的大腸包小腸

# %%
# cql = ("select * from " + dcard_article_relationship +";")
# relationship_df = t_dao.execCQLSelectToPandasDF(DB_KEYSPACE, cql)
# print len(relationship_df)
# relationship_df.head(50)

# %%
# cql = ("select * from " + dcard_article_food +";")
# food_df = t_dao.execCQLSelectToPandasDF(DB_KEYSPACE, cql)
# print len(food_df)
# food_df.head(50)

# %%
article_raw_pd_list = []

# %%
# print len(pd_df)
# relationship_df[["article_id", "title_clean"]].head(20)

# %%
# from pyspark.sql.functions import udf
# def update_column(x):
# #     check = QuestionTypeCheck(segmentor)
# #     check.source = 'ptt'
# #     label = check.check_question_type(x)
#     input_text = input_text.replace(u'Re: ', u'')
#     input_text = re.sub(u"\\[.*?]", u"", input_text)
#     segmentor = JiebaSegmentor(jieba_dict_path1, [jieba_dict_path2,jieba_dict_path3,jieba_dict_path4])
#     segmentor.pseg_lcut('test')
#     return 'label'

# update_column_udf = udf(update_column)
# new_df = df.withColumn('question_type',
#                     update_column_udf(df['question_type']))

# %%
# new_df = df.limit(100)

# %%
# dao.saveToCassandraDF(new_df, "nlp_keyspace", "dcard_article_test", "append")

# %%
def filter_by_tag(tag):
    v_tag = ['v', 'vd', 'vg', 'vi', 'vn', 'vq', 'vt']
    n_tag = ['n', 'ng', 'nr', 'nrfg', 'nrt', 'ns', 'nt','nz']
    a_tag = ['a', 'ad', 'ag', 'an']
#         print tag['word'][0] + '(' + tag['tag'][0] + ')'
    if tag in v_tag or tag in n_tag or tag in a_tag:
        return True
    return False

def filter_by_tag_udf(row):
    v_tag = ['v', 'vd', 'vg', 'vi', 'vn', 'vq', 'vt']
    n_tag = ['n', 'ng', 'nr', 'nrfg', 'nrt', 'ns', 'nt','nz']
#     a_tag = ['a', 'ad', 'ag', 'an']
#         print tag['word'][0] + '(' + tag['tag'][0] + ')'
#     if row['tag'] in v_tag or row['tag'] in n_tag or row['tag'] in a_tag:
    if row['tag'] in v_tag or row['tag'] in n_tag:
        return True
    return False

# %%
word_article_mapping_relationship, len(relationship_df)

# %%
word_article_mapping_food, len(food_df)
# Out:
# ('word_article_mapping_food', 9230)

# %%
def get_word_count(pd_df, table):
    word_count = []
    for index, row in pd_df.iterrows():

        # question斷詞
        if not row['title_clean']:
            continue

    #     print row['question']
        words = segmentor.pseg_lcut(row['title_clean'])
    #     print words
        article_id = row['article_id']
        for index, row in words.iterrows():
    #         print row['word']

            # 只存名詞 and 動詞
            if filter_by_tag(row['tag']):
            # 每個詞更新到 mapping table
                cql = ("update " + table + " " +
                       "set article_id = article_id + ['" + str(article_id) + "'] " +
                       "where word = '" + row['word'] + "';")
#                 print cql
                t_dao.execCQL(DB_KEYSPACE, cql)
                word_count.append(row['word'])
    return word_count

# %%
word_count_relationship = get_word_count(relationship_df, word_article_mapping_relationship)
word_count_relationship

# %%
word_count_food = get_word_count(food_df,  word_article_mapping_food)
word_count_food
# Out:
# [u'\u559d',
#  u'\u724c',
#  u'\u6c7d\u6c34',
#  u'\u53f0\u5357',
#  u'\u6771\u5340',
#  u'\u5e73\u50f9',
#  u'\u751c\u9ede\u5e97',
#  u'\u6d77\u7522',
#  u'\u6709\u6bd2',
#  u'\u53bb',
#  u'\u5ec8\u9580',
#  u'\u91d1\u9580',
#  u'\u73a9',
#  u'\u4eba',
#  u'\u8d85\u4e0d',
#  u'\u8ca0\u8cac',
#  u'\u9bae\u8766',
#  u'\u7fa9\u5927\u5229\u9eb5',
#  u'\u98df\u8b5c',
#  u'\u62b9\u91ac',
#  u'\u5410\u53f8',
#  u'\u51b7\u51cd',
#  u'\u53bb\u904e',
#  u'\u9593\u53f0',
#  u'\u5496\u5561\u5ef3',
#  u'\u4e2d\u897f\u5340',
#  u'\u725b',
#  u'\u903c',
#  u'\u9928\u5b50',
#  u'\u8868\u55ae',
#  u'\u95dc\u9589',
#  u'\u5927\u5b78\u751f',
#  u'\u5496\u5561',
#  u'\u5e02\u5834\u9700\u6c42',
#  u'\u8abf\u67e5',
#  u'\u696d\u5473',
#  u'\u63a8',
#  u'\u8336',
#  u'\u5957\u9910',
#  u'\u5403',
#  u'\u5e03\u4e01',
#  u'\u98df\u8a18',
#  u'\u53f0\u4e2d',
#  u'\u9e7d\u57d5',
#  u'\u98df\u5708',
#  u'\u4f6c',
#  u'\u6389\u7259',
#  u'\u9152\u5427',
#  u'\u692a\u7cd6',
#  u'\u9019\u662f',
#  u'\u798f\u888b',
#  u'\u5bbf\u820d',
#  u'\u7c21\u55ae',
#  u'\u6599\u7406',
#  u'\u86e4\u870a',
#  u'\u8766\u4ec1',
#  u'\u9eb5\u98df',
#  u'\u63a8\u85a6',
#  u'\u62cc',
#  u'\u627e',
#  u'\u9905\u4e7e',
#  u'\u963f\u5b24',
#  u'\u716e',
#  u'\u5348\u9910',
#  u'\u6c42',
#  u'\u885b\u7406',
#  u'\u5927\u8178\u5305\u5c0f\u8178',
#  u'\u5168\u5bb6',
#  u'\u65b0\u54c1',
#  u'\u62b9\u8336',
#  u'\u8212\u8299',
#  u'\u96f7',
#  u'\u5e03\u4e01',
#  u'\u662f\u8ab0',
#  u'\u8349\u8393',
#  u'\u5eab\u8389',
#  u'\u725b\u5976',
#  u'\u98df',
#  u'\u5317\u6295\u4eba',
#  u'\u8acb\u76ca',
#  u'\u6e05\u723d',
#  u'\u6599\u7406',
#  u'\u6dbc\u62cc',
#  u'\u6d77\u5e36\u82bd',
#  u'\u8a62',
#  u'\u6d77\u9bae',
#  u'\u7389\u5973',
#  u'\u9b6f\u8089\u98ef',
#  u'\u5e73\u6c11',
#  u'\u7f8e\u98df',
#  u'\u8b66\u5927',
#  u'\u751f',
#  u'\u98df\u8a18',
#  u'\u6c42',
#  u'\u9577\u5e9a\u91ab\u9662',
#  u'\u7f8e\u98df',
#  u'\u52a0\u71b1',
#  u'\u84b8\u86cb',
#  u'\u4eba',
#  u'\u7092\u98ef',
#  u'\u65b0\u54c1',
#  u'\u4e0a\u5e02',
#  u'\u9bae\u679c',
#  u'\u96ea\u916a',
#  u'\u971c\u6dc7\u6dcb',
#  u'\u5c4f\u6771',
#  u'\u6771\u6e2f',
#  u'\u83ef\u50d1',
#  u'\u5e02\u5834',
#  u'\u98df\u8a18',
#  u'\u5317',
#  u'\u9ad8\u96c4',
#  u'\u8f14\u82f1',
#  u'\u86cb\u5305\u98ef',
#  u'\u627e',
#  u'\u51b0\u54c1',
#  u'\u7f8e\u98df\u7248',
#  u'\u80fd\u4e0d\u80fd',
#  u'\u5403\u7248',
#  u'\u53f0\u5357',
#  u'\u8fa6\u516c\u5ba4',
#  u'\u9ede\u5fc3',
#  u'\u6c42',
#  u'\u63a8\u85a6',
#  u'\u9910',
#  u'\u9152\u9928',
#  u'\u51b0',
#  u'\u53ef\u53ef',
#  u'\u828b\u982d',
#  u'\u5976\u6cb9',
#  u'\u9165',
#  u'\u9019\u662f',
#  u'\u9b5a',
#  u'\u6771\u6d77',
#  u'\u5546\u5708',
#  u'\u597d\u5403',
#  u'\u50b3\u7d71',
#  u'\u96de\u86cb\u7cd5',
#  u'\u5976',
#  u'\u9732',
#  u'\u9eb5\u5305',
#  u'\u6587\u5316',
#  u'\u4e2d\u5fc3',
#  u'\u98df\u5708',
#  u'\u9ad8\u96c4',
#  u'\u559c\u6b61',
#  u'\u9eb5\u5305\u5e97',
#  u'\u6c42',
#  u'\u63a8\u85a6',
#  u'\u559d\u904e',
#  u'\u6700\u68d2',
#  u'\u9ed1\u7cd6',
#  u'\u73cd\u5976',
#  u'\u6d88\u5931',
#  u'\u9ad8\u96c4',
#  u'\u65b0\u5d1b\u6c5f',
#  u'\u5208\u5305',
#  u'\u6f8e\u6e56',
#  u'\u4f34\u624b\u79ae',
#  u'\u63a8\u85a6',
#  u'\u62ab\u85a9',
#  u'\u984c',
#  u'\u5584\u5316',
#  u'\u795e\u6b66',
#  u'\u62c9\u9eb5',
#  u'\u9ad8\u96c4',
#  u'\u71d2\u70e4',
#  u'\u5927\u5751',
#  u'\u828b\u5713',
#  u'\u597d\u5403',
#  u'\u98ef\u7cf0',
#  u'\u6de1\u6c34',
#  u'\u8d85',
#  u'\u7c21\u55ae',
#  u'\u916a\u68a8',
#  u'\u5e03\u4e01',
#  u'\u725b\u5976',
#  u'\u6cd5\u5f0f',
#  u'\u751c\u9ede',
#  u'\u8ab2',
#  u'\u6ce1\u8299',
#  u'\u9999\u8305',
#  u'\u96de\u98ef',
#  u'\u60f3\u50cf',
#  u'\u5f88\u592f',
#  u'\u96ea\u7cd5',
#  u'\u5496\u54e9\u96de',
#  u'\u817f',
#  u'\u73cd\u5976',
#  u'\u51b0\u68d2',
#  u'\u5ee2\u6587',
#  u'\u4f5b\u5fc3',
#  u'\u990a',
#  u'\u65b0',
#  u'\u6ce1\u9eb5',
#  u'\u7f8e\u5999',
#  u'\u6771\u897f',
#  u'\u65b0',
#  u'\u8349\u8393',
#  u'\u4e73\u916a',
#  u'\u86cb\u7cd5',
#  u'\u5929\u6c23',
#  u'\u8def\u6613\u838e',
#  u'\u5e03\u857e',
#  u'\u96b1\u85cf\u7248',
#  u'\u597d\u5403',
#  u'\u5ba2\u5bb6',
#  u'\u9ebb\u7cec',
#  u'\u9ad8\u96c4',
#  u'\u86cb\u5305\u98ef',
#  u'\u5439',
#  u'\u7184\u71c8',
#  u'\u4f5b\u5fc3',
#  u'\u5e97\u5bb6',
#  u'\u96c6\u601d',
#  u'\u63a8\u85a6',
#  u'\u6843\u5712',
#  u'\u4e2d\u58e2',
#  u'\u58fd\u559c\u71d2',
#  u'\u5e97',
#  u'\u751f\u65e5\u86cb\u7cd5',
#  u'\u8aaa',
#  u'\u6cf0\u6cf0',
#  u'\u5148',
#  u'\u666f\u7f8e',
#  u'\u591c\u5e02',
#  u'\u91d1\u7530',
#  u'\u53e4\u65e9\u5473',
#  u'\u86cb\u7cd5',
#  u'\u559c\u6b61',
#  u'\u559d\u5496\u5561',
#  u'\u65e5\u5f0f',
#  u'\u9ebb\u5a46',
#  u'\u5168\u806f',
#  u'\u65b0\u54c1',
#  u'\u806f\u540d',
#  u'\u6cd5\u5f0f',
#  u'\u4e73\u916a',
#  u'\u5e03\u4e01',
#  u'\u5c0f',
#  u'\u9bae\u8089',
#  u'\u5275\u610f',
#  u'\u6e6f\u5305',
#  u'\u51b0\u6dc7\u6dcb',
#  u'\u5bc4',
#  u'\u6fb3\u9580',
#  u'\u65b0\u7af9',
#  u'\u51b0',
#  u'\u559c\u6b61',
#  u'\u6ff0\u514b',
#  u'\u65e9\u5348\u9910',
#  u'\u4eba',
#  u'\u8acb\u9032',
#  u'\u9ad8\u96c4',
#  u'\u4efb\u6027',
#  u'\u6524\u8ca9',
#  u'\u5916\u5bbf',
#  u'\u7c21\u55ae',
#  u'\u6599\u7406',
#  u'\u597d\u7269',
#  u'\u63a8\u85a6',
#  u'\u63d0\u62c9\u7c73\u8607',
#  u'\u908a\u7de3',
#  u'\u4eba',
#  u'\u725b\u8089\u9eb5',
#  u'\u62b9\u8336',
#  u'\u5496\u54e9',
#  u'\u8aaa',
#  u'\u5c0f\u5403',
#  u'\u8ca8',
#  u'\u5403',
#  u'\u4e0a\u6d77',
#  u'\u61f7\u5ff5',
#  u'\u5473\u9053',
#  u'\u56de\u6b78',
#  u'\u9ea5',
#  u'\u7126\u7cd6',
#  u'\u5976\u8336',
#  u'\u708e',
#  u'\u4ed4',
#  u'\u963f\u5b24',
#  u'\u7b11\u5bb9',
#  u'\u8d77\u53f8',
#  u'\u63a7',
#  u'\u5c16\u53eb',
#  u'\u5168\u806f',
#  u'\u65b0\u54c1',
#  u'\u8d77\u53f8',
#  u'\u5b63',
#  u'\u4e09\u5275',
#  u'\u5973\u50d5',
#  u'\u9910\u5ef3',
#  u'\u725b\u5976',
#  u'\u91ac\u6cb9',
#  u'\u5403',
#  u'\u7da0',
#  u'\u5496\u54e9',
#  u'\u716e',
#  u'\u7d00\u9304',
#  u'\u7db2\u8cfc',
#  u'\u725b\u8089\u6e6f',
#  u'\u706b\u934b',
#  u'\u6599',
#  u'\u716e',
#  u'\u934b',
#  u'\u714e',
#  u'\u725b\u6392',
#  u'\u4fc4\u570b',
#  u'\u98f2\u6599',
#  u'\u81ed\u9178',
#  u'\u512a\u916a\u4e73',
#  u'\u6eab\u99a8',
#  u'\u6625\u6372',
#  u'\u98df\u969b',
#  u'\u7f85\u52d2',
#  u'\u7fa9\u5927\u5229\u9eb5',
#  u'\u542b',
#  u'\u9752\u91ac',
#  u'\u98df\u8b5c',
#  u'\u5c0b\u627e',
#  u'\u8edf\u7cd6',
#  u'\u73cd\u716e\u4e39',
#  u'\u6cf0\u5c71',
#  u'\u8336\u6524',
#  u'\u4e00\u689d\u8857',
#  u'\u9ed1\u7cd6',
#  u'\u9bae\u5976\u8336',
#  u'\u5168\u806f',
#  u'\u5730\u74dc',
#  u'\u73cd\u73e0',
#  u'\u5713',
#  u'\u5690\u9bae',
#  u'\u677f\u6a4b',
#  u'\u7f8e\u98df',
#  u'\u81fa\u4e2d',
#  u'\u6563\u6b65',
#  u'\u7f8e\u98df',
#  u'\u70b8\u96de',
#  u'\u9e97\u9732',
#  u'\u812b\u6a21',
#  u'\u6210\u529f',
#  u'\u86cb\u7092\u98ef',
#  u'\u9650\u5b9a',
#  u'\u6bd4\u85a9',
#  u'\u6de1\u6c34',
#  u'\u8001\u8857',
#  u'\u7f8e\u98df',
#  u'\u67e5\u8b49',
#  u'\u9ea5\u7576\u52de',
#  u'\u98f2\u6599',
#  u'\u53bb',
#  u'\u51b0',
#  u'\u5305\u88dd',
#  u'\u5269',
#  u'\u7d19',
#  u'\u5065\u5eb7',
#  u'\u71d5\u9ea5',
#  u'\u8edf',
#  u'\u9905\u4e7e',
#  u'\u9905\u4e7e',
#  u'\u4fdd\u5b58',
#  u'\u65b9\u6cd5',
#  u'\u756a\u85af',
#  u'\u5305',
#  u'\u9935\u98df',
#  u'\u5ba4\u53cb',
#  u'\u8611\u83c7',
#  u'\u71c9\u98ef',
#  u'\u82b1\u84ee',
#  u'\u65b0\u958b',
#  u'\u71d2\u70e4\u5e97',
#  u'\u8ff7\u514b\u590f',
#  u'\u6839\u672c',
#  u'\u8d85',
#  u'\u51a4\u6789',
#  u'\u87ba',
#  u'\u7345\u7c89',
#  u'\u5916\u98df',
#  u'\u591a\u502b\u591a',
#  u'\u597d\u5403',
#  u'\u70b8',
#  u'\u8c6c\u5c3e\u5df4',
#  u'\u8abf\u9152',
#  u'\u51b7',
#  u'\u4fbf\u7576',
#  u'\u756a\u8304',
#  u'\u8089\u91ac',
#  u'\u7fa9\u5927\u5229\u9eb5',
#  u'\u597d',
#  u'\u5c0f\u6c23',
#  u'\u80af\u5fb7\u57fa',
#  u'\u512a\u60e0\u5238',
#  u'\u5403',
#  u'\u5de7\u514b\u529b',
#  u'\u8b8a',
#  u'\u5403',
#  u'\u77f3\u982d',
#  u'\u5317\u8eca',
#  u'\u9650\u6642',
#  u'\u9910\u5ef3',
#  u'\u60f3\u8acb',
#  u'\u9eb5\u689d',
#  u'\u8cb7',
#  u'\u860b\u679c\u6d3e',
#  u'\u61f6\u4eba',
#  u'\u751c\u9ede',
#  u'\u714e\u86cb',
#  u'\u5230',
#  u'\u8c9d\u6bbc',
#  u'\u6d41\u6c99',
#  u'\u9eb5\u5305',
#  u'\u98f2\u6599\u754c',
#  u'\u6295\u7968',
#  u'\u98df\u8a18',
#  u'\u6797\u68ee',
#  u'\u5317\u539f',
#  u'\u71d2',
#  u'\u5065\u5eb7',
#  u'\u97d3\u570b',
#  u'\u70e4\u8089',
#  u'\u53f0\u5317',
#  u'\u7121\u6cd5',
#  u'\u8a02\u8cfc',
#  u'\u6c42\u52a9',
#  u'\u6599\u7406',
#  u'\u7532\u6bbc\u985e',
#  u'\u56f0\u64fe',
#  u'\u592a\u967d',
#  u'\u597d',
#  u'\u4eba\u751f',
#  u'\u597d',
#  u'\u96e3',
#  u'\u4e2d\u53e4',
#  u'\u65e9',
#  u'\u70b8',
#  u'\u6e6f\u5713',
#  u'\u61f6\u4eba',
#  u'\u716e',
#  u'\u597d',
#  u'\u65b0\u7af9',
#  u'\u7af9\u5317\u5e02',
#  u'\u827e\u871c\u5947',
#  u'\u7fa9\u5927\u5229',
#  u'\u9910\u5ef3',
#  u'\u5bc4\u751f',
#  u'\u70b8\u91ac',
#  u'\u70cf\u9f8d\u9eb5',
#  u'\u706b\u934b\u5e97',
#  u'\u9593\u6709',
#  u'\u80e1\u9ebb',
#  u'\u91ac',
#  u'\u9ad8\u96c4',
#  u'\u5efa\u5de5',
#  u'\u7f8e\u98df',
#  u'\u706b\u8eca\u7ad9',
#  u'\u7d05\u8c46\u9905',
#  u'\u63a8\u63a8',
#  u'\u69b4\u84ee',
#  u'\u6bd4\u85a9',
#  u'\u63a8\u85a6',
#  u'\u5927\u793e',
#  u'\u597d\u5403',
#  u'\u6771\u4eac',
#  u'\u71d2\u8089',
#  u'\u63a8\u85a6',
#  u'\u963f\u65e6\u5e2b',
#  u'\u7f8a\u8089\u7210',
#  u'\u97d3\u570b',
#  u'\u70b8\u96de',
#  u'\u5403',
#  u'\u8c46\u82bd\u83dc',
#  u'\u756a\u8304',
#  u'\u4e0d\u914d',
#  u'\u82b1\u84ee',
#  u'\u58fd\u8c50\u9109',
#  u'\u5c0f',
#  u'\u597d',
#  u'\u725b\u6392\u9928',
#  u'\u5c08\u696d',
#  u'\u5c4b\u99ac',
#  u'\u6d77\u9bae\u7ca5',
#  u'\u5916\u5e36',
#  u'\u80af\u5fb7\u57fa',
#  u'\u8d77\u58eb',
#  u'\u6469\u5929\u6a13',
#  u'\u96de\u817f\u5821',
#  u'\u505a\u51fa',
#  u'\u597d\u5403',
#  u'\u86cb\u7cd5',
#  u'\u9650\u5b9a\u7248',
#  u'\u6ab8\u6aac',
#  u'\u80af\u5fb7\u57fa',
#  u'\u512a\u60e0',
#  u'\u767c',
#  u'\u81fa\u4e2d',
#  u'\u751c\u9ede',
#  u'\u98df\u8a18',
#  u'\u6cd5\u6a02',
#  u'\u6cd5\u5f0f',
#  u'\u8584\u9905',
#  u'\u5c4b',
#  u'\u4e39\u4e39',
#  u'\u6f22\u5821',
#  u'\u54e1\u5de5',
#  u'\u96b1\u85cf',
#  u'\u5403\u6cd5',
#  u'\u5168\u806f',
#  u'\u8292\u679c',
#  u'\u6b50\u59c6',
#  u'\u857e',
#  u'\u4e03\u661f',
#  u'\u51b0\u6dc7\u6dcb',
#  u'\u6c7d\u6c34',
#  u'\u4f4e\u78b3',
#  u'\u98f2\u98df',
#  u'\u65e5\u5f0f',
#  u'\u6f22\u5821',
#  u'\u6392',
#  u'\u716e',
#  u'\u5a66',
#  u'\u6771\u6d77\u5927\u5b78',
#  u'\u91d1',
#  u'\u6674\u5ddd',
#  u'\u62c9\u9eb5',
#  u'\u5fd9',
#  u'\u5077\u61f6',
#  u'\u5bb6\u5e38',
#  u'\u6599\u7406',
#  u'\u7d05\u6cb9',
#  u'\u7092\u624b',
#  u'\u597d\u5403',
#  u'\u8d85\u5546',
#  u'\u98ef\u7cf0',
#  u'\u9650\u5b9a',
#  u'\u871c\u6843',
#  u'\u679c\u8336',
#  u'\u8d85',
#  u'\u8a87\u5f35',
#  u'\u5e97\u54e1',
#  u'\u76f4\u63a5',
#  u'\u53bb',
#  u'\u5ba2\u8a34',
#  u'\u5ba2\u8a34',
#  u'\u5b8c',
#  u'\u98f2\u6599',
#  u'\u6599',
#  u'\u91d1\u7926',
#  u'\u5fb7\u5f0f',
#  u'\u5e03\u4e01',
#  u'\u5bc2',
#  u'\u4eba',
#  u'\u751c\u98df',
#  u'\u57fa\u9686',
#  u'\u751c\u9ede',
#  u'\u63a8\u85a6',
#  u'\u79be\u5802',
#  u'\u6d77\u9e7d',
#  u'\u8c46\u4e73',
#  u'\u51b0\u6dc7\u6dcb',
#  u'\u9001',
#  u'\u6539',
#  u'\u751c\u9ede',
#  u'\u8a02\u55ae',
#  u'\u5168\u5bb6',
#  u'\u5de7\u514b\u529b',
#  u'\u96d9\u5c64',
#  u'\u676f\u5b50',
#  u'\u86cb\u7cd5',
#  u'\u8089\u54c1',
#  u'\u90e8',
#  u'\u53f0\u4e2d',
#  u'\u597d\u53cb',
#  u'\u6176\u751f',
#  u'\u9910\u5ef3',
#  u'\u63a8\u85a6',
#  u'\u6843\u5712',
#  u'\u591c\u5e02',
#  u'\u53e4\u65e9\u5473',
#  u'\u86b5\u55f2',
#  u'\u503c',
#  u'\u65b0',
#  u'\u8cb7',
#  u'\u751f',
#  u'\u9435\u934b',
#  u'\u958b\u934b',
#  u'\u5f8c',
#  u'\u8b8a',
#  u'\u9905\u4e7e',
#  u'\u5317\u6597',
#  u'\u4e2d\u83ef',
#  u'\u934b\u8cbc',
#  u'\u5091',
#  u'\u7279\u8abf',
#  u'\u8c50\u539f',
#  u'\u5bb6\u4f19',
#  u'\u934b\u5e97',
#  u'\u80af\u5fb7\u57fa',
#  u'\u70b8\u96de',
#  u'\u76ae',
#  u'\u7fa9\u5b88',
#  u'\u7f8e\u5973',
#  u'\u52f8',
#  u'\u85af\u689d',
#  u'\u5e97\u5bb6',
#  u'\u5168\u904b\u6703',
#  u'\u5de5\u4f5c\u4eba\u54e1',
#  u'\u4fbf\u7576',
#  u'\u65e5\u8a18',
#  u'\u54c8\u6839\u9054\u65af',
#  u'\u5496\u5561',
#  u'\u53e3\u5473',
#  u'\u9eb5\u5305',
#  u'\u5305',
#  u'\u888b\u5b50',
#  u'\u537b\u6709',
#  u'\u5c0f',
#  u'\u868a\u5b50',
#  u'\u6c42',
#  u'\u65b0\u7af9',
#  u'\u597d\u5403',
#  u'\u65e9\u9910',
#  u'\u63a8\u85a6',
#  u'\u6c42',
#  u'\u5c0b\u627e',
#  u'\u7f8e\u5473',
#  u'\u5403',
#  u'\u8089',
#  u'\u8d85',
#  u'\u5065\u5eb7',
#  u'\u53f0\u83dc',
#  u'\u5403',
#  u'\u5718\u8cfc',
#  u'\u7f8e\u98df',
#  u'\u5c0f',
#  u'\u592b\u59bb',
#  u'\u62cc',
#  u'\u6a02',
#  u'\u699b',
#  u'\u679c\u91ac',
#  u'\u716e',
#  u'\u6eab\u6cc9\u86cb',
#  u'\u65b9\u6cd5',
#  u'\u53f0\u5317',
#  u'\u751c\u9ede',
#  u'\u5c08\u696d',
#  u'\u559c\u6b61',
#  u'\u5403',
#  u'\u6c99',
#  u'\u6574\u7c92',
#  u'\u81fa\u4e2d',
#  u'\u65e9\u5348\u9910',
#  u'\u98df\u8a18',
#  u'\u862d\u7fbd',
#  u'\u9928',
#  u'\u9023\u9396',
#  u'\u7f8e\u98df',
#  u'\u65e9\u5348\u9910',
#  u'\u7d00\u5ff5\u65e5',
#  u'\u5973\u53cb',
#  u'\u8aaa\u597d',
#  u'\u5403',
#  u'\u725b\u6392\u9928',
#  u'\u53f0\u5317',
#  u'\u6176\u751f',
#  u'\u706b\u934b',
#  u'\u6c42',
#  u'\u63a8\u85a6',
#  u'\u53f0\u4e2d',
#  u'\u9ad8',
#  u'\u9e79\u6d3e',
#  u'\u65e9\u5348\u9910',
#  u'\u5168\u5bb6',
#  u'\u7fa9\u7f8e',
#  u'\u5976\u8336',
#  u'\u5e03\u4e01',
#  u'\u5361\u6ecb',
#  u'\u7206\u7c73\u82b1',
#  u'\u9ed1\u677e\u6c99\u58eb',
#  u'\u9ad8\u96c4',
#  u'\u611b',
#  u'\u5403',
#  u'\u8089',
#  u'\u4ea4\u6d41',
#  u'\u7f8e\u570b',
#  u'\u4e0b\u5348\u8336',
#  u'\u4ead',
#  u'\u8fa3',
#  u'\u7092\u5e74\u7cd5',
#  u'\u888b\u88dd',
#  u'\u8cb7',
#  u'\u6c34\u96fb',
#  u'\u5c0f\u7de8',
#  u'\u716e\u98ef',
#  u'\u9678\u5bb6',
#  u'\u73ed',
#  u'\u8525\u6cb9\u9905',
#  u'\u5168\u5bb6',
#  u'\u53cb\u5584',
#  u'\u98df\u5149',
#  u'\u5169\u65e5\u904a',
#  u'\u7f8e\u98df',
#  u'\u65c5',
#  u'\u5403',
#  u'\u81ed\u8c46\u8150',
#  u'\u58fd\u53f8',
#  u'\u626d\u86cb',
#  u'\u767c\u63da',
#  u'\u53f0\u7063',
#  u'\u6210\u529f',
#  u'\u57fa\u9686',
#  u'\u5212\u7b97',
#  u'\u6ef7\u5473',
#  u'\u62c9\u9eb5',
#  u'\u6cbe',
#  u'\u63a7',
#  u'\u8acb\u9032',
#  u'\u53f0\u5357',
#  u'\u96f7',
#  u'\u7d93\u9a57',
#  u'\u7f8e\u98df',
#  u'\u963f\u5e73',
#  u'\u5c0f\u5403',
#  u'\u5973\u53cb',
#  u'\u62b1\u6028',
#  u'\u5e78\u798f',
#  u'\u80a5',
#  u'\u5eda\u623f',
#  u'\u91cd',
#  u'\u4e73\u916a',
#  u'\u86cb\u7cd5',
#  u'\u5168\u5bb6',
#  u'\u828b\u6ce5',
#  u'\u6ce1\u8299',
#  u'\u505a\u83dc',
#  u'\u7642\u7652',
#  u'\u8543\u8304',
#  u'\u79cb\u8475',
#  u'\u9b5a\u76ae',
#  u'\u8c46\u8150',
#  u'\u86cb\u82b1\u6e6f',
#  u'\u9752\u6912',
#  u'\u8089\u7d72',
#  u'\u9ad8\u96c4',
#  u'\u706b\u934b',
#  u'\u63a8\u85a6',
#  u'\u597d',
#  u'\u5496\u5561',
#  u'\u6c99\u76ae\u72d7',
#  u'\u6155\u65af',
#  u'\u86cb\u7cd5',
#  u'\u9192\u543e',
#  u'\u8523\u5abd',
#  u'\u5e97',
#  u'\u81fa\u5317',
#  u'\u9910\u5ef3',
#  u'\u89aa\u5b50',
#  u'\u751c',
#  u'\u7389\u5b50\u71d2',
#  u'\u6cf0\u5f0f\u7da0',
#  u'\u5496\u54e9\u96de',
#  u'\u59ae\u59ae',
#  u'\u96e3\u5403',
#  u'\u539f\u56e0',
#  u'\u63a8\u5ee3',
#  u'\u632a\u5a01',
#  u'\u9910\u5ef3',
#  u'\u902e',
#  u'\u4e38',
#  u'\u90ce',
#  u'\u97d3\u570b',
#  u'\u5f18\u5927',
#  u'\u65e9\u5348\u9910',
#  u'\u77e5\u9053',
#  u'\u96de\u7fc5',
#  u'\u724c',
#  u'\u897f\u5824',
#  u'\u751c\u9ede',
#  u'\u5403\u8ca8',
#  u'\u9eb5\u5305',
#  u'\u52a0',
#  u'\u5347\u7d1a',
#  u'\u81fa\u4e2d',
#  u'\u751c\u9ede',
#  u'\u98df\u8a18',
#  u'\u6850',
#  u'\u9e97\u9905',
#  u'\u5c0f',
#  u'\u8001\u95c6',
#  u'\u751c\u871c',
#  u'\u624b\u4f5c',
#  u'\u86cb\u7cd5',
#  u'\u661f\u5df4\u514b',
#  u'\u5f18\u5149',
#  u'\u59d0',
#  u'\u53ef\u8cb7',
#  u'\u5230',
#  u'\u6b50\u5f0f',
#  u'\u719f\u8089',
#  u'\u9ad8\u96c4',
#  u'\u6960\u6893',
#  u'\u65e9\u5348\u9910',
#  u'\u73cd\u73e0\u5976\u8336',
#  u'\u5275\u610f',
#  u'\u6599\u7406',
#  u'\u9177',
#  u'\u8056\u77f3',
#  u'\u68c9\u82b1\u7cd6',
#  u'\u9285\u947c\u71d2',
#  u'\u5973\u5b50',
#  u'\u98df\u5802',
#  u'\u91d1\u5c4b\u85cf\u5b0c',
#  u'\u8d8a\u5f0f',
#  u'\u6599\u7406',
#  u'\u7206\u6c23',
#  u'\u7b11\u6b7b',
#  u'\u9ad8\u96c4',
#  u'\u5546\u5708',
#  u'\u5065\u5eb7\u9910',
#  u'\u6c42',
#  u'\u6f8e\u6e56',
#  u'\u5403\u5230\u98fd',
#  u'\u71d2\u70e4',
#  u'\u5e97\u5bb6',
#  u'\u63a8\u85a6',
#  u'\u63a8\u85a6',
#  u'\u81fa\u5317',
#  u'\u9910\u5ef3',
#  u'\u5361\u5a1c',
#  u'\u8d6b\u62c9',
#  u'\u52a9',
#  u'\u86cb\u767d',
#  u'\u9905',
#  u'\u6a21\u5177',
#  u'\u4e0a\u73ed',
#  u'\u4fbf\u7576',
#  u'\u96d9\u5317',
#  u'\u4e0d\u932f',
#  u'\u7279\u8272',
#  u'\u9910\u5ef3',
#  u'\u9999\u8349',
#  u'\u7d19\u5305',
#  u'\u96de',
#  u'\u62b9\u8336',
#  u'\u86cb\u5854',
#  u'\u9650\u6642',
#  u'\u9910\u5ef3',
#  u'\u82b3',
#  u'\u828b\u982d',
#  u'\u9bae\u5976',
#  u'\u5ba2\u5bb6',
#  u'\u9ebb\u7cec',
#  u'\u63a8\u53f0',
#  u'\u597d\u559d',
#  u'\u73fe\u6253',
#  u'\u679c\u6c41',
#  u'\u725b\u5976',
#  u'\u885b\u751f',
#  u'\u96f6\u98df',
#  u'\u5fae\u9189',
#  u'\u8349\u8393',
#  u'\u624b\u5de5',
#  u'\u505a\u6210',
#  u'\u679c\u6f3f',
#  u'\u665a\u9910',
#  u'\u9ad8\u96c4',
#  u'\u611b\u5fc3',
#  u'\u756a\u8304',
#  u'\u9ad8\u96c4',
#  u'\u9ebb\u8fa3\u934b',
#  u'\u7cbd\u5b50',
#  u'\u65f1\u6eaa',
#  u'\u8e29\u5230',
#  u'\u96f7',
#  u'\u96d9\u8272',
#  u'\u68cb',
#  u'\u683c\u683c',
#  u'\u5b50',
#  u'\u9905\u4e7e',
#  u'\u91d1\u9580',
#  u'\u65b0',
#  u'\u7279\u7522',
#  u'\u9ad8\u7cb1',
#  u'\u871c\u991e',
#  u'\u706b\u934b',
#  u'\u6599',
#  u'\u505a',
#  u'\u65e5\u672c\u6599\u7406',
#  u'\u8c6c\u8089',
#  u'\u4e3c\u98ef',
#  u'\u7c21\u55ae',
#  u'\u4e0a\u624b',
#  u'\u53f0\u5357',
#  u'\u5929',
#  u'\u5403\u5230\u98fd',
#  u'\u6488',
#  u'\u597d\u5eb7',
#  u'\u696d\u914d',
#  u'\u65e9',
#  u'\u5348\u9910\u5e97',
#  u'\u7279\u8f2f',
#  u'\u81fa\u5317',
#  u'\u4fe1\u7fa9',
#  u'\u65d7\u8266\u5e97',
#  u'\u6a02\u5929',
#  u'\u5e0c\u81d8',
#  u'\u85cd\u8393',
#  u'\u512a\u683c',
#  u'\u96ea\u7cd5',
#  u'\u65b0\u7af9',
#  u'\u5403',
#  u'\u864e\u5c3e',
#  u'\u81ea\u52a9\u9910',
#  u'\u4fbf\u7576',
#  u'\u4fbf\u5b9c',
#  u'\u597d\u5403',
#  u'\u4fbf\u7576',
#  u'\u9999\u6e2f',
#  u'\u63a8\u85a6',
#  u'\u81fa\u7063',
#  u'\u7f8e\u98df',
#  u'\u96dc\u8a8c',
#  u'\u90e8\u843d\u5ba2',
#  u'\u4fbf\u7576',
#  u'\u6703\u4e0d\u6703',
#  u'\u4fbf\u5b9c',
#  u'\u8857',
#  u'\u89aa\u6c11',
#  u'\u7f8e\u98df',
#  u'\u5929\u4f7f',
#  u'\u96de\u86cb\u7cd5',
#  u'\u5403',
#  u'\u914d\u91ac',
#  u'\u5403',
#  u'\u4e0d\u5230',
#  u'\u98df\u7269',
#  u'\u8dea\u6c42',
#  u'\u9ad8\u96c4',
#  u'\u597d\u5403',
#  u'\u62c9\u9eb5',
#  u'\u81fa\u4e2d',
#  u'\u751c\u9ede',
#  u'\u98df\u8a18',
#  u'\u9b06\u9905',
#  u'\u6cf0\u5f0f\u7d05',
#  u'\u5496\u54e9\u98ef',
#  u'\u70e4',
#  u'\u621a\u98a8',
#  u'\u897f\u9580',
#  u'\u7f8e\u98df',
#  u'\u5abd\u54aa',
#  u'\u96de\u86cb\u4ed4',
#  u'\u6234',
#  u'\u7259\u5957',
#  u'\u5973\u53cb',
#  u'\u5973\u5b69',
#  u'\u6709\u5920',
#  u'\u61f6',
#  u'\u4e45\u9055',
#  u'\u716e',
#  u'\u7d00\u9304',
#  u'\u53f0\u5317',
#  u'\u9eb5\u5305',
#  u'\u53ef\u7e8c',
#  u'\u9910\u5ef3',
#  u'\u5d50',
#  u'\u63db\u5438',
#  u'\u5fae',
#  u'\u73cd\u73e0\u5976\u8336',
#  u'\u9ea5\u7247',
#  u'\u8001\u95c6',
#  u'\u4fbf\u7576',
#  u'\u98ef',
#  u'\u725b\u8089\u9eb5',
#  u'\u9ad8\u96c4',
#  u'\u5e6b\u5fd9',
#  u'\u6176\u751f',
#  u'\u9910\u5ef3',
#  u'\u6469\u65af',
#  u'\u65e5\u5f0f',
#  u'\u8c6c\u6392',
#  u'\u4e09\u660e\u6cbb',
#  u'\u5c0f\u6642\u5019',
#  u'\u61f7\u5ff5',
#  u'\u5473\u9053',
#  u'\u6a02\u83ef',
#  u'\u591c\u5e02',
#  u'\u9ebb\u7cec',
#  u'\u5403\u5230\u98fd',
#  u'\u5b9a\u7fa9',
#  u'\u6488',
#  u'\u5916\u9001\u54e1',
#  u'\u670d\u52d9\u614b\u5ea6',
#  u'\u6975\u5dee',
#  u'\u65e5\u672c',
#  u'\u7f8e\u98df',
#  u'\u9e7f\u5152\u5cf6',
#  u'\u904a\u5b78',
#  u'\u5403',
#  u'\u8393\u679c',
#  u'\u559c\u9905',
#  ...]

# %%
# Dcard心情版實驗
# title文字雲
# response文字雲
# title+response文字雲
from collections import Counter
def counter(board, word_count, top):
#     print(len(word_count)),Counter(word_count).most_common()
    text_list = [x for x in Counter(word_count).most_common() if len(x[0]) >1 ]
    text_list = text_list[:top]
#     print text_list[0]
    word_count_data = ""
    for t in text_list:
        if len(t[0]) <= 1:
            continue
    #     if t[0] in utility_word:
    #         continue
    
        print("----------------------")
        print(t[0] + " : " + str(t[1]))
        cql = ("insert into " + board_keyword + 
               "(board, keyword, count) values('" + board + "','" + t[0] + "'," + str(t[1]) + ");")
#         cql = ("update " + board_keyword + " " +
#                "set keyword = keyword + ['" + t[0] + "'] " +
#                "where board = '" + board + "';")
        print cql
        t_dao.execCQL(DB_KEYSPACE, cql)
#     for _ in range(t[1]):
#         word_count_data = word_count_data + " " + (t[0])

# %%
counter(board="relationship", 
        word_count=word_count_relationship,
        top=50)

# %%
counter(board="food", 
        word_count=word_count_food,
        top=300)
# Out:
# ----------------------
# 美食 : 554
# insert into board_keyword(board, keyword, count) values('food','美食',554);
# ----------------------
# 推薦 : 438
# insert into board_keyword(board, keyword, count) values('food','推薦',438);
# ----------------------
# 好吃 : 376
# insert into board_keyword(board, keyword, count) values('food','好吃',376);
# ----------------------
# 台南 : 274
# insert into board_keyword(board, keyword, count) values('food','台南',274);
# ----------------------
# 高雄 : 264
# insert into board_keyword(board, keyword, count) values('food','高雄',264);
# ----------------------
# 台北 : 259
# insert into board_keyword(board, keyword, count) values('food','台北',259);
# ----------------------
# 蛋糕 : 241
# insert into board_keyword(board, keyword, count) values('food','蛋糕',241);
# ----------------------
# 餐廳 : 234
# insert into board_keyword(board, keyword, count) values('food','餐廳',234);
# ----------------------
# 甜點 : 209
# insert into board_keyword(board, keyword, count) values('food','甜點',209);
# ----------------------
# 全家 : 190
# insert into board_keyword(board, keyword, count) values('food','全家',190);
# ----------------------
# 料理 : 186
# insert into board_keyword(board, keyword, count) values('food','料理',186);
# ----------------------
# 巧克力 : 142
# insert into board_keyword(board, keyword, count) values('food','巧克力',142);
# ----------------------
# 食記 : 137
# insert into board_keyword(board, keyword, count) values('food','食記',137);
# ----------------------
# 麥當勞 : 120
# insert into board_keyword(board, keyword, count) values('food','麥當勞',120);
# ----------------------
# 抹茶 : 115
# insert into board_keyword(board, keyword, count) values('food','抹茶',115);
# ----------------------
# 便當 : 108
# insert into board_keyword(board, keyword, count) values('food','便當',108);
# ----------------------
# 全聯 : 107
# insert into board_keyword(board, keyword, count) values('food','全聯',107);
# ----------------------
# 新品 : 99
# insert into board_keyword(board, keyword, count) values('food','新品',99);
# ----------------------
# 燒肉 : 96
# insert into board_keyword(board, keyword, count) values('food','燒肉',96);
# ----------------------
# 餅乾 : 92
# insert into board_keyword(board, keyword, count) values('food','餅乾',92);
# ----------------------
# 咖啡 : 88
# insert into board_keyword(board, keyword, count) values('food','咖啡',88);
# ----------------------
# 火鍋 : 88
# insert into board_keyword(board, keyword, count) values('food','火鍋',88);
# ----------------------
# 吃到飽 : 88
# insert into board_keyword(board, keyword, count) values('food','吃到飽',88);
# ----------------------
# 新竹 : 88
# insert into board_keyword(board, keyword, count) values('food','新竹',88);
# ----------------------
# 草莓 : 85
# insert into board_keyword(board, keyword, count) values('food','草莓',85);
# ----------------------
# 飲料 : 84
# insert into board_keyword(board, keyword, count) values('food','飲料',84);
# ----------------------
# 口味 : 81
# insert into board_keyword(board, keyword, count) values('food','口味',81);
# ----------------------
# 麵包 : 80
# insert into board_keyword(board, keyword, count) values('food','麵包',80);
# ----------------------
# 奶茶 : 79
# insert into board_keyword(board, keyword, count) values('food','奶茶',79);
# ----------------------
# 咖啡廳 : 79
# insert into board_keyword(board, keyword, count) values('food','咖啡廳',79);
# ----------------------
# 早餐 : 78
# insert into board_keyword(board, keyword, count) values('food','早餐',78);
# ----------------------
# 臺中 : 77
# insert into board_keyword(board, keyword, count) values('food','臺中',77);
# ----------------------
# 食譜 : 76
# insert into board_keyword(board, keyword, count) values('food','食譜',76);
# ----------------------
# 夜市 : 74
# insert into board_keyword(board, keyword, count) values('food','夜市',74);
# ----------------------
# 早午餐 : 74
# insert into board_keyword(board, keyword, count) values('food','早午餐',74);
# ----------------------
# 韓國 : 74
# insert into board_keyword(board, keyword, count) values('food','韓國',74);
# ----------------------
# 日本 : 70
# insert into board_keyword(board, keyword, count) values('food','日本',70);
# ----------------------
# 零食 : 70
# insert into board_keyword(board, keyword, count) values('food','零食',70);
# ----------------------
# 韓式 : 68
# insert into board_keyword(board, keyword, count) values('food','韓式',68);
# ----------------------
# 專業 : 68
# insert into board_keyword(board, keyword, count) values('food','專業',68);
# ----------------------
# 台中 : 67
# insert into board_keyword(board, keyword, count) values('food','台中',67);
# ----------------------
# 拉麵 : 66
# insert into board_keyword(board, keyword, count) values('food','拉麵',66);
# ----------------------
# 知道 : 66
# insert into board_keyword(board, keyword, count) values('food','知道',66);
# ----------------------
# 選擇 : 64
# insert into board_keyword(board, keyword, count) values('food','選擇',64);
# ----------------------
# 牛奶 : 64
# insert into board_keyword(board, keyword, count) values('food','牛奶',64);
# ----------------------
# 冰淇淋 : 63
# insert into board_keyword(board, keyword, count) values('food','冰淇淋',63);
# ----------------------
# 食物 : 62
# insert into board_keyword(board, keyword, count) values('food','食物',62);
# ----------------------
# 泡麵 : 59
# insert into board_keyword(board, keyword, count) values('food','泡麵',59);
# ----------------------
# 簡單 : 58
# insert into board_keyword(board, keyword, count) values('food','簡單',58);
# ----------------------
# 牛排 : 57
# insert into board_keyword(board, keyword, count) values('food','牛排',57);
# ----------------------
# 台灣 : 57
# insert into board_keyword(board, keyword, count) values('food','台灣',57);
# ----------------------
# 壽司 : 56
# insert into board_keyword(board, keyword, count) values('food','壽司',56);
# ----------------------
# 日式 : 55
# insert into board_keyword(board, keyword, count) values('food','日式',55);
# ----------------------
# 限時 : 55
# insert into board_keyword(board, keyword, count) values('food','限時',55);
# ----------------------
# 好喝 : 54
# insert into board_keyword(board, keyword, count) values('food','好喝',54);
# ----------------------
# 布丁 : 54
# insert into board_keyword(board, keyword, count) values('food','布丁',54);
# ----------------------
# 喜歡 : 53
# insert into board_keyword(board, keyword, count) values('food','喜歡',53);
# ----------------------
# 乳酪 : 53
# insert into board_keyword(board, keyword, count) values('food','乳酪',53);
# ----------------------
# 肯德基 : 52
# insert into board_keyword(board, keyword, count) values('food','肯德基',52);
# ----------------------
# 嘉義 : 51
# insert into board_keyword(board, keyword, count) values('food','嘉義',51);
# ----------------------
# 平價 : 50
# insert into board_keyword(board, keyword, count) values('food','平價',50);
# ----------------------
# 漢堡 : 50
# insert into board_keyword(board, keyword, count) values('food','漢堡',50);
# ----------------------
# 檸檬 : 49
# insert into board_keyword(board, keyword, count) values('food','檸檬',49);
# ----------------------
# 調查 : 49
# insert into board_keyword(board, keyword, count) values('food','調查',49);
# ----------------------
# 珍珠 : 48
# insert into board_keyword(board, keyword, count) values('food','珍珠',48);
# ----------------------
# 有沒有 : 47
# insert into board_keyword(board, keyword, count) values('food','有沒有',47);
# ----------------------
# 尋找 : 45
# insert into board_keyword(board, keyword, count) values('food','尋找',45);
# ----------------------
# 桃園 : 45
# insert into board_keyword(board, keyword, count) values('food','桃園',45);
# ----------------------
# 吐司 : 45
# insert into board_keyword(board, keyword, count) values('food','吐司',45);
# ----------------------
# 星巴克 : 45
# insert into board_keyword(board, keyword, count) values('food','星巴克',45);
# ----------------------
# 手作 : 45
# insert into board_keyword(board, keyword, count) values('food','手作',45);
# ----------------------
# 紅茶 : 45
# insert into board_keyword(board, keyword, count) values('food','紅茶',45);
# ----------------------
# 黑糖 : 44
# insert into board_keyword(board, keyword, count) values('food','黑糖',44);
# ----------------------
# 這是 : 44
# insert into board_keyword(board, keyword, count) values('food','這是',44);
# ----------------------
# 法式 : 42
# insert into board_keyword(board, keyword, count) values('food','法式',42);
# ----------------------
# 優惠 : 42
# insert into board_keyword(board, keyword, count) values('food','優惠',42);
# ----------------------
# 同學 : 42
# insert into board_keyword(board, keyword, count) values('food','同學',42);
# ----------------------
# 披薩 : 41
# insert into board_keyword(board, keyword, count) values('food','披薩',41);
# ----------------------
# 義大利麵 : 41
# insert into board_keyword(board, keyword, count) values('food','義大利麵',41);
# ----------------------
# 店家 : 40
# insert into board_keyword(board, keyword, count) values('food','店家',40);
# ----------------------
# 湯圓 : 40
# insert into board_keyword(board, keyword, count) values('food','湯圓',40);
# ----------------------
# 花蓮 : 40
# insert into board_keyword(board, keyword, count) values('food','花蓮',40);
# ----------------------
# 水餃 : 39
# insert into board_keyword(board, keyword, count) values('food','水餃',39);
# ----------------------
# 超商 : 39
# insert into board_keyword(board, keyword, count) values('food','超商',39);
# ----------------------
# 咖哩 : 38
# insert into board_keyword(board, keyword, count) values('food','咖哩',38);
# ----------------------
# 蜂蜜 : 38
# insert into board_keyword(board, keyword, count) values('food','蜂蜜',38);
# ----------------------
# 食圈 : 38
# insert into board_keyword(board, keyword, count) values('food','食圈',38);
# ----------------------
# 聚餐 : 38
# insert into board_keyword(board, keyword, count) values('food','聚餐',38);
# ----------------------
# 燒烤 : 37
# insert into board_keyword(board, keyword, count) values('food','燒烤',37);
# ----------------------
# 請益 : 37
# insert into board_keyword(board, keyword, count) values('food','請益',37);
# ----------------------
# 健康 : 37
# insert into board_keyword(board, keyword, count) values('food','健康',37);
# ----------------------
# 麻糬 : 36
# insert into board_keyword(board, keyword, count) values('food','麻糬',36);
# ----------------------
# 鬆餅 : 36
# insert into board_keyword(board, keyword, count) values('food','鬆餅',36);
# ----------------------
# 泡芙 : 36
# insert into board_keyword(board, keyword, count) values('food','泡芙',36);
# ----------------------
# 屏東 : 36
# insert into board_keyword(board, keyword, count) values('food','屏東',36);
# ----------------------
# 牛肉麵 : 35
# insert into board_keyword(board, keyword, count) values('food','牛肉麵',35);
# ----------------------
# 奶油 : 35
# insert into board_keyword(board, keyword, count) values('food','奶油',35);
# ----------------------
# 路易莎 : 35
# insert into board_keyword(board, keyword, count) values('food','路易莎',35);
# ----------------------
# 廚房 : 35
# insert into board_keyword(board, keyword, count) values('food','廚房',35);
# ----------------------
# 芋頭 : 35
# insert into board_keyword(board, keyword, count) values('food','芋頭',35);
# ----------------------
# 炸雞 : 34
# insert into board_keyword(board, keyword, count) values('food','炸雞',34);
# ----------------------
# 便宜 : 34
# insert into board_keyword(board, keyword, count) values('food','便宜',34);
# ----------------------
# 動態 : 33
# insert into board_keyword(board, keyword, count) values('food','動態',33);
# ----------------------
# 好市 : 33
# insert into board_keyword(board, keyword, count) values('food','好市',33);
# ----------------------
# 雪糕 : 32
# insert into board_keyword(board, keyword, count) values('food','雪糕',32);
# ----------------------
# 爭鮮 : 32
# insert into board_keyword(board, keyword, count) values('food','爭鮮',32);
# ----------------------
# 宵夜 : 32
# insert into board_keyword(board, keyword, count) values('food','宵夜',32);
# ----------------------
# 自製 : 32
# insert into board_keyword(board, keyword, count) values('food','自製',32);
# ----------------------
# 沙拉 : 31
# insert into board_keyword(board, keyword, count) values('food','沙拉',31);
# ----------------------
# 花生 : 31
# insert into board_keyword(board, keyword, count) values('food','花生',31);
# ----------------------
# 宜蘭 : 31
# insert into board_keyword(board, keyword, count) values('food','宜蘭',31);
# ----------------------
# 飯糰 : 30
# insert into board_keyword(board, keyword, count) values('food','飯糰',30);
# ----------------------
# 霜淇淋 : 30
# insert into board_keyword(board, keyword, count) values('food','霜淇淋',30);
# ----------------------
# 鮮奶 : 30
# insert into board_keyword(board, keyword, count) values('food','鮮奶',30);
# ----------------------
# 焦糖 : 29
# insert into board_keyword(board, keyword, count) values('food','焦糖',29);
# ----------------------
# 伴手禮 : 29
# insert into board_keyword(board, keyword, count) values('food','伴手禮',29);
# ----------------------
# 彰化 : 29
# insert into board_keyword(board, keyword, count) values('food','彰化',29);
# ----------------------
# 燉飯 : 28
# insert into board_keyword(board, keyword, count) values('food','燉飯',28);
# ----------------------
# 芋泥 : 28
# insert into board_keyword(board, keyword, count) values('food','芋泥',28);
# ----------------------
# 聯名 : 28
# insert into board_keyword(board, keyword, count) values('food','聯名',28);
# ----------------------
# 懶人 : 28
# insert into board_keyword(board, keyword, count) values('food','懶人',28);
# ----------------------
# 雞肉 : 27
# insert into board_keyword(board, keyword, count) values('food','雞肉',27);
# ----------------------
# 發現 : 27
# insert into board_keyword(board, keyword, count) values('food','發現',27);
# ----------------------
# 隱藏 : 27
# insert into board_keyword(board, keyword, count) values('food','隱藏',27);
# ----------------------
# 朋友 : 27
# insert into board_keyword(board, keyword, count) values('food','朋友',27);
# ----------------------
# 蛋餅 : 27
# insert into board_keyword(board, keyword, count) values('food','蛋餅',27);
# ----------------------
# 舒芙蕾 : 27
# insert into board_keyword(board, keyword, count) values('food','舒芙蕾',27);
# ----------------------
# 評比 : 27
# insert into board_keyword(board, keyword, count) values('food','評比',27);
# ----------------------
# 中壢 : 27
# insert into board_keyword(board, keyword, count) values('food','中壢',27);
# ----------------------
# 飲食 : 27
# insert into board_keyword(board, keyword, count) values('food','飲食',27);
# ----------------------
# 地瓜 : 27
# insert into board_keyword(board, keyword, count) values('food','地瓜',27);
# ----------------------
# 臭豆腐 : 26
# insert into board_keyword(board, keyword, count) values('food','臭豆腐',26);
# ----------------------
# 下午茶 : 26
# insert into board_keyword(board, keyword, count) values('food','下午茶',26);
# ----------------------
# 最愛 : 26
# insert into board_keyword(board, keyword, count) values('food','最愛',26);
# ----------------------
# 珍奶 : 26
# insert into board_keyword(board, keyword, count) values('food','珍奶',26);
# ----------------------
# 海鮮 : 26
# insert into board_keyword(board, keyword, count) values('food','海鮮',26);
# ----------------------
# 適合 : 26
# insert into board_keyword(board, keyword, count) values('food','適合',26);
# ----------------------
# 起司 : 26
# insert into board_keyword(board, keyword, count) values('food','起司',26);
# ----------------------
# 約會 : 26
# insert into board_keyword(board, keyword, count) values('food','約會',26);
# ----------------------
# 泰式 : 26
# insert into board_keyword(board, keyword, count) values('food','泰式',26);
# ----------------------
# 女友 : 26
# insert into board_keyword(board, keyword, count) values('food','女友',26);
# ----------------------
# 味道 : 26
# insert into board_keyword(board, keyword, count) values('food','味道',26);
# ----------------------
# 美味 : 25
# insert into board_keyword(board, keyword, count) values('food','美味',25);
# ----------------------
# 小吃 : 25
# insert into board_keyword(board, keyword, count) values('food','小吃',25);
# ----------------------
# 生魚片 : 25
# insert into board_keyword(board, keyword, count) values('food','生魚片',25);
# ----------------------
# 古早味 : 24
# insert into board_keyword(board, keyword, count) values('food','古早味',24);
# ----------------------
# 三明治 : 24
# insert into board_keyword(board, keyword, count) values('food','三明治',24);
# ----------------------
# 東京 : 24
# insert into board_keyword(board, keyword, count) values('food','東京',24);
# ----------------------
# 壽喜燒 : 24
# insert into board_keyword(board, keyword, count) values('food','壽喜燒',24);
# ----------------------
# 飲料店 : 24
# insert into board_keyword(board, keyword, count) values('food','飲料店',24);
# ----------------------
# 豆腐 : 24
# insert into board_keyword(board, keyword, count) values('food','豆腐',24);
# ----------------------
# 吃貨 : 24
# insert into board_keyword(board, keyword, count) values('food','吃貨',24);
# ----------------------
# 摩斯 : 24
# insert into board_keyword(board, keyword, count) values('food','摩斯',24);
# ----------------------
# 拿鐵 : 23
# insert into board_keyword(board, keyword, count) values('food','拿鐵',23);
# ----------------------
# 義式 : 23
# insert into board_keyword(board, keyword, count) values('food','義式',23);
# ----------------------
# 鮮奶茶 : 23
# insert into board_keyword(board, keyword, count) values('food','鮮奶茶',23);
# ----------------------
# 限定 : 23
# insert into board_keyword(board, keyword, count) values('food','限定',23);
# ----------------------
# 請進 : 23
# insert into board_keyword(board, keyword, count) values('food','請進',23);
# ----------------------
# 早餐店 : 23
# insert into board_keyword(board, keyword, count) values('food','早餐店',23);
# ----------------------
# 馬卡龍 : 23
# insert into board_keyword(board, keyword, count) values('food','馬卡龍',23);
# ----------------------
# 布朗尼 : 23
# insert into board_keyword(board, keyword, count) values('food','布朗尼',23);
# ----------------------
# 熊貓 : 23
# insert into board_keyword(board, keyword, count) values('food','熊貓',23);
# ----------------------
# 食堂 : 23
# insert into board_keyword(board, keyword, count) values('food','食堂',23);
# ----------------------
# 港式 : 23
# insert into board_keyword(board, keyword, count) values('food','港式',23);
# ----------------------
# 手工 : 23
# insert into board_keyword(board, keyword, count) values('food','手工',23);
# ----------------------
# 馬鈴薯 : 23
# insert into board_keyword(board, keyword, count) values('food','馬鈴薯',23);
# ----------------------
# 牛肉 : 23
# insert into board_keyword(board, keyword, count) values('food','牛肉',23);
# ----------------------
# 烤箱 : 22
# insert into board_keyword(board, keyword, count) values('food','烤箱',22);
# ----------------------
# 雞蛋糕 : 22
# insert into board_keyword(board, keyword, count) values('food','雞蛋糕',22);
# ----------------------
# 幸福 : 22
# insert into board_keyword(board, keyword, count) values('food','幸福',22);
# ----------------------
# 板橋 : 22
# insert into board_keyword(board, keyword, count) values('food','板橋',22);
# ----------------------
# 市場 : 22
# insert into board_keyword(board, keyword, count) values('food','市場',22);
# ----------------------
# 試吃 : 22
# insert into board_keyword(board, keyword, count) values('food','試吃',22);
# ----------------------
# 炒飯 : 22
# insert into board_keyword(board, keyword, count) values('food','炒飯',22);
# ----------------------
# 甜點店 : 22
# insert into board_keyword(board, keyword, count) values('food','甜點店',22);
# ----------------------
# 評價 : 22
# insert into board_keyword(board, keyword, count) values('food','評價',22);
# ----------------------
# 珍珠奶茶 : 22
# insert into board_keyword(board, keyword, count) values('food','珍珠奶茶',22);
# ----------------------
# 芒果 : 21
# insert into board_keyword(board, keyword, count) values('food','芒果',21);
# ----------------------
# 黃金 : 21
# insert into board_keyword(board, keyword, count) values('food','黃金',21);
# ----------------------
# 隱藏版 : 21
# insert into board_keyword(board, keyword, count) values('food','隱藏版',21);
# ----------------------
# 滷味 : 21
# insert into board_keyword(board, keyword, count) values('food','滷味',21);
# ----------------------
# 薯條 : 21
# insert into board_keyword(board, keyword, count) values('food','薯條',21);
# ----------------------
# 晚餐 : 21
# insert into board_keyword(board, keyword, count) values('food','晚餐',21);
# ----------------------
# 優格 : 20
# insert into board_keyword(board, keyword, count) values('food','優格',20);
# ----------------------
# 跪求 : 20
# insert into board_keyword(board, keyword, count) values('food','跪求',20);
# ----------------------
# 泡菜 : 20
# insert into board_keyword(board, keyword, count) values('food','泡菜',20);
# ----------------------
# 外送員 : 20
# insert into board_keyword(board, keyword, count) values('food','外送員',20);
# ----------------------
# 酒吧 : 20
# insert into board_keyword(board, keyword, count) values('food','酒吧',20);
# ----------------------
# 紅豆 : 20
# insert into board_keyword(board, keyword, count) values('food','紅豆',20);
# ----------------------
# 泰國 : 20
# insert into board_keyword(board, keyword, count) values('food','泰國',20);
# ----------------------
# 美式 : 19
# insert into board_keyword(board, keyword, count) values('food','美式',19);
# ----------------------
# 酒館 : 19
# insert into board_keyword(board, keyword, count) values('food','酒館',19);
# ----------------------
# 鮭魚 : 19
# insert into board_keyword(board, keyword, count) values('food','鮭魚',19);
# ----------------------
# 丼飯 : 19
# insert into board_keyword(board, keyword, count) values('food','丼飯',19);
# ----------------------
# 可可 : 19
# insert into board_keyword(board, keyword, count) values('food','可可',19);
# ----------------------
# 番茄 : 19
# insert into board_keyword(board, keyword, count) values('food','番茄',19);
# ----------------------
# 素食 : 19
# insert into board_keyword(board, keyword, count) values('food','素食',19);
# ----------------------
# 推推 : 19
# insert into board_keyword(board, keyword, count) values('food','推推',19);
# ----------------------
# 火鍋店 : 18
# insert into board_keyword(board, keyword, count) values('food','火鍋店',18);
# ----------------------
# 美國 : 18
# insert into board_keyword(board, keyword, count) values('food','美國',18);
# ----------------------
# 媽媽 : 18
# insert into board_keyword(board, keyword, count) values('food','媽媽',18);
# ----------------------
# 活動 : 18
# insert into board_keyword(board, keyword, count) values('food','活動',18);
# ----------------------
# 求解 : 18
# insert into board_keyword(board, keyword, count) values('food','求解',18);
# ----------------------
# 慶生 : 18
# insert into board_keyword(board, keyword, count) values('food','慶生',18);
# ----------------------
# 東西 : 18
# insert into board_keyword(board, keyword, count) values('food','東西',18);
# ----------------------
# 低碳 : 18
# insert into board_keyword(board, keyword, count) values('food','低碳',18);
# ----------------------
# 烤肉 : 18
# insert into board_keyword(board, keyword, count) values('food','烤肉',18);
# ----------------------
# 宿舍 : 18
# insert into board_keyword(board, keyword, count) values('food','宿舍',18);
# ----------------------
# 午餐 : 17
# insert into board_keyword(board, keyword, count) values('food','午餐',17);
# ----------------------
# 月餅 : 17
# insert into board_keyword(board, keyword, count) values('food','月餅',17);
# ----------------------
# 氣炸鍋 : 17
# insert into board_keyword(board, keyword, count) values('food','氣炸鍋',17);
# ----------------------
# 員工 : 17
# insert into board_keyword(board, keyword, count) values('food','員工',17);
# ----------------------
# 提拉米蘇 : 17
# insert into board_keyword(board, keyword, count) values('food','提拉米蘇',17);
# ----------------------
# 男友 : 17
# insert into board_keyword(board, keyword, count) values('food','男友',17);
# ----------------------
# 香港 : 17
# insert into board_keyword(board, keyword, count) values('food','香港',17);
# ----------------------
# 信義 : 17
# insert into board_keyword(board, keyword, count) values('food','信義',17);
# ----------------------
# 貝果 : 17
# insert into board_keyword(board, keyword, count) values('food','貝果',17);
# ----------------------
# 澎湖 : 17
# insert into board_keyword(board, keyword, count) values('food','澎湖',17);
# ----------------------
# 基隆 : 17
# insert into board_keyword(board, keyword, count) values('food','基隆',17);
# ----------------------
# 日記 : 17
# insert into board_keyword(board, keyword, count) values('food','日記',17);
# ----------------------
# 雞胸肉 : 17
# insert into board_keyword(board, keyword, count) values('food','雞胸肉',17);
# ----------------------
# 豆花 : 17
# insert into board_keyword(board, keyword, count) values('food','豆花',17);
# ----------------------
# 天堂 : 16
# insert into board_keyword(board, keyword, count) values('food','天堂',16);
# ----------------------
# 老闆 : 16
# insert into board_keyword(board, keyword, count) values('food','老闆',16);
# ----------------------
# 麥片 : 16
# insert into board_keyword(board, keyword, count) values('food','麥片',16);
# ----------------------
# 抱怨 : 16
# insert into board_keyword(board, keyword, count) values('food','抱怨',16);
# ----------------------
# 點心 : 16
# insert into board_keyword(board, keyword, count) values('food','點心',16);
# ----------------------
# 冰沙 : 16
# insert into board_keyword(board, keyword, count) values('food','冰沙',16);
# ----------------------
# 義美 : 16
# insert into board_keyword(board, keyword, count) values('food','義美',16);
# ----------------------
# 意外 : 16
# insert into board_keyword(board, keyword, count) values('food','意外',16);
# ----------------------
# 香草 : 16
# insert into board_keyword(board, keyword, count) values('food','香草',16);
# ----------------------
# 八方 : 16
# insert into board_keyword(board, keyword, count) values('food','八方',16);
# ----------------------
# 烤雞 : 16
# insert into board_keyword(board, keyword, count) values('food','烤雞',16);
# ----------------------
# 雞排 : 16
# insert into board_keyword(board, keyword, count) values('food','雞排',16);
# ----------------------
# 巷弄 : 16
# insert into board_keyword(board, keyword, count) values('food','巷弄',16);
# ----------------------
# 雞湯 : 16
# insert into board_keyword(board, keyword, count) values('food','雞湯',16);
# ----------------------
# 風味 : 16
# insert into board_keyword(board, keyword, count) values('food','風味',16);
# ----------------------
# 捷運站 : 16
# insert into board_keyword(board, keyword, count) values('food','捷運站',16);
# ----------------------
# 淡水 : 15
# insert into board_keyword(board, keyword, count) values('food','淡水',15);
# ----------------------
# 冰店 : 15
# insert into board_keyword(board, keyword, count) values('food','冰店',15);
# ----------------------
# 限動 : 15
# insert into board_keyword(board, keyword, count) values('food','限動',15);
# ----------------------
# 部落客 : 15
# insert into board_keyword(board, keyword, count) values('food','部落客',15);
# ----------------------
# 吃法 : 15
# insert into board_keyword(board, keyword, count) values('food','吃法',15);
# ----------------------
# 店名 : 15
# insert into board_keyword(board, keyword, count) values('food','店名',15);
# ----------------------
# 台中市 : 15
# insert into board_keyword(board, keyword, count) values('food','台中市',15);
# ----------------------
# 吃吃 : 15
# insert into board_keyword(board, keyword, count) values('food','吃吃',15);
# ----------------------
# 煉乳 : 15
# insert into board_keyword(board, keyword, count) values('food','煉乳',15);
# ----------------------
# 海港 : 15
# insert into board_keyword(board, keyword, count) values('food','海港',15);
# ----------------------
# 火車站 : 15
# insert into board_keyword(board, keyword, count) values('food','火車站',15);
# ----------------------
# 小七 : 15
# insert into board_keyword(board, keyword, count) values('food','小七',15);
# ----------------------
# 麻辣鍋 : 15
# insert into board_keyword(board, keyword, count) values('food','麻辣鍋',15);
# ----------------------
# 得到 : 15
# insert into board_keyword(board, keyword, count) values('food','得到',15);
# ----------------------
# 拜託 : 15
# insert into board_keyword(board, keyword, count) values('food','拜託',15);
# ----------------------
# 雞腿堡 : 15
# insert into board_keyword(board, keyword, count) values('food','雞腿堡',15);
# ----------------------
# 飲品 : 15
# insert into board_keyword(board, keyword, count) values('food','飲品',15);
# ----------------------
# 蛤蜊 : 15
# insert into board_keyword(board, keyword, count) values('food','蛤蜊',15);
# ----------------------
# 報報 : 15
# insert into board_keyword(board, keyword, count) values('food','報報',15);
# ----------------------
# 外宿 : 14
# insert into board_keyword(board, keyword, count) values('food','外宿',14);
# ----------------------
# 失敗 : 14
# insert into board_keyword(board, keyword, count) values('food','失敗',14);
# ----------------------
# 平台 : 14
# insert into board_keyword(board, keyword, count) values('food','平台',14);
# ----------------------
# 麵線 : 14
# insert into board_keyword(board, keyword, count) values('food','麵線',14);
# ----------------------
# 楠梓 : 14
# insert into board_keyword(board, keyword, count) values('food','楠梓',14);
# ----------------------
# 超高 : 14
# insert into board_keyword(board, keyword, count) values('food','超高',14);
# ----------------------
# 公館 : 14
# insert into board_keyword(board, keyword, count) values('food','公館',14);
# ----------------------
# 自助餐 : 14
# insert into board_keyword(board, keyword, count) values('food','自助餐',14);
# ----------------------
# 傳統 : 14
# insert into board_keyword(board, keyword, count) values('food','傳統',14);
# ----------------------
# 豬排 : 14
# insert into board_keyword(board, keyword, count) values('food','豬排',14);
# ----------------------
# 回歸 : 14
# insert into board_keyword(board, keyword, count) values('food','回歸',14);
# ----------------------
# 幫忙 : 14
# insert into board_keyword(board, keyword, count) values('food','幫忙',14);
# ----------------------
# 教學 : 14
# insert into board_keyword(board, keyword, count) values('food','教學',14);
# ----------------------
# 冷凍 : 14
# insert into board_keyword(board, keyword, count) values('food','冷凍',14);
# ----------------------
# 爆米花 : 14
# insert into board_keyword(board, keyword, count) values('food','爆米花',14);
# ----------------------
# 情人節 : 14
# insert into board_keyword(board, keyword, count) values('food','情人節',14);
# ----------------------
# 涼麵 : 14
# insert into board_keyword(board, keyword, count) values('food','涼麵',14);
# ----------------------
# 玉米 : 14
# insert into board_keyword(board, keyword, count) values('food','玉米',14);
# ----------------------
# 炒麵 : 14
# insert into board_keyword(board, keyword, count) values('food','炒麵',14);
# ----------------------
# 果醬 : 14
# insert into board_keyword(board, keyword, count) values('food','果醬',14);
# ----------------------
# 菜單 : 14
# insert into board_keyword(board, keyword, count) values('food','菜單',14);
# ----------------------
# 榴槤 : 14
# insert into board_keyword(board, keyword, count) values('food','榴槤',14);
# ----------------------
# 慕斯 : 14
# insert into board_keyword(board, keyword, count) values('food','慕斯',14);
# ----------------------
# 介紹 : 14
# insert into board_keyword(board, keyword, count) values('food','介紹',14);
# ----------------------
# 套餐 : 13
# insert into board_keyword(board, keyword, count) values('food','套餐',13);
# ----------------------
# 日本料理 : 13
# insert into board_keyword(board, keyword, count) values('food','日本料理',13);
# ----------------------
# 捷運 : 13
# insert into board_keyword(board, keyword, count) values('food','捷運',13);
# ----------------------
# 脆皮 : 13
# insert into board_keyword(board, keyword, count) values('food','脆皮',13);
# ----------------------
# 燕麥 : 13
# insert into board_keyword(board, keyword, count) values('food','燕麥',13);
# ----------------------
# 大學 : 13
# insert into board_keyword(board, keyword, count) values('food','大學',13);
# ----------------------
# 咖啡店 : 13
# insert into board_keyword(board, keyword, count) values('food','咖啡店',13);
# ----------------------
# 北區 : 13
# insert into board_keyword(board, keyword, count) values('food','北區',13);
# ----------------------
# 看到 : 13
# insert into board_keyword(board, keyword, count) values('food','看到',13);
# ----------------------
# 葡萄 : 13
# insert into board_keyword(board, keyword, count) values('food','葡萄',13);
# ----------------------
# 萊爾富 : 13
# insert into board_keyword(board, keyword, count) values('food','萊爾富',13);
# ----------------------
# 咖哩飯 : 13
# insert into board_keyword(board, keyword, count) values('food','咖哩飯',13);
# ----------------------
# 連鎖 : 13
# insert into board_keyword(board, keyword, count) values('food','連鎖',13);
# ----------------------
# 初鹿 : 13
# insert into board_keyword(board, keyword, count) values('food','初鹿',13);
# ----------------------
# 肉鬆 : 13
# insert into board_keyword(board, keyword, count) values('food','肉鬆',13);
# ----------------------
# 使用 : 13
# insert into board_keyword(board, keyword, count) values('food','使用',13);
# ----------------------
# 難吃 : 13
# insert into board_keyword(board, keyword, count) values('food','難吃',13);
# ----------------------
# 免費 : 13
# insert into board_keyword(board, keyword, count) values('food','免費',13);
# ----------------------
# 人生 : 13
# insert into board_keyword(board, keyword, count) values('food','人生',13);

# %%
response_cql = ""
count_list = ["a","b","c","d","e"]
for count in count_list:
    response_cql = response_cql + "'" + count + "',"
response_cql = response_cql[:-1]
response_cql

# %%
# # Libraries
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt
# font_path = "/home/charles/YaHeiConsolas.ttf"
# # Create the wordcloud object
# wordcloud = WordCloud(width=640, height=640, margin=0, 
#                       font_path=font_path, colormap="Blues").generate(word_count_data[1:])
 
# # Display the generated image:
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.margins(x=0, y=0)
# plt.show()

# %%
# mapping_pd = pd.DataFrame({'name':['a','b','c','a','c','c'],
#                            'word':[['aa'],['bb'],['bb'],['aa'],['cc'],['cc']]})
mapping_pd = pd.DataFrame({'name':['a','b','c','a','c','c'],
                           'word':['aa','bb','bb','aa','cc','cc']})
# mapping_pd.groupby(['name'])['name','word'].apply(lambda x: x.append(x)).reset_index(drop=True)

df = mapping_pd.groupby('name').agg({'name':'first',
                                     'word':','.join}).reset_index(drop=True)
df
# df[['name','word']]

# %%
aa = ['*','B','C']
aa = [x.lower() for x in aa]
','.join(aa)

# %%
mapping_pd = pd.DataFrame({'name':['a','b','c','a','c','c'],
                           'word':['aa','bb','bb','aa','cc','cc']})
mapping_pd
# word_match_pd = board_keyword_df[board_keyword_df["keyword"].str.match('|'.join(word_list))]

# %%
word_list = ["aa"]
mapping_pd[mapping_pd["word"].str in word_list]
