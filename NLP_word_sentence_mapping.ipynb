# %%
# encoding=UTF-8
# !flask/bin/python

from cassandra.cluster import Cluster
from cassandra.policies import DCAwareRoundRobinPolicy
from cassandra.auth import PlainTextAuthProvider
from cassandra.query import BatchStatement
import pandas as pd
# from pyspark.sql.types import StringType, StructType, StructField


class CassandraType(object):
    PRODUCTION = 0
    TEST = 1
    TEST_DOCKER = 2


class CassandraDAO(object):

    # you have to install following items :
    # a. python-Cassandra driver
    # b. pyspark cassandra connector

    def __init__(self, type):
        #         print('runing father.__init__')
        if type == CassandraType.PRODUCTION:
            self.contact_points = ['192.168.95.127', '192.168.95.122']
            self.contact_points_str = "192.168.95.127,192.168.95.122"
        elif type == CassandraType.TEST:
            self.contact_points = ['192.168.0.41', '192.168.0.42']
            self.contact_points_str = "192.168.0.41,192.168.0.42"
        else:
            self.contact_points = ['192.168.0.121', '192.168.0.122', '192.168.0.52']
            self.contact_points_str = "192.168.0.121,192.168.0.122,192.168.0.52"

        self.formatString = "org.apache.spark.sql.cassandra"
        self.username = "username"
        self.password = "password"
        self.cluster = None
        self.session = None
        self.createSession()

    def __del__(self):
        self.cluster.shutdown()

    def pandas_factory(self, colnames, rows):
        return pd.DataFrame(rows, columns=colnames)

    def createSession(self):
        print "contact_points = " + self.contact_points_str
        self.cluster = Cluster(
            contact_points=self.contact_points,  # random select a node
            #             load_balancing_policy = DCAwareRoundRobinPolicy(local_dc='datacenter1'),
            #         auth_provider = PlainTextAuthProvider(username='cassandra', password='cassandra')
        )
        self.session = self.cluster.connect()
        self.session.row_factory = self.pandas_factory
        self.session.default_fetch_size = None
        # needed for large queries, otherwise driver will do pagination. Default is 50000.

    def getSession(self):
        return self.session

    def execCQL(self, keyspace, cql):
        """
        execute CQL
        """
        self.session.set_keyspace(keyspace)
        self.session.execute_async(cql)

    def execCQLSelect(self, keyspace, cql):
        """
        execute CQL, select only
        """

        self.session.set_keyspace(keyspace)

        #       cassandra ResultSet
        async_results = self.session.execute_async(cql)
        return async_results

    def execCQLCallBackAnysc(self, keyspace, cql, handle_success, handle_error):
        """
        execute CQL, if success => handle_success function, else handle_error
        """
        self.session.set_keyspace(keyspace)
        async_results = self.session.execute_async(cql)
        async_results.add_callbacks(handle_success, handle_error)

    def execCQLSelectToPandasDF(self, keyspace, cql):
        """
        execute CQL, select only, return Pandas DataFrame
        """

        self.session.set_keyspace(keyspace)

        #       cassandra ResultSet
#         async_results = self.session.execute_async(cql, timeout=None)
        results = self.session.execute(cql, timeout=None)
        #         async_results = self.session.execute_async(cql)
        #       to Pandas DataFrame
#         return async_results.result()._current_rows
        return results._current_rows

    def execCQLSelectToDF(self, sqlContext, keyspace, cql):
        """
        execute CQL, select only, return Spark DataFrame
        """

        #       pandas dataframe to spark dataframe
        pandas_dataframe = self.execCQLSelectToPandasDF(keyspace, cql)
        if pandas_dataframe.empty:
            schema = StructType([])
            return sqlContext.createDataFrame([], schema)
        else:
            return sqlContext.createDataFrame(pandas_dataframe)

    def execCQLSelectToRDD(self, sqlContext, keyspace, cql):
        """
        execute CQL, select only, return Spark RDD
        """

        return self.execCQLSelectToDF(sqlContext, keyspace, cql).rdd.map(tuple)  # dataFrame to RDD

    @property
    def contactPoints(self):
        return self.contact_points

    @contactPoints.setter
    def contactPoints(self, contact_points):
        self.contact_points = contact_points

    @contactPoints.deleter
    def contactPoints(self):
        del self.contact_points

#     # pyspark cassandra connector
#     def readFromCassandraDF(self, sqlContext, keyspace, table):
#         """
#         read data from Cassandra, return Dataframe
#         """

#         return sqlContext.read \
#             .format(self.formatString) \
#             .options(table=table, keyspace=keyspace) \
#             .option("spark.cassandra.connection.host", self.contact_points_str) \
#             .load()

#     def readFromCassandraRDD(self, sqlContext, keyspace, table):
#         """
#         read data from Cassandra, return RDD
#         """

#         df = sqlContext.read \
#             .format(self.formatString) \
#             .options(table=table, keyspace=keyspace) \
#             .option("spark.cassandra.connection.host", self.contact_points_str) \
#             .load()
#         return df.rdd.map(tuple)  # dataFrame to RDD

#     def saveToCassandraDF(self, dataFrame, keyspace, table, mode="error"):
#         """
#         Save data to Cassandra using DataFrame, select one mode to save
        
#         SaveMode.ErrorIfExists (default) | "error"      When saving a DataFrame to a data source,
#                                                         if data already exists, an exception is expected to be thrown.
#         SaveMode.Append                  | "append"     When saving a DataFrame to a data source,
#                                                         if data/table already exists, contents of the DataFrame are
#                                                         expected to be appended to existing data.
#         SaveMode.Overwrite               | "overwrite"  Overwrite mode means that when saving a DataFrame to a data source,
#                                                         if data/table already exists, existing data is expected to be
#                                                         overwritten by the contents of the DataFrame.
#         SaveMode.Ignore                  | "ignore"     Ignore mode means that when saving a DataFrame to a data source,
#                                                         if data already exists, the save operation is expected to not
#                                                         save the contents of the DataFrame and to not change the
#                                                         existing data. This is similar to a CREATE TABLE IF NOT EXISTS

#                                                         in SQL.
#         """

#         dataFrame.write \
#             .format(self.formatString) \
#             .mode(mode) \
#             .options(table=table, keyspace=keyspace) \
#             .option("spark.cassandra.connection.host", self.contact_points_str) \
#             .save()

# %%
dao = CassandraDAO('BACKUP')
# Out:
# contact_points = 192.168.0.121,192.168.0.122,192.168.0.52

# %%
import pandas as pd
import jieba
import jieba.posseg as pseg

class JiebaSegmentor:

    def __init__(self, dict_path, userdict=[], stopwords = False, stopwords_path=None):
        self.dict_path = dict_path
        self.userdict = userdict
        self.dictionary_init()
        self.stopwords_path = stopwords_path
        self.stopwords = stopwords
        self.stopwords_set = set()
        self.stopwords_init()

    def dictionary_init(self):
        jieba.set_dictionary(self.dict_path)
        for path in self.userdict:
            print path
            jieba.load_userdict(path)
    
    def stopwords_init(self):
        if self.stopwords_path:
            with open(self.stopwords_path ,'r') as stopwords:
                for stopword in stopwords:
                    self.stopwords_set.add(stopword.strip('\n').decode('utf-8'))

    def taiwan_country(self):
        return [u'臺北', u'台北', u'基隆', u'臺中', u'台中', u'臺南', u'台南', u'高雄',
                u'宜蘭', u'桃園', u'新竹', u'苗栗', u'彰化', u'南投', u'嘉義', u'雲林',
                u'屏東', u'臺東', u'台東', u'花蓮', u'澎湖']

    def wordToNumber(self, input_text):

        target = u''
        for s in input_text:

            if (s == u'零') or (s == '0'):
                to_word = u'0'
            elif (s == u'一') or (s == u'壹') or (s == '1'):
                to_word = u'1'
            elif (s == u'二') or (s == u'兩') or (s == u'貳') or (s == '2'):
                to_word = u'2'
            elif (s == u'三') or (s == u'參') or (s == '3'):
                to_word = u'3'
            elif (s == u'四') or (s == u'肆') or (s == '4'):
                to_word = u'4'
            elif (s == u'五') or (s == u'伍') or (s == '5'):
                to_word = u'5'
            elif (s == u'六') or (s == u'陸') or (s == '6'):
                to_word = u'6'
            elif (s == u'七') or (s == u'柒') or (s == '7'):
                to_word = u'7'
            elif (s == u'八') or (s == u'捌') or (s == '8'):
                to_word = u'8'
            elif (s == u'九') or (s == u'玖') or (s == '9'):
                to_word = u'9'
            else:
                to_word = s

        target = target + to_word
        return target

    def input_text_preprocessing(self, input_text):

        if type(input_text) is not unicode:
            input_text = input_text.decode('utf-8')

#         input_text = self.wordToNumber(input_text)
        return input_text

    def get_names(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        names = []
        words = pseg.cut(input_text)
        print words
        for w, f in words:
            if f.lower() == 'nr':
                names.append(w)
        for name in names:
            print name.encode('utf-8')
        return names

    def lcut(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        cut_raw = jieba.lcut(input_text)
        key = []

        for k in cut_raw:
            if self.stopwords:
                if k in self.stopwords_set:
                    continue
            
            key.append(k)
        df = pd.DataFrame({"word": key})
        return df

    def pseg_lcut(self, input_text):

        input_text = self.input_text_preprocessing(input_text)
        cut_raw = pseg.lcut(input_text)
        key = []
        value = []

        for k, v in cut_raw:
            tag = v
            if self.stopwords:
                if k in self.stopwords_set:
                    continue
            
            if k in self.taiwan_country():
                tag = u'ns'
            if len(k) > 1 and tag == u'x':
                tag = u'n'
            key.append(k)
            value.append(tag)
        df = pd.DataFrame({"word": key, "tag": value})
        return df

# %%
jieba_dict_path1 = "/home/charles/dataset/jieba/dict_taiwan.txt"
jieba_dict_path2 = "/home/charles/dataset/jieba/userdict.txt"
jieba_dict_path3 = "/home/charles/dataset/jieba/dict.txt.big"
jieba_dict_path4 = "/home/charles/dataset/jieba/dict.txt.small"
jieba_stopwords_path = "/home/charles/dataset/jieba/stopwords.txt"
segmentor = JiebaSegmentor(jieba_dict_path1, 
                           [jieba_dict_path2,jieba_dict_path3,jieba_dict_path4], 
                           stopwords = False, 
                           stopwords_path=jieba_stopwords_path)
# Out:
# Building prefix dict from /home/charles/dataset/jieba/dict_taiwan.txt ...
# DEBUG:jieba:Building prefix dict from /home/charles/dataset/jieba/dict_taiwan.txt ...
# Loading model from cache /tmp/jieba.u48306fa201322dcccc3d0c62898fbadc.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.u48306fa201322dcccc3d0c62898fbadc.cache
# Loading model cost 0.389 seconds.
# DEBUG:jieba:Loading model cost 0.389 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# /home/charles/dataset/jieba/userdict.txt
# /home/charles/dataset/jieba/dict.txt.big
# /home/charles/dataset/jieba/dict.txt.small

# %%
segmentor.stopwords=False
segmentor.pseg_lcut('或許今天阿伯的媽媽給我好大一包的紅包喔')
# Out:
#    tag word
# 0    d   或許
# 1    t   今天
# 2   ns   阿伯
# 3   uj    的
# 4    n   媽媽
# 5    p    給
# 6    r    我
# 7    a    好
# 8    a    大
# 9    m   一包
# 10  uj    的
# 11   n   紅包
# 12   e    喔

# %%
segmentor.stopwords=True
segmentor.pseg_lcut('或許今天阿伯的媽媽給我好大一包的紅包喔')
# Out:
#   tag word
# 0   t   今天
# 1  ns   阿伯
# 2   n   媽媽
# 3   a    好
# 4   m   一包
# 5   n   紅包
# 6   e    喔

# %%
HELPER_KEYSPACE = 'nlp_keyspace'
#select range
cql = ("select * from nlp_keyspace.dcard_article " +
        "where article_id > 0 and article_id < 5000 allow filtering;")
cql = ("select * from nlp_keyspace.dcard_article where article_id > 205000 and " +
       "article_id < 210000 allow filtering;")
pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
print len(pd_df)
pd_df
# Out:
# 341
#      article_id     board category  \
# 0        207159      mood     None
# 1        206571      talk     None
# 2        205492      mood     None
# 3        209409      talk     None
# 4        207108      mood     None
# 5        205870      mood     None
# 6        208405      mood     None
# 7        206930      mood     None
# 8        207149      talk     None
# 9        206547      talk     None
# 10       207055      mood     None
# 11       206354      mood     None
# 12       207386      mood     None
# 13       208675      talk     None
# 14       208185      mood     None
# 15       207156      mood     None
# 16       207353      mood     None
# 17       209454      mood     None
# 18       206194      mood     None
# 19       208341      mood     None
# 20       209502      mood     None
# 21       205165      mood     None
# 22       208433      mood     None
# 23       209984      mood     None
# 24       205595      talk     None
# 25       208077      mood     None
# 26       209964      talk     None
# 27       205953      talk     None
# 28       206637       job     None
# 29       207166      talk     None
# ..          ...       ...      ...
# 311      207437      mood     None
# 312      206447      mood     None
# 313      208280      food     None
# 314      209767      mood     None
# 315      207288      food     None
# 316      206828      talk     None
# 317      207231      mood     None
# 318      208987      talk     None
# 319      206602      talk     None
# 320      206804      mood     None
# 321      205344      mood     None
# 322      205243  trending     None
# 323      205722       job     None
# 324      207091      talk     None
# 325      206232      mood     None
# 326      205011      mood     None
# 327      206927      talk     None
# 328      209133      talk     None
# 329      209757      mood     None
# 330      206372      talk     None
# 331      205150      talk     None
# 332      207327      talk     None
# 333      208286      mood     None
# 334      209273      mood     None
# 335      205792      talk     None
# 336      205648      mood     None
# 337      209958      talk     None
# 338      206800      mood     None
# 339      205196  trending     None
# 340      205345      mood     None
#
#                                                content  \
# 0    前情提要(文超長)小時候的體罰影響真的很深最近因為考試所以壓力有點兒大rrrr\n想到了一些...
# 1    下個月似乎就要送舊了某收錢人員密我某:你要去送舊嗎?我:沒有耶，我有事某:那你要繳200喔!...
# 2    期待好久的中央中文轉學考竟然不開大二的缺，覺得無敵傷心。要是大三才轉，學業一定會很嚴重地落後...
# 3                  很多肥宅都滿喜歡AKB48的，可是有正妹喜歡AKB48嗎？有沒有八卦？
# 4    最近因為考試所以壓力有點兒大rrrr想到了一些以前的事情原PO家庭蠻嚴格的我一直記得我剛上小...
# 5    2015/05/17之前，我們沒有見過半次面，或許你連我的聲音都沒有聽過，我們只在RC上交流...
# 6    班上有一個我不喜歡的人因為他跟我們這一群是朋友所以我跟他也只好表面上是朋友，其實心裡一直不喜...
# 7    今天真是彼母之不順早上七早八早起來載我弟去上課之後準備載我每天通勤的同學回來臺北上課突然發現...
# 8    如果有崩潰板我應該會果斷發在那.........本PO的字扭來扭去 擠在一起  像是小學生是...
# 9    想問大家對於做一份報告願意付出每人不超過500元的金錢嗎？例如主題是蘋果, 願意買不同品種的...
# 10   今天早上一路奔波從南部家裡到北部學校雖然已經當了超過一學期的大學生但是一踏入宿舍還是有點.....
# 11   生活在工科的女生，其實也是很渴望認識女生的但是經過努力之下，還是只有一個要好的女生朋友，從高...
# 12   原po是個豐滿、胖胖的女生，又長到接近170，看起來就略嫌大隻。在一間算是充滿著正妹的學校念...
# 13   曾經參加過的教育性營隊最近要公開說明會有不清楚自己將來想做什麼的很推薦參加喔～-------...
# 14   看著狄卡很多抒發高中跟大學的差別也覺得好感慨啊高中的時候讀女校女校就是外面給人乖巧的假象但是...
# 15   本人是個大書痴很喜歡窩在書店裡面手機滿滿都是待閱list恰巧我住臺北恰巧我有個跟我興趣相仿的...
# 16   我已經不去看也不去想但是還是有共同朋友還是會看到狀態雖然不知道發生什麼事依舊想要挽回我們的友...
# 17   今天面試完的了大樓管理員，被面試的總幹事虧到整個人都無地自容了：「哎唷，怎麼唸到碩士了來做這...
# 18   當你剪了新頭髮，穿新衣服，跟過去的自己說掰掰，心情本來是愉悅的⊙▽⊙但是只要有人開口講這一句...
# 19   看到很多人在討論大學不比以前高中國中單純認識的朋友也很複雜好像每天都在耍心機但我覺得是人都有...
# 20   只要你一犯錯一次，每個人都會說，你每次都是這樣。活在這樣的陰影下，漸漸的我失落了這份工作，壓...
# 21   半夢半醒做了個怪夢夢裡和一群朋友去間餐廳吃飯聊天結果看見前女友和她的男友正在另一張桌子分手我...
# 22   [有點不知道要發在哪版比較好，先發在心情好了，因為被嚇壞了]剛剛上某一堂必修因為老師突然說下...
# 23   時間：5/17 星期日 早上11點左右地點：台中市潭子區旱溪西路(靠近嘉豐路96巷口)我母親...
# 24   剛剛看到一篇歧視高職生的文章在這，我要大大鼓勵高職生，你們不要覺得被歧視我國中考基測，因為喜...
# 25   不知道大家有沒有聽過爸爸媽媽的情史？媽媽小檔案：據媽媽說她以前有驕傲的23腰據說媽媽她和朋友...
# 26   我家室友OO是一個很特別的人她完全不吃蔬菜，是「完全」哦大部分的人是不吃特定蔬菜像是紅蘿蔔之...
# 27   在Dcard的肥宅們 打gay賀 如果今天有一位正妹跟你說"如果你減肥到XX公斤就當你女朋友...
# 28   如題想請問大家有沒有在這其中一家打工換宿過呢？目前兩家都有上 但是第一次嘗試打工換宿，不知道...
# 29   大家平日穿著都怎麼穿呢我習慣穿長袖襯衫+丹寧褲、休閒褲天氣微熱就穿件簡單的t配上長袖襯衫捲袖...
# ..                                                 ...
# 311  昨天，是妳的生日。生日快樂，我只在訊息裡留下這四個字，然後回到召喚峽谷，繼續戰鬥。不久之後，...
# 312  上一次被釣也是常常來密我找我聊天聊久變成習慣後自己反而變成主動的那一方電話get後還講得很開...
# 313  這是剛剛在校園裡買的手工餅乾因為太久沒做餅乾了，頓時嘴巴有點嘴饞xD說真的這小小一盒不便宜啊...
# 314  最近我們有一份可以抵期末考的報告，因為我覺得做每件事都應該要認真去做，因此我花不少時間在做這...
# 315  來新竹快要一年了 總覺得吃的東西都是那幾樣阿 每次在學校跟實驗室的學長們決定要吃甚麼都苦思好...
# 316  你們對於肥宅的觀感其實並不完全正確肥宅 雖然可能又醜又肥又宅 又臭酸但肥宅交不到女友是因為沒...
# 317  一開始是你先密我的~在這之前我完全沒有想過我跟你會有啥交集但自從那天開始我承認我蠻喜歡跟你聊...
# 318  小弟來高應大三年了，當初興沖沖想說在市區很方便，殊不知上課要到另一個校區啊!!!!!在這鳥不...
# 319  本人身材矮小才15x公分上圍有點豐滿(大概D 吧)，不胖不瘦，可是胸大看起來就有點肉肉有在健...
# 320  嗯，最近看了很多Dcard，上面有很多討論同性戀的議題，我看了有點不舒服又有點難過，下面的留...
# 321  剛剛在滑d card 時看到一篇關於劈腿的文章在我用手機打了肉肉長的回文後才發現原po已刪文...
# 322  國民黨前幾天領表截止，只有楊志良跟洪秀柱兩個人，不過應該是洪秀柱代表國民黨選2016總統，如...
# 323  下個月就要畢業了.....想去大陸工作或實習，出去闖看看挑戰的心情和累積經驗不知道有沒有人正...
# 324  相信最近應該有許多卡友看到北榮婦產科的胎死腹中事件，一位頂尖的婦產科醫師就這樣被指控，最後離...
# 325  大喇喇的射手女孩有時候實在TMD粗魯，但當你認識她的時候，她真的溫柔當她更喜歡你的時候(不一...
# 326  小的是一個離家好幾十公里唸書的孩子在家裡是最大的小孩下面有一個弟弟一個妹妹老爸在國外工作媽媽...
# 327  因為接下來三天天天要小考大考一直想著要讀書要讀書要讀書的玩了一個下午晚上的手遊好不容易關掉遊...
# 328  最近閃光怕我暑假無聊買了一本超厚超厚的《S.》來給我殺時間（因為他在當兵所以沒什麼時間陪我）...
# 329  ---------前提------------我是某個不靠海縣市+保守家庭養出的小孩，也許會...
# 330  蒸餃電鍋清蒸水餃下水煮煎餃加少許的油煎哪個比較好吃呢 ?_ _下一篇 餃子跟天津飯哪個好吃?...
# 331  有一年，我跟一群朋友吃飯。 我們開心的在聊天聊到一半。Ａ同學說：「欸，我大學時期騎車這麼的危...
# 332  今天看到這篇文章http://goo.gl/xaoYxF覺得統測生為甚麼待遇差這麼多去年我考...
# 333  從下定決心每天要運動還自己一個健康的身體開始,每晚操場跑步也持續了一個多月,差不多跑了快一個...
# 334  好 因為現在春天人發春是正常的但為什麼身邊都是見色忘友的人阿以前都笑笑的說我們是永遠的BFF...
# 335  我借男生朋友的帳號發的~小妹這學期修了一門有助教帶討論的課總而言之事情就發生在討論課我們教授...
# 336  我想應該有人有和我一樣的經驗我的大學好朋友是系上公認的正妹就是學長哈她同屆愛她學弟也迷戀的那...
# 337  深夜裡城市透著微光我沿著河畔漫步水岸此刻你想著誰?妳在遙遠的島國生活我在彼岸相望夜空 月明星...
# 338  有些人在別人面前總是很快樂搞笑啊，扮諧星啊看到別人快樂自己其實也會快樂但其實是因為我們不想帶...
# 339  37歲的黃姓高齡產婦孩子胎死腹中，日前在立委姚文智與謝維洲的陪同下召開記者會，控訴台北榮總醫...
# 318                        有沒有各校名產的八卦?
# 319                             胸大就是裸露
# 320                          給我一個出櫃的勇氣
# 321                               關於劈腿
# 322                     關於國民黨2016總統候選人
# 323                     想去大陸工作 該怎麼找職缺?
# 324            胎死腹中事件後，女孩還會希望跟男性醫生交往嗎？
# 325                          射手女孩都這樣嗎?
# 326                          弟弟，剋星回來囉！
# 327                          世界上最浪漫的情話
# 328                      有關《S.》這部小說的問題
# 329            有那個勇氣為什麼不敢進學校面對你的書啊(文長)
# 330                   蒸餃、水餃跟煎餃哪個比較好吃 ?
# 331                           千萬別鐵齒啊～～
# 332                   會考、統測大出包，學生待遇大不同
# 333                        那個我一直追不到的女孩
# 334                             關於見色忘友
# 335                   請不要把怪怪的東西放在桌上=_=
# 336                    為什麼我要當別人和她的交友踏板
# 337                  最近上走在學校偶有靈感,寫了一首詩
# 338                     其實我們不堅強只是會隱藏難過
# 339                榮總死胎案醫師請辭 姚文智鞠躬道歉快閃
# 340        【討論】為什麼家人總之限制小孩的發文自由？（文有點長）
#
# [341 rows x 8 columns]

# %%
article_raw_pd_list = []

# %%
target = 100000000
step = 100000
start = 0
HELPER_KEYSPACE = 'nlp_keyspace'

# %%
for x in range(start,target,step):
#     print str(x) + " ~ " + str(x+step)

    try:
        #select range
        cql = ("select article_id, question from dcard_query_table " +
                "where article_id > " + str(x) + " and article_id <= " + str(x+step) +
                " group by article_id allow filtering;")

#         cql = ("select * from nlp_keyspace.dcard_article " +
#                 "where article_id > " + str(x) + " and article_id <= " + str(x+step) + " allow filtering;")
        print cql
    #     cql = ("select * from nlp_keyspace.dcard_article_test;")
        pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
        article_raw_pd_list.append(pd_df)
    except:
        print 'break'
        cql = ("select article_id, question from dcard_query_table " +
                "where article_id > " + str(x) + " and article_id <= " + str(x+step) +
                " group by article_id allow filtering;")
        print cql
    #     cql = ("select * from nlp_keyspace.dcard_article_test;")
        pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
        article_raw_pd_list.append(pd_df)
        continue
# Out:
# select article_id, question from dcard_query_table where article_id > 0 and article_id <= 100000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 100000 and article_id <= 200000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 200000 and article_id <= 300000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 300000 and article_id <= 400000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 400000 and article_id <= 500000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 500000 and article_id <= 600000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 600000 and article_id <= 700000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 700000 and article_id <= 800000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 800000 and article_id <= 900000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 900000 and article_id <= 1000000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1000000 and article_id <= 1100000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1100000 and article_id <= 1200000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1200000 and article_id <= 1300000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1300000 and article_id <= 1400000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1400000 and article_id <= 1500000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1500000 and article_id <= 1600000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1600000 and article_id <= 1700000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1700000 and article_id <= 1800000 group by article_id allow filtering;
# break
# select article_id, question from dcard_query_table where article_id > 1700000 and article_id <= 1800000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1800000 and article_id <= 1900000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 1900000 and article_id <= 2000000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2000000 and article_id <= 2100000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2100000 and article_id <= 2200000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2200000 and article_id <= 2300000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2300000 and article_id <= 2400000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2400000 and article_id <= 2500000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2500000 and article_id <= 2600000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2600000 and article_id <= 2700000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2700000 and article_id <= 2800000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 2800000 and article_id <= 2900000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id >
 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99000000 and article_id <= 99100000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99100000 and article_id <= 99200000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99200000 and article_id <= 99300000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99300000 and article_id <= 99400000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99400000 and article_id <= 99500000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99500000 and article_id <= 99600000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99600000 and article_id <= 99700000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99700000 and article_id <= 99800000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99800000 and article_id <= 99900000 group by article_id allow filtering;
# select article_id, question from dcard_query_table where article_id > 99900000 and article_id <= 100000000 group by article_id allow filtering;

# %%
# cql=("select * from nlp_keyspace.dcard_query_table where article_id >200000000 and article_id < 200200000 group by article_id allow filtering;")
# pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
# article_raw_pd_list.append(pd_df)

# %%
# del pd_df
print len(article_raw_pd_list)
query_df=pd.DataFrame(columns=['article_id','question'])

query_df=pd.concat(article_raw_pd_list).reset_index(drop=True)
# Out:
# 1000

# %%
print len(query_df)
query_df
# Out:
# 111038
#         article_id                                           question
# 0            76367                                           自以為的以和為貴
# 1            13946                                              魯蛇成功記
# 2            83078                                   中華電信的iPhone6....
# 3            10305                                          剛剛考資格考第一科
# 4            46779                                         我想，這是一個里程碑
# 5            42565                                             最無奈的錯過
# 6            56309                                      有沒有感情過很坎坷的同路人
# 7            21766                                            想去旅行的城市
# 8            23962                                       既然遇見為何還是擦身而過
# 9            29720                                       愛情總是悄悄地出現 -5
# 10           82835                                             現在很想見你
# 11           64442                                           關於期末考的症狀
# 12           34744                                       有沒有私藏笑話可以聽 ?
# 13           84281                                              魯到都爛了
# 14           82471                                          永遠看不懂的驗證碼
# 15           35337                                              背包的款式
# 16           12820                         如果手機最多只能收藏200封訊息，你會保留哪些？：）
# 17           42412                                          BBC 候選人專訪
# 18           87694                                          臉頰烙印巴掌的記憶
# 19           35472                                    天呀 中午圖書館是晾美腿的地方
# 20           27682  大家都超嗨的啦！超好玩的啦！8/1台北單身趴圓滿落幕之超長心得與感謝文   大家好，我是副召...
# 21           58264                                          求救!想在楓谷跨年
# 22           12349                                     突然就是想不起來對方的本名!
# 23           28817                                                他的他
# 24           41188                                         大選在即，候選人是?
# 25           36167                                               安安你好
# 26           24792                                  妳喜歡他的一切，都是我調教出來的。
# 27           39299                                          其實自己呢呢呢～～
# 28           58351                                       關於出去玩滑手機這件事情
# 29           16634                                  最近的議題發燒發熱 卻讓我忽冷忽熱
# ...            ...                                                ...
# 111008    99713347                                           未滿18的大一生
# 111009    99740711                                    浩鼎案效應 民進黨訂翁啟惠條款
# 111010    99730593                                           放假還要被叫回去
# 111011    99765679                                           老妹真的太神回啦
# 111012    99783798                               美國首列互聯網屏蔽為貿易壁壘  中國反駁
# 111013    99739803                                               宿舍百態
# 111014    99765368                                 有人跟我一樣愛看wootalk文嗎😂
# 111015    99790716                                       VJR125的市占率??
# 111016    99815967                                             致..前男友
# 111017    99883028                                           彰化的下面是嘉義
# 111018    99821733                               對於台中吃燒肉訂位的無奈........
# 111019    99804095                                  越南促移南海鑽井平台 北京斷然拒絕
# 111020    99894993                                       下下禮拜別惹大學生不開心
# 111021    99829033                                     我的高中妹妹做料理Part2
# 111022    99849360                                        工作不嘗試後怎知好不好
# 111023    99852874                                         到底哪個報導是正確的
# 111024    99937412                                               大一領悟
# 111025    99960303                                                 三角
# 111026    99958929                                              #公車司機
# 111027    99941175                                             專業在哪裡？
# 111028    99974650                                           怎麼樣擴展交友圈
# 111029    99957837                                           身邊有沒有一種人
# 111030    99956251                                               我們的島
# 111031    99985770                                            大創可愛的婆婆
# 111032    99990566                                       有人跟我一樣是肚肚控嗎😂
# 111033    99964871                                       寶寶心理苦  但寶寶不說
# 111034    99972131                                             關於把妹金句
# 111035    99956186                                            沒有吃不胖的人
# 111036    99977672                                       不想去家庭旅遊該怎麼辦？
# 111037    99970227                                          我要用一句話上熱門
#
# [111038 rows x 2 columns]

# %%
# from pyspark.sql.functions import udf
# def update_column(x):
# #     check = QuestionTypeCheck(segmentor)
# #     check.source = 'ptt'
# #     label = check.check_question_type(x)
#     input_text = input_text.replace(u'Re: ', u'')
#     input_text = re.sub(u"\\[.*?]", u"", input_text)
#     segmentor = JiebaSegmentor(jieba_dict_path1, [jieba_dict_path2,jieba_dict_path3,jieba_dict_path4])
#     segmentor.pseg_lcut('test')
#     return 'label'

# update_column_udf = udf(update_column)
# new_df = df.withColumn('question_type',
#                     update_column_udf(df['question_type']))

# %%
# new_df = df.limit(100)

# %%
# dao.saveToCassandraDF(new_df, "nlp_keyspace", "dcard_article_test", "append")

# %%
def filter_by_tag(tag):
    v_tag = ['v', 'vd', 'vg', 'vi', 'vn', 'vq', 'vt']
    n_tag = ['n', 'ng', 'nr', 'nrfg', 'nrt', 'ns', 'nt','nz']
    a_tag = ['a', 'ad', 'ag', 'an']
#         print tag['word'][0] + '(' + tag['tag'][0] + ')'
    if tag in v_tag or tag in n_tag or tag in a_tag:
        return True
    return False

def filter_by_tag_udf(row):
    v_tag = ['v', 'vd', 'vg', 'vi', 'vn', 'vq', 'vt']
    n_tag = ['n', 'ng', 'nr', 'nrfg', 'nrt', 'ns', 'nt','nz']
    a_tag = ['a', 'ad', 'ag', 'an']
#         print tag['word'][0] + '(' + tag['tag'][0] + ')'
    if row['tag'] in v_tag or row['tag'] in n_tag or row['tag'] in a_tag:
        return True
    return False

# %%
WORD_ARTICLE_MAPPING_TABLE = 'word_article_mapping'

for index, row in query_df.iterrows():
    
    # question斷詞
    if not row['question']:
        continue
    
#     print row['question']
    words = segmentor.pseg_lcut(row['question'])
#     print words
    article = row['article_id']
    for index, row in words.iterrows():
#         print row['word']
        
        # 只存名詞 and 動詞
        if filter_by_tag(row['tag']):
        # 每個詞更新到 mapping table
            cql = ("update " + WORD_ARTICLE_MAPPING_TABLE + " " +
                   "set article = article + [" + str(article) + "] " +
                   "where word = '" + row['word'] + "';")
#             print cql
#             dao.execCQL(HELPER_KEYSPACE, cql)

# %%
ppp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a2d17bb96faf> in <module>()
# ----> 1 ppp
#
# NameError: name 'ppp' is not defined

# %% [markdown]
# # query test

# %%
segmentor.stopwords=True
segmentor.pseg_lcut('肯德基新產品完勝麥當勞')
# Out:
#    tag word
# 0   nr  肯德基
# 1    a    新
# 2    n   產品
# 3    v   完勝
# 4  nrt  麥當勞

# %%
from gensim.corpora import *
from gensim.models import TfidfModel
from datetime import datetime
from gensim import models
tfidf_model_path = "/home/charles/dataset/tfidf_model/v2"
tfidf_model = TfidfModel.load(tfidf_model_path+"/tfidf.model")
dictionary = Dictionary.load(tfidf_model_path+"/tfidf_corpus_dict")

# %%
stopword_set = set()
with open(jieba_stopwords_path,'r') as stopwords:
    for stopword in stopwords:
        stopword_set.add(stopword.strip('\n').decode('utf-8'))

# %%
def find_keyword(text):
# #     test_cut_raw_0 = jieba.lcut(text)
#     test_cut_raw_0 =pseg.lcut(text)
#     text_subject_dict={}
#     for w,n in test_cut_raw_0:
#         print w + ' (' + n + ')'
#         text_subject_dict.update({w:n})
    
    if type(text) is not unicode:
        text = text.decode('utf-8')
        
    segmentor.stopwords=True

    text_subject_dict={}
    words_pd = segmentor.pseg_lcut(text)
    for index, row in words_pd.iterrows():
        text_subject_dict.update({row['word']:row['tag']})
        
    
    # jieba分词语料集 去除停用词
#     corpus0 = []
#     # load stopwords set
#     stopword_set = set()
#     with open(jieba_stopwords_path,'r') as stopwords:
#         for stopword in stopwords:
#             stopword_set.add(stopword.strip('\n').decode('utf8'))
#     for index, row in words_pd.iterrows():
#         if row['word'] not in stopword_set:
#             corpus0.append(row['word'])
    
    corpus0 = list(words_pd['word'])
    
    test_corpus_0 = dictionary.doc2bow(corpus0)
    test_corpus_tfidf_0 = tfidf_model[test_corpus_0]
    test_corpus_tfidf_0 = sorted(test_corpus_tfidf_0, key=lambda item: item[1], reverse=True)
    id2token = dict(zip(dictionary.token2id.values(), dictionary.token2id.keys()))
    result = []
    
    keyword_dict={}
    keyword_frames_list=[]
    word_list=[]
    tag_list=[]
    tfidf_list=[]
    for i in range(len(test_corpus_tfidf_0)):
        result.append({id2token[test_corpus_tfidf_0[i][0]]: test_corpus_tfidf_0[i][1]})
        print "--------------------------------------"
        word = id2token[test_corpus_tfidf_0[i][0]]
        tfidf = test_corpus_tfidf_0[i][1]
        print 'keyword: ' + word + '(' + text_subject_dict[word] + ') , tfidf: ' + str(tfidf)
        word_list.append(word)
        tag_list.append(text_subject_dict[word])
        tfidf_list.append(tfidf)
    
    keyword_pd=pd.DataFrame({"word":word_list,
                             "tag":tag_list,
                             "tfidf":tfidf_list})
    return keyword_pd
#         try:
#             w2v_predict(w2v_model, word)
#         except KeyError as er:
#             print 'no synonyms'

# %%
# TFIDF 字不會重複出現
keyword_pd = find_keyword('柯文哲2020選總統')
keyword_pd
# Out:
# --------------------------------------
# keyword: 柯文哲(n) , tfidf: 0.7892749298187913
# --------------------------------------
# keyword: 選(v) , tfidf: 0.48881048728300514
# --------------------------------------
# keyword: 總統(n) , tfidf: 0.37163072085296306
#   tag     tfidf word
# 0   n  0.789275  柯文哲
# 1   v  0.488810    選
# 2   n  0.371631   總統

# %%
# 查對應表
mapping_dict={}
mapping_frames_list=[]

# 只存名詞 and 動詞
keyword_pd['filter_by_tag'] = keyword_pd.apply(filter_by_tag_udf, axis=1)
keyword_pd = keyword_pd[keyword_pd['filter_by_tag'] == True]
print keyword_pd
top_n = 3
for index, row in keyword_pd.head(top_n).iterrows():
    
    cql = ("select * from nlp_keyspace.word_article_mapping where word='" + row['word'] + "';")
    print cql
    pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
    mapping_frames_list.append(pd_df)

if len(mapping_frames_list) > 0:
    mapping_pd=pd.DataFrame(columns=['row','article'])
    mapping_pd=pd.concat(mapping_frames_list).reset_index(drop=True)
mapping_pd
# Out:
#   tag     tfidf word filter_by_tag
# 0   n  0.789275  柯文哲          True
# 1   v  0.488810    選          True
# 2   n  0.371631   總統          True
# select * from nlp_keyspace.word_article_mapping where word='柯文哲';
# select * from nlp_keyspace.word_article_mapping where word='選';
# select * from nlp_keyspace.word_article_mapping where word='總統';
#   word                                            article
# 0  柯文哲  [62729, 41495, 44917, 22088, 40245, 40309, 696...
# 1    選  [17042, 33765, 15662, 15808, 37238, 49332, 441...
# 2   總統  [96854, 16633, 6196, 34614, 69325, 11161, 6426...

# %%
# 統計哪個字出現最多次
article_list=[]
for index, row in mapping_pd.iterrows():
    #單個字去除重複文章id
    for item in list(set(row['article'])):
        article_list.append(item)
#         article_list.append(list(set(item)))
#         print type(item)
        
print str(len(article_list))
# article_list
# Out:
# 466

# %%
from collections import Counter
result = Counter(article_list)
count_pd = pd.DataFrame(dict(result).items(), columns=['article_id', 'count'])
count_pd = count_pd.sort_values(by=['count'], ascending=False)
print len(count_pd)
count_pd
# Out:
# 459
#      article_id  count
# 163     1377629      2
# 396      882547      2
# 90       717009      2
# 427      814411      2
# 137      854316      2
# 183      706415      2
# 243       39434      2
# 0        462848      1
# 306      938650      1
# 307      889499      1
# 308      492191      1
# 304     1012375      1
# 309      857200      1
# 310      587035      1
# 311       36507      1
# 312      512677      1
# 313       40617      1
# 305      510616      1
# 301      593550      1
# 303       17042      1
# 302     1006223      1
# 300     1066946      1
# 299      952972      1
# 298     1042058      1
# 297      274057      1
# 296      469636      1
# 295      996995      1
# 294      394877      1
# 293     1219196      1
# 292     7211639      1
# ..          ...    ...
# 117      866564      1
# 143      588086      1
# 144    44862775      1
# 145    69893172      1
# 159      936277      1
# 171      525677      1
# 170      737644      1
# 169      538981      1
# 168      992610      1
# 167     1002896      1
# 166       13664      1
# 165      999775      1
# 164      771422      1
# 162       29017      1
# 161    26263896      1
# 160      791933      1
# 158       40931      1
# 146       56636      1
# 157       11161      1
# 156      161103      1
# 155      522466      1
# 154     1076172      1
# 153      947255      1
# 152    32540995      1
# 151    61832514      1
# 150      948960      1
# 149      986432      1
# 148      561057      1
# 147     1165629      1
# 458      550909      1
#
# [459 rows x 2 columns]

# %%
# 至少要出現兩個字
top_pd = count_pd[count_pd['count'] > 1]
top_pd
# if len(top_pd) == 0:
#     top_pd = count_pd[count_pd['count'] == 1]
# Out:
#      article_id  count
# 163     1377629      2
# 396      882547      2
# 90       717009      2
# 427      814411      2
# 137      854316      2
# 183      706415      2
# 243       39434      2

# %%
# 依照次數分類查詢

count_list = sorted(list(set(top_pd['count'])), reverse=True)
count_list
# Out:
# [2]

# %%
response_frames_list = []
for count in count_list:
    print count
    ans_pd = top_pd[top_pd['count'] == count]
    for index, row in ans_pd.iterrows():
    
#         cql = ("select * from nlp_keyspace.dcard_response where article_id=" +
#                str(row['article_id']) + ";")
        
        cql = ("select * from nlp_keyspace.dcard_query_table where article_id=" +
               str(row['article_id']) + ";")
        print cql
        pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
        response_frames_list.append(pd_df)
    
    if len(response_frames_list) > 0:
        answer_pd=pd.concat(response_frames_list).reset_index(drop=True)
        if len(answer_pd) > 10:
            break
        
answer_pd
# Out:
# 2
# select * from nlp_keyspace.dcard_query_table where article_id=1377629;
# select * from nlp_keyspace.dcard_query_table where article_id=882547;
# select * from nlp_keyspace.dcard_query_table where article_id=717009;
# select * from nlp_keyspace.dcard_query_table where article_id=814411;
# select * from nlp_keyspace.dcard_query_table where article_id=854316;
# select * from nlp_keyspace.dcard_query_table where article_id=706415;
# select * from nlp_keyspace.dcard_query_table where article_id=39434;
#     article_id  floor     board  like_count                         question  \
# 0      1377629      1  trending           4           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 1      1377629      2  trending           3           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 2      1377629      3  trending           3           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 3      1377629      4  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 4      1377629      5  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 5      1377629      6  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 6      1377629      7  trending           3           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 7      1377629      8  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 8       882547      1  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 9       882547      2  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 10      882547      3  trending           2             測測自己的政見意向，你會選哪一位總統呢？
# 11      882547      6  trending           2             測測自己的政見意向，你會選哪一位總統呢？
# 12      882547      7  trending           1             測測自己的政見意向，你會選哪一位總統呢？
# 13      882547      9  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 14      882547     10  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 15      882547     16  trending           6             測測自己的政見意向，你會選哪一位總統呢？
# 16      882547     17  trending           5             測測自己的政見意向，你會選哪一位總統呢？
# 17      882547     18  trending           1             測測自己的政見意向，你會選哪一位總統呢？
# 18      882547     21  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 19      717009      1  trending           4                           總統該選誰？
# 20      717009      2  trending           5                           總統該選誰？
# 21      717009      3  trending           2                           總統該選誰？
# 22      717009      5  trending           8                           總統該選誰？
# 23      717009      8  trending           5                           總統該選誰？
# 24      717009     11  trending           3                           總統該選誰？
# 25      717009     13  trending           3                           總統該選誰？
# 26      717009     14  trending           4                           總統該選誰？
# 27      717009     25  trending           0                           總統該選誰？
# 28      717009     26  trending           1                           總統該選誰？
# 29      717009     27  trending           0                           總統該選誰？
# ..         ...    ...       ...         ...                              ...
# 54      854316      8  trending           5                        總統到底可以選誰啊
# 55      854316      9  trending           0                        總統到底可以選誰啊
# 56      854316     10  trending           4                        總統到底可以選誰啊
# 57      854316     11  trending           0                        總統到底可以選誰啊
# 58      854316     14  trending           2                        總統到底可以選誰啊
# 59      854316     20  trending           0                        總統到底可以選誰啊
# 60      854316     21  trending           4                        總統到底可以選誰啊
# 61      854316     22  trending           2                        總統到底可以選誰啊
# 62      854316     27  trending           1                        總統到底可以選誰啊
# 63      854316     29  trending           0                        總統到底可以選誰啊
# 64      854316     30  trending           0                        總統到底可以選誰啊
# 65      854316     31  trending           1                        總統到底可以選誰啊
# 66      854316     32  trending           1                        總統到底可以選誰啊
# 67      854316     33  trending           2                        總統到底可以選誰啊
# 68      706415      1  trending           4        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 69      706415      4  trending           7        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 70      706415      6  trending           2        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 71      706415      7  trending           0        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 72      706415      8  trending           2        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 73      706415      9  trending           3        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 74      706415     10  trending           0        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 75      706415     11  trending           2        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 76      706415     13  trending           1        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 77      706415     14  trending           0        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 78       39434      1  trending           6  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 79       39434      2  trending           4  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 80       39434      4  trending           6  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 81       39434      5  trending           4  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 82       39434      6  trending           1  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 83       39434      9  trending           3  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
#
#                                       response
# 0                                     名嘴先去醒醒腦…
# 1              建議多方攝取資訊\n一體兩面的事情很多\n每個人解讀方式也不同
# 2                              無期限支持柯文哲選中華民國總統
# 3                                臺灣名嘴的話原po敢信？？
# 4                               現在覺得他有時候的反應太矯情
# 5                                      開微博反攻大陸
# 6     如果是馬英九去開設微博帳號不知道會被罵成多慘\n\n說不定還有人要用叛亂罪起訴他
# 7                         如果柯p用推特是不是就要選美國總統了ㄎㄎ
# 8                                   希望也有政黨票的xd
# 9                                        還蠻有趣的
# 10              我怎麼覺得\n它每個議題的選項都只有兩個\n有點引導式問答？
# 11                                  為什麼我朱豬倫是0%
# 12                                 44% 蔡 44% 宋
# 13                         蔡47% 宋41% 12%朱\nXDD
# 14                                  因為跳過也是一種回答
# 15                               東華妹當然朱的不能有半分啊
# 16                              東華妹一定玩了超多次xXDD
# 17                              才沒有XDDD\n一次而已啦
# 18                                  你們這樣朱立倫很傷心
# 19                            蔡英文的反核政策不錯，你可以參考
# 20                                    不要投KMT就好
# 21                            等看到選舉人公報就知道政見了~~
# 22  你讓我突然覺得自己只會看人就投票很膚淺\n我有空也來研究政策好了\n\n星期一天氣晴
# 23     妳來這發問不如上網去發漏候選人的網頁、臉書，裡面一大堆怎麼會不知道有什麼政見？
# 24         說好的 做好 做滿\n那就要真的 做好 做滿\n請還給新北市民一個市長
# 25                    有個連紅豆餅的餡都包不滿了\n可想而知啊XDDD
# 26                        這麼猶豫 都選不就得了ヾ(*´∀｀*)ﾉ
# 27                      銘傳財經是上次留一堆亂嗆又狂自刪留言那位嗎？
# 28                                 民國黨可是雷射師父阿~
# 29                 妳可以去g0v找找，有人在幫忙蒐集政見，朱立倫目前很缺
# ..                                         ...
# 54                                       藍信祺正解
# 55                              自己設法多方蒐集彙整資料啊!
# 56                                       投我啊廢話
# 57                                    投小英 放空台指
# 58                  蔡英文２０１２有說沒選上就不選？？\n可以給個資料嗎
# 59                                  不要讓新北市民不開心
# 60                                        棄朱保宋
# 61                                     小英加油！\n
# 62                          你不知道台灣人有100%的健忘症嗎？
# 63                               不是已經選完了嗎XDDDD
# 64                                      淘汰爛蘋果啊
# 65                               馬英九的民調是19趴好嗎
# 66                            宋神掌也是蠻可憐 選了一輩子總統
# 67                   宋楚瑜完全就是封建思維的人\n千千萬萬不要被他唬了
# 68                                   .....錢太多哦
# 69                   第一個說要公開建國的候選人耶\n台獨的不支持一下嗎
# 70               請轉有趣版\n話說美國也是有阿貓阿狗在選總統的，不必太意外
# 71                               有提政策給推 反觀某空心菜
# 72               傻孩子 你有沒有看到猴王因為這樣所以在陪德到處漏尿發神經?
# 73                                      推轉有趣版😂
# 74                              看來你是接不下我的必殺絕招了
# 75                                       譁眾取寵啦
# 76                   哈哈哈~~~~~建議他直接來看我們精神科比較快XD
# 77                            今天看到笑死\n他的FB更好笑喔
# 78                                    2:45有點奇葩
# 79                              不想看民調了，直接坐等結果。
# 80       柯P的當選絕對是台灣政治轉型的第一步，只是希望他未來在市議會還能扛得住XD
# 81                                柯P當選會用誰啊?(歪頭
# 82              那個42%拒絕回答的都是選連勝文的, \n\n柯P這次書定惹
# 83  可以的話 \n我一點都不希望這兩個人當選…\n\n到底是誰推這兩個人出來選市長的啊！
#
# [84 rows x 6 columns]

# %%
# response_dict={}
# response_frames_list=[]
# top_count = 0
# count_list = list(top_pd['count'])
# for index, row in top_pd.iterrows():
    
#     cql = ("select * from nlp_keyspace.dcard_response where article_id=" + str(row['article_id']) + ";")
#     print cql
#     pd_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
    
    
#     response_frames_list.append(pd_df)
# #     if len(pd_df) > 4:
# #         break

# # response_pd=pd.DataFrame(columns=['row','article'])
# answer_pd = pd.DataFrame({})
# if len(response_frames_list) > 0:
#     answer_pd=pd.concat(response_frames_list).reset_index(drop=True)

# %% [markdown]
# # 透過question_type查wiki,google search, google map

# %%
# for index, row in top_pd.iterrows():
#     cql = ("select * from nlp_keyspace.dcard_article_test where article_id=" + str(row['article_id']) + ";")
#     print cql
#     article_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)
#     print article_df['question'][0]

# %%
if len(answer_pd) == 0:
    print 'AQ還在學習中......'

# %% [markdown]
# # 過濾答案

# %%
# import re
# def filter_url(row):
    
#     pattern = re.compile('http://\S+|https://\S+')
#     match = pattern.search(row['content'])
#     if match:
#         return True
#     return False

# # 過濾url的答案
# mask = (answer_pd['has_url'] == False)
# answer_pd = answer_pd.loc[mask]

# %%
if len(answer_pd):
    answer_pd = answer_pd.sort_values(by=['like_count'], ascending=False)
#     print answer_pd
answer_pd
# Out:
#     article_id  floor     board  like_count                         question  \
# 36      814411      4  trending          52              柯文哲:台灣醫療沒人敢改 除非我當總統
# 35      814411      1  trending          43              柯文哲:台灣醫療沒人敢改 除非我當總統
# 38      814411      6  trending          10              柯文哲:台灣醫療沒人敢改 除非我當總統
# 22      717009      5  trending           8                           總統該選誰？
# 37      814411      5  trending           8              柯文哲:台灣醫療沒人敢改 除非我當總統
# 50      854316      1  trending           8                        總統到底可以選誰啊
# 69      706415      4  trending           7        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 80       39434      4  trending           6  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 78       39434      1  trending           6  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 41      814411      9  trending           6              柯文哲:台灣醫療沒人敢改 除非我當總統
# 15      882547     16  trending           6             測測自己的政見意向，你會選哪一位總統呢？
# 16      882547     17  trending           5             測測自己的政見意向，你會選哪一位總統呢？
# 23      717009      8  trending           5                           總統該選誰？
# 20      717009      2  trending           5                           總統該選誰？
# 54      854316      8  trending           5                        總統到底可以選誰啊
# 19      717009      1  trending           4                           總統該選誰？
# 0      1377629      1  trending           4           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 26      717009     14  trending           4                           總統該選誰？
# 56      854316     10  trending           4                        總統到底可以選誰啊
# 60      854316     21  trending           4                        總統到底可以選誰啊
# 68      706415      1  trending           4        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 79       39434      2  trending           4  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 81       39434      5  trending           4  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 48      814411     21  trending           4              柯文哲:台灣醫療沒人敢改 除非我當總統
# 1      1377629      2  trending           3           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 73      706415      9  trending           3        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 83       39434      9  trending           3  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 6      1377629      7  trending           3           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 2      1377629      3  trending           3           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 25      717009     13  trending           3                           總統該選誰？
# ..         ...    ...       ...         ...                              ...
# 17      882547     18  trending           1             測測自己的政見意向，你會選哪一位總統呢？
# 31      717009     36  trending           1                           總統該選誰？
# 82       39434      6  trending           1  連勝文 vs 柯文哲 - 你要選誰? 為什麼? 最後30天民調
# 65      854316     31  trending           1                        總統到底可以選誰啊
# 74      706415     10  trending           0        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 77      706415     14  trending           0        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 71      706415      7  trending           0        「世界台灣皇帝」藍信祺選總統　政見：每人發100億
# 5      1377629      6  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 4      1377629      5  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 7      1377629      8  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 3      1377629      4  trending           0           柯文哲開微博圖總統大位？ 市府澄清：增加善意
# 8       882547      1  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 27      717009     25  trending           0                           總統該選誰？
# 64      854316     30  trending           0                        總統到底可以選誰啊
# 14      882547     10  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 29      717009     27  trending           0                           總統該選誰？
# 30      717009     35  trending           0                           總統該選誰？
# 32      717009     37  trending           0                           總統該選誰？
# 18      882547     21  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 39      814411      7  trending           0              柯文哲:台灣醫療沒人敢改 除非我當總統
# 40      814411      8  trending           0              柯文哲:台灣醫療沒人敢改 除非我當總統
# 43      814411     12  trending           0              柯文哲:台灣醫療沒人敢改 除非我當總統
# 63      854316     29  trending           0                        總統到底可以選誰啊
# 44      814411     14  trending           0              柯文哲:台灣醫療沒人敢改 除非我當總統
# 13      882547      9  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 49      814411     22  trending           0              柯文哲:台灣醫療沒人敢改 除非我當總統
# 57      854316     11  trending           0                        總統到底可以選誰啊
# 59      854316     20  trending           0                        總統到底可以選誰啊
# 9       882547      2  trending           0             測測自己的政見意向，你會選哪一位總統呢？
# 55      854316      9  trending           0                        總統到底可以選誰啊
#
#                                       response
# 36    我覺得柯p是個很誠實的人\n他在想什麼都很明確的跟大家說\n總比很多人心照不宣好
# 35                                 卡等2020柯P選總統
# 38                               感覺他至少比小英還有老朱強
# 22  你讓我突然覺得自己只會看人就投票很膚淺\n我有空也來研究政策好了\n\n星期一天氣晴
# 37                      拜託別再出來亂了\n先把你跳票的政見搞好好嗎
# 50                         你之前有去幫其他四組獨立候選人連署嗎？
# 69                   第一個說要公開建國的候選人耶\n台獨的不支持一下嗎
# 80       柯P的當選絕對是台灣政治轉型的第一步，只是希望他未來在市議會還能扛得住XD
# 78                                    2:45有點奇葩
# 41                         柯批選總統 \n我絕對從美國飛回來投票
# 15                               東華妹當然朱的不能有半分啊
# 16                              東華妹一定玩了超多次xXDD
# 23     妳來這發問不如上網去發漏候選人的網頁、臉書，裡面一大堆怎麼會不知道有什麼政見？
# 20                                    不要投KMT就好
# 54                                       藍信祺正解
# 19                            蔡英文的反核政策不錯，你可以參考
# 0                                     名嘴先去醒醒腦…
# 26                        這麼猶豫 都選不就得了ヾ(*´∀｀*)ﾉ
# 56                                       投我啊廢話
# 60                                        棄朱保宋
# 68                                   .....錢太多哦
# 79                              不想看民調了，直接坐等結果。
# 81                                柯P當選會用誰啊?(歪頭
# 48                                快改吧 我７年後要工作啦
# 1              建議多方攝取資訊\n一體兩面的事情很多\n每個人解讀方式也不同
# 73                                      推轉有趣版😂
# 83  可以的話 \n我一點都不希望這兩個人當選…\n\n到底是誰推這兩個人出來選市長的啊！
# 6     如果是馬英九去開設微博帳號不知道會被罵成多慘\n\n說不定還有人要用叛亂罪起訴他
# 2                              無期限支持柯文哲選中華民國總統
# 25                    有個連紅豆餅的餡都包不滿了\n可想而知啊XDDD
# ..                                         ...
# 17                              才沒有XDDD\n一次而已啦
# 31              去官網看呀\n寫滿多的\n\n千萬不要大家說誰空心妳就信了！
# 82              那個42%拒絕回答的都是選連勝文的, \n\n柯P這次書定惹
# 65                               馬英九的民調是19趴好嗎
# 74                              看來你是接不下我的必殺絕招了
# 77                            今天看到笑死\n他的FB更好笑喔
# 71                               有提政策給推 反觀某空心菜
# 5                                      開微博反攻大陸
# 4                               現在覺得他有時候的反應太矯情
# 7                         如果柯p用推特是不是就要選美國總統了ㄎㄎ
# 3                                臺灣名嘴的話原po敢信？？
# 8                                   希望也有政黨票的xd
# 27                      銘傳財經是上次留一堆亂嗆又狂自刪留言那位嗎？
# 64                                      淘汰爛蘋果啊
# 14                                  因為跳過也是一種回答
# 29                 妳可以去g0v找找，有人在幫忙蒐集政見，朱立倫目前很缺
# 30                           三個都各蓋一個章，都支持，都好棒棒
# 32                  空心又不是指沒政見\n是指政見都是些天方夜譚吧0.0
# 18                                  你們這樣朱立倫很傷心
# 39                                        猛烈..
# 40                                      柯p選總统~
# 43                         哈哈去跟小英說啊\n說不定她會採納意見
# 63                               不是已經選完了嗎XDDDD
# 44                 砍老的實在是.........小的也沒有比較多啊= =
# 13                         蔡47% 宋41% 12%朱\nXDD
# 49                      為什麼他說的很多話都跟我看的研究成果不一樣…
# 57                                    投小英 放空台指
# 59                                  不要讓新北市民不開心
# 9                                        還蠻有趣的
# 55                              自己設法多方蒐集彙整資料啊!
#
# [84 rows x 6 columns]

# %%
for i,r in answer_pd.reset_index().iterrows():
    print str(i) + '. ' + r['content']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-b69cbe407eee> in <module>()
#       1 for i,r in answer_pd.reset_index().iterrows():
# ----> 2     print str(i) + '. ' + r['content']
#
# /home/charles/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     555     def __getitem__(self, key):
#     556         try:
# --> 557             result = self.index.get_value(self, key)
#     558
#     559             if not np.isscalar(result):
#
# /home/charles/anaconda2/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1802                     raise InvalidIndexError(key)
#    1803                 else:
# -> 1804                     raise e1
#    1805             except Exception:  # pragma: no cover
#    1806                 raise e1
#
# KeyError: 'content'

# %% [markdown]
# # 沒找到就回答罐頭訊息

# %%
ppp

# %% [markdown]
# # 測試

# %%
cql = ("select * from nlp_keyspace.word_article_mapping;")
map_df = dao.execCQLSelectToPandasDF(HELPER_KEYSPACE, cql)

# %%
len(map_df)

# %%
word_df = map_df[map_df['word'].str.len() == 1]
print len(word_df)
word_df
